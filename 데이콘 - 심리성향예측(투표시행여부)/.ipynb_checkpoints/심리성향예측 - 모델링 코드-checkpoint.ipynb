# %%
from os import listdir
import os
import pandas as pd
import numpy as np
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error, f1_score, roc_auc_score
from sklearn.model_selection import cross_val_score, GridSearchCV,StratifiedKFold, KFold, RandomizedSearchCV, train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
import catboost as cb
from sklearn.ensemble import ExtraTreesClassifier

from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.model_selection import cross_validate

warnings.filterwarnings(action='ignore')

plt.style.use('ggplot') #ggplot스타일 사용
plt.rc('axes', unicode_minus=False)

# %%
def correlation_extract(df, threshold):
    cor_df = df.corr()
    col_list = cor_df.columns
    
    for idx, col in enumerate(col_list):
        idx_ls = cor_df[abs(cor_df[col])>=threshold].index.tolist()
        print(f'{col} : {idx_ls}')
def col_extract(df):
    col_ls = []
    for col in df.columns.tolist():
        if col[0] == 'Q' and col[-1] == 'E':
            col_ls.append(col)
            
    return col_ls

# %%
model_path = './modeling_folder'
data_file_path = './open data'

# %%
tr = pd.read_csv(os.path.join(model_path,'train_data.csv'))
te = pd.read_csv(os.path.join(model_path,'test_data.csv'))

# %%
# modeling_file_ls = []
# for file in os.listdir(model_path):
#     if 'modeling' in file:
#         modeling_file_ls.append(file)

# ver_num_ls = []
# for file in modeling_file_ls:
#     ver_num_ls.append(re.sub('[^0-9]','',file))

# ver_num = int(pd.Series(list(set(ver_num_ls))).sort_values(ascending=False).iloc[0])
ver_num =  1

base_tr = pd.read_csv(os.path.join(data_file_path,'train.csv'))
tr = pd.read_csv(
    os.path.join(model_path,'modeling_tr_ver{}.csv'.format(ver_num))
)
te = pd.read_csv(
    os.path.join(model_path,'modeling_te_ver{}.csv'.format(ver_num))
)

base_column = base_tr.drop(columns = 'index').columns.tolist()
submission = te[['index']]

tr.drop(columns = 'index',inplace = True)
te.drop(columns = 'index', inplace = True)

# %%
# 변수 체크
tr.columns
# Out:
# Index(['QaA', 'QaE', 'QbA', 'QbE', 'QcA', 'QcE', 'QdA', 'QdE', 'QeA', 'QeE',
#        'QfA', 'QfE', 'QgA', 'QgE', 'QhA', 'QhE', 'QiA', 'QiE', 'QjA', 'QjE',
#        'QkA', 'QkE', 'QlA', 'QlE', 'QmA', 'QmE', 'QnA', 'QnE', 'QoA', 'QoE',
#        'QpA', 'QpE', 'QqA', 'QqE', 'QrA', 'QrE', 'QsA', 'QsE', 'QtA', 'QtE',
#        'age_group', 'education', 'engnat', 'familysize', 'gender', 'hand',
#        'married', 'race', 'religion', 'tp01', 'tp02', 'tp03', 'tp04', 'tp05',
#        'tp06', 'tp07', 'tp08', 'tp09', 'tp10', 'urban', 'voted', 'wf_01',
#        'wf_02', 'wf_03', 'wr_01', 'wr_02', 'wr_03', 'wr_04', 'wr_05', 'wr_06',
#        'wr_07', 'wr_08', 'wr_09', 'wr_10', 'wr_11', 'wr_12', 'wr_13',
#        'Q_E_sum', 'Q_E_median', 'education_ft1', 'education_ft2',
#        'married_value', 'age_group_value', 'wr_sum', 'wf_sum', 'wr_wf_sum'],
#       dtype='object')

# %% [markdown]
# # Model training

# %% [markdown]
# ## LGBM Modeling code

# %%
def validation_model(df,base_column):
    plus_col = list(set(df.columns.tolist()) - set(base_column))
    except_col = list(set(base_column) - set(df.columns.tolist()))
    print(f'추가변수 : {plus_col}')
    print(f'제외변수 : {except_col}')
    X_train, X_test, y_train, y_test = train_test_split(
                                df.drop(columns = 'voted'),df['voted'],
                                random_state = 0,
                                test_size = 0.2
                            )
    
    folds = StratifiedKFold(n_splits=5, shuffle = True, random_state = 111)
    oof_preds = np.zeros(X_train.shape[0])
    test_preds = np.zeros(X_test.shape[0])
    feature_importance = pd.DataFrame()
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_train,y_train)):
        
        train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
        valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]

#       'bagging_fraction': 0.5174586752499394,
#       'colsample_bytree': 0.16336591285805346,
#       'feature_fraction': 0.6600295087430476,
#       'lambda_l1': 0.5045786221433113,
#       'lambda_l2': 0.34677843618253623,
#       'learning_rate': 0.008679434863557151,
#       'max_depth': 5.05906487896959,
#       'min_child_weight': 35.46747545288431,
#       'num_leaves': 532.5547433920851
     
    # 성능이 좋은 베이지안 파라미터
#      bagging_fraction = 0.9669958011996147,
#             colsample_bytree = 0.5987970645475955, # 0.78
#             feature_fraction = 0.7318970172463788,
#             lambda_l1 = 0.03879591433177747,
#             lambda_l2 = 0.2799788929506455,
#             learning_rate = 0.006097808404537128, # 0.011
#             max_depth = 9,
#             min_child_weight = 38,
#             num_leaves = 395,

# 로그화
# bagging_fraction = 0.16026521886490075,
# colsample_bytree = 0.38230762664460116,
# feature_fraction = 0.8803127292536881,
# lambda_l1 = 0.6427909607958205,
# lambda_l2 = 0.8516225399539507,
# learning_rate = 0.004810297234567945,
# max_depth = 6.072081164468878,
# min_child_weight = 30.470923513342353,
# num_leaves = 570.2124396849822,

        clf = lgb.LGBMClassifier(
            n_estimators=1000,
            objective='binary',
            boosting_type='gbdt', # gbdt
            bagging_fraction = 0.16026521886490075,
            colsample_bytree = 0.38230762664460116,
            feature_fraction = 0.8803127292536881,
            lambda_l1 = 0.6427909607958205,
            lambda_l2 = 0.8516225399539507,
            learning_rate = 0.004810297234567945,
            max_depth = 6,
            min_child_weight = 30,
            num_leaves = 570,
            random_state= 200,
        )
        
        clf.fit(
            train_x, train_y,
            eval_set = [(train_x, train_y), (valid_x, valid_y)], 
            eval_metric='auc', 
            verbose= 100, 
            early_stopping_rounds=300,
        )
        
        oof_preds[valid_idx] = clf.predict_proba(valid_x, best_iteration_ = clf.best_iteration_)[:,1]
        test_preds += clf.predict_proba(X_test, num_iteration = clf.best_iteration_)[:,1] / folds.n_splits 
        
        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = X_train.columns
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance = pd.concat([feature_importance, fold_importance_df], axis=0)

        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
    
    ft = feature_importance.groupby('feature')['importance'].mean().reset_index()

    ft2 = ft.sort_values('importance',ascending = False).iloc[:50]
    
    feature_graph_df = feature_importance.sort_values('importance')
    plt.figure(figsize = (16,12))
    plt.barh(ft2['feature'],ft2['importance'])
    
    final_score = roc_auc_score(y_test,test_preds)
    print('\n\n')
    print('================================================')
    print(f'\n최종성능: {final_score}\n')
    print('================================================')
    return ft, test_preds, y_test

# %% [markdown]
# ### LGBM training

# %%
ft, test_preds, y_test = validation_model(tr,base_column)
# Out:
# 추가변수 : ['education_ft2', 'age_group_value', 'wr_sum', 'married_value', 'wr_wf_sum', 'education_ft1', 'Q_E_sum', 'wf_sum', 'Q_E_median']
# 제외변수 : []
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0
# [700]	training's auc: 0.834822	training's binary_logloss: 0.506044	valid_1's auc: 0.762505	valid_1's binary_logloss: 0.559688
# [800]	training's auc: 0.841984	training's binary_logloss: 0.499934	valid_1's auc: 0.762471	valid_1's binary_logloss: 0.559815
# Early stopping, best iteration is:
# [548]	training's auc: 0.824902	training's binary_logloss: 0.514581	valid_1's auc: 0.762822	valid_1's binary_logloss: 0.559409
# Fold  3 AUC : 0.762822
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.782102	training's binary_logloss: 0.574479	valid_1's auc: 0.764335	valid_1's binary_logloss: 0.580901
# [200]	training's auc: 0.791156	training's binary_logloss: 0.547842	valid_1's auc: 0.767918	valid_1's binary_logloss: 0.561207
# [300]	training's auc: 0.799216	training's binary_logloss: 0.536665	valid_1's auc: 0.769275	valid_1's binary_logloss: 0.556869
# [400]	training's auc: 0.809312	training's binary_logloss: 0.527527	valid_1's auc: 0.769763	valid_1's binary_logloss: 0.55582
# [500]	training's auc: 0.817092	training's binary_logloss: 0.520774	valid_1's auc: 0.770071	valid_1's binary_logloss: 0.555451
# [600]	training's auc: 0.8254	training's binary_logloss: 0.513812	valid_1's auc: 0.770221	valid_1's binary_logloss: 0.555334
# [700]	training's auc: 0.832851	training's binary_logloss: 0.507475	valid_1's auc: 0.770327	valid_1's binary_logloss: 0.555201
# [800]	training's auc: 0.840325	training's binary_logloss: 0.501089	valid_1's auc: 0.770009	valid_1's binary_logloss: 0.555464
# [900]	training's auc: 0.846836	training's binary_logloss: 0.495396	valid_1's auc: 0.770058	valid_1's binary_logloss: 0.555489
# [1000]	training's auc: 0.852674	training's binary_logloss: 0.490222	valid_1's auc: 0.769742	valid_1's binary_logloss: 0.555796
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.852674	training's binary_logloss: 0.490222	valid_1's auc: 0.769742	valid_1's binary_logloss: 0.555796
# Fold  4 AUC : 0.769742
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.782297	training's binary_logloss: 0.574616	valid_1's auc: 0.765919	valid_1's binary_logloss: 0.580685
# [200]	training's auc: 0.791508	training's binary_logloss: 0.548044	valid_1's auc: 0.767082	valid_1's binary_logloss: 0.561115
# [300]	training's auc: 0.80122	training's binary_logloss: 0.535904	valid_1's auc: 0.767223	valid_1's binary_logloss: 0.556917
# [400]	training's auc: 0.81205	training's binary_logloss: 0.525977	valid_1's auc: 0.767439	valid_1's binary_logloss: 0.555811
# [500]	training's auc: 0.82094	training's binary_logloss: 0.518243	valid_1's auc: 0.7679	valid_1's binary_logloss: 0.555216
# [600]	training's auc: 0.827863	training's binary_logloss: 0.512132	valid_1's auc: 0.767982	valid_1's binary_logloss: 0.554917
# [700]	training's auc: 0.834475	training's binary_logloss: 0.506291	valid_1's auc: 0.767498	valid_1's binary_logloss: 0.555217
# [800]	training's auc: 0.841036	training's binary_logloss: 0.500648	valid_1's auc: 0.767501	valid_1's binary_logloss: 0.555288
# Early stopping, best iteration is:
# [553]	training's auc: 0.824639	training's binary_logloss: 0.514924	valid_1's auc: 0.768108	valid_1's binary_logloss: 0.554972
# Fold  5 AUC : 0.768108
#
#
#
# ================================================
#
# 최종성능: 0.773446187979554
#
# ================================================

# %% [markdown]
# ### LGBM 변수소거 테스트

# %%
# 모든 변수 포함
ft, test_preds, y_test = validation_model(tr,base_column)
# Out:
# 추가변수 : ['married_value', 'wf_sum', 'Q_E_sum', 'wr_sum', 'age_group_value', 'education_ft2', 'education_ft1', 'wr_wf_sum', 'Q_E_median']
# 제외변수 : []
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0
# [400]	training's auc: 0.830221	training's binary_logloss: 0.523746	valid_1's auc: 0.767733	valid_1's binary_logloss: 0.559854
# [500]	training's auc: 0.8385	training's binary_logloss: 0.513062	valid_1's auc: 0.768026	valid_1's binary_logloss: 0.557193
# [600]	training's auc: 0.846313	training's binary_logloss: 0.504525	valid_1's auc: 0.768218	valid_1's binary_logloss: 0.556058
# [700]	training's auc: 0.852736	training's binary_logloss: 0.497765	valid_1's auc: 0.768165	valid_1's binary_logloss: 0.555612
# [800]	training's auc: 0.859395	training's binary_logloss: 0.491253	valid_1's auc: 0.768335	valid_1's binary_logloss: 0.555411
# [900]	training's auc: 0.865615	training's binary_logloss: 0.485313	valid_1's auc: 0.76813	valid_1's binary_logloss: 0.555383
# Early stopping, best iteration is:
# [625]	training's auc: 0.847787	training's binary_logloss: 0.502884	valid_1's auc: 0.768369	valid_1's binary_logloss: 0.555811
# Fold  5 AUC : 0.768369
#
#
#
# ================================================
#
# 최종성능: 0.7726395224259547
#
# ================================================

# %%
# 다중공선성 여부 체크 후 변수소거법
correlation_extract(tr,0.7)
# Out:
# QaA : ['QaA']
# QaE : ['QaE']
# QbA : ['QbA']
# QbE : ['QbE']
# QcA : ['QcA']
# QcE : ['QcE']
# QdA : ['QdA']
# QdE : ['QdE']
# QeA : ['QeA']
# QeE : ['QeE']
# QfA : ['QfA']
# QfE : ['QfE']
# QgA : ['QgA']
# QgE : ['QgE']
# QhA : ['QhA']
# QhE : ['QhE', 'Q_E_sum']
# QiA : ['QiA']
# QiE : ['QiE']
# QjA : ['QjA']
# QjE : ['QjE']
# QkA : ['QkA']
# QkE : ['QkE']
# QlA : ['QlA']
# QlE : ['QlE']
# QmA : ['QmA']
# QmE : ['QmE']
# QnA : ['QnA']
# QnE : ['QnE']
# QoA : ['QoA']
# QoE : ['QoE']
# QpA : ['QpA']
# QpE : ['QpE']
# QqA : ['QqA']
# QqE : ['QqE']
# QrA : ['QrA']
# QrE : ['QrE']
# QsA : ['QsA']
# QsE : ['QsE']
# QtA : ['QtA']
# QtE : ['QtE']
# age_group : ['age_group', 'age_group_value']
# education : ['education', 'education_ft2']
# engnat : ['engnat']
# familysize : ['familysize']
# gender : ['gender']
# hand : ['hand']
# married : ['married', 'married_value']
# race : ['race']
# religion : ['religion']
# tp01 : ['tp01']
# tp02 : ['tp02']
# tp03 : ['tp03']
# tp04 : ['tp04']
# tp05 : ['tp05']
# tp06 : ['tp06']
# tp07 : ['tp07']
# tp08 : ['tp08']
# tp09 : ['tp09']
# tp10 : ['tp10']
# urban : ['urban']
# voted : ['voted']
# wf_01 : ['wf_01']
# wf_02 : ['wf_02', 'wf_sum']
# wf_03 : ['wf_03', 'wf_sum']
# wr_01 : ['wr_01']
# wr_02 : ['wr_02']
# wr_03 : ['wr_03']
# wr_04 : ['wr_04']
# wr_05 : ['wr_05']
# wr_06 : ['wr_06']
# wr_07 : ['wr_07']
# wr_08 : ['wr_08']
# wr_09 : ['wr_09']
# wr_10 : ['wr_10']
# wr_11 : ['wr_11']
# wr_12 : ['wr_12']
# wr_13 : ['wr_13']
# Q_E_sum : ['QhE', 'Q_E_sum']
# Q_E_median : ['Q_E_median']
# education_ft1 : ['education_ft1']
# education_ft2 : ['education', 'education_ft2']
# married_value : ['married', 'married_value']
# age_group_value : ['age_group', 'age_group_value']
# wr_sum : ['wr_sum', 'wr_wf_sum']
# wf_sum : ['wf_02', 'wf_03', 'wf_sum']
# wr_wf_sum : ['wr_sum', 'wr_wf_sum']

# %%
# 모든 변수 포함
ft, test_preds, y_test = validation_model(
    tr.drop(
        columns = [
            'wf_03',
            'wf_02'
        ]
    ),
    base_column
)
# Out:
# 추가변수 : ['married_value', 'wf_sum', 'Q_E_sum', 'wr_sum', 'age_group_value', 'education_ft2', 'education_ft1', 'wr_wf_sum', 'Q_E_median']
# 제외변수 : ['wf_02', 'wf_03']
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.771392	training's binary_logloss: 0.593917	valid_1's auc: 0.765986	valid_1's binary_logloss: 0.595499
# [200]	training's auc: 0.776976	training's binary_logloss: 0.565693	valid_1's auc: 0.766751	valid_1's binary_logloss: 0.570465
# [300]	training's auc: 0.780656	training's binary_logloss: 0.554263	valid_1's auc: 0.767735	valid_1's binary_logloss: 0.561776
# [400]	training's auc: 0.785053	training's binary_logloss: 0.547902	valid_1's auc: 0.768867	valid_1's binary_logloss: 0.558391
# [500]	training's auc: 0.789991	training's binary_logloss: 0.543173	valid_1's auc: 0.769707	valid_1's binary_logloss: 0.556983
# [600]	training's auc: 0.795659	training's binary_logloss: 0.538669	valid_1's auc: 0.770001	valid_1's binary_logloss: 0.556397
# [700]	training's auc: 0.800796	training's binary_logloss: 0.534597	valid_1's auc: 0.770089	valid_1's binary_logloss: 0.556066
# [800]	training's auc: 0.805401	training's binary_logloss: 0.530883	valid_1's auc: 0.770067	valid_1's binary_logloss: 0.555957
# [900]	training's auc: 0.809572	training's binary_logloss: 0.527488	valid_1's auc: 0.770067	valid_1's binary_logloss: 0.555907
# [1000]	training's auc: 0.81355	training's binary_logloss: 0.524302	valid_1's auc: 0.770129	valid_1's binary_logloss: 0.55589
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.81355	training's binary_logloss: 0.524302	valid_1's auc: 0.770129	valid_1's binary_logloss: 0.55589
# Fold  1 AUC : 0.770129
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.773212	training's binary_logloss: 0.59331	valid_1's auc: 0.760419	valid_1's binary_logloss: 0.597526
# [200]	training's auc: 0.77796	training's binary_logloss: 0.564885	valid_1's auc: 0.760927	valid_1's binary_logloss: 0.573066
# [300]	training's auc: 0.781496	training's binary_logloss: 0.553362	valid_1's auc: 0.761642	valid_1's binary_logloss: 0.565081
# [400]	training's auc: 0.786094	training's binary_logloss: 0.546766	valid_1's auc: 0.76227	valid_1's binary_logloss: 0.562179
# [500]	training's auc: 0.791065	training's binary_logloss: 0.54189	valid_1's auc: 0.76264	valid_1's binary_logloss: 0.561081
# [600]	training's auc: 0.796064	training's binary_logloss: 0.537649	valid_1's auc: 0.762998	valid_1's binary_logloss: 0.560601
# [700]	training's auc: 0.800583	training's binary_logloss: 0.53392	valid_1's auc: 0.763131	valid_1's binary_logloss: 0.560271
# [800]	training's auc: 0.804745	training's binary_logloss: 0.530436	valid_1's auc: 0.763161	valid_1's binary_logloss: 0.560132
# [900]	training's auc: 0.80886	training's binary_logloss: 0.527052	valid_1's auc: 0.76298	valid_1's binary_logloss: 0.560157
# [1000]	training's auc: 0.813139	training's binary_logloss: 0.52364	valid_1's auc: 0.762625	valid_1's binary_logloss: 0.560373
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.810734	training's binary_logloss: 0.525228	valid_1's auc: 0.769423	valid_1's binary_logloss: 0.55665
# Fold  4 AUC : 0.769423
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.770958	training's binary_logloss: 0.594155	valid_1's auc: 0.764401	valid_1's binary_logloss: 0.596042
# [200]	training's auc: 0.775862	training's binary_logloss: 0.566105	valid_1's auc: 0.766047	valid_1's binary_logloss: 0.570325
# [300]	training's auc: 0.779537	training's binary_logloss: 0.554821	valid_1's auc: 0.767229	valid_1's binary_logloss: 0.561179
# [400]	training's auc: 0.783982	training's binary_logloss: 0.548488	valid_1's auc: 0.768203	valid_1's binary_logloss: 0.557676
# [500]	training's auc: 0.789315	training's binary_logloss: 0.543388	valid_1's auc: 0.768416	valid_1's binary_logloss: 0.55637
# [600]	training's auc: 0.794624	training's binary_logloss: 0.539069	valid_1's auc: 0.768579	valid_1's binary_logloss: 0.555838
# [700]	training's auc: 0.799438	training's binary_logloss: 0.53518	valid_1's auc: 0.768583	valid_1's binary_logloss: 0.555551
# [800]	training's auc: 0.803896	training's binary_logloss: 0.531578	valid_1's auc: 0.768586	valid_1's binary_logloss: 0.555275
# [900]	training's auc: 0.807819	training's binary_logloss: 0.528376	valid_1's auc: 0.76848	valid_1's binary_logloss: 0.555199
# [1000]	training's auc: 0.811481	training's binary_logloss: 0.525405	valid_1's auc: 0.768362	valid_1's binary_logloss: 0.555155
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.811481	training's binary_logloss: 0.525405	valid_1's auc: 0.768362	valid_1's binary_logloss: 0.555155
# Fold  5 AUC : 0.768362
#
#
#
# ================================================
#
# 최종성능: 0.7732838034582648
#
# ================================================

# %%
# 모든 변수 포함
ft, test_preds, y_test = validation_model(tr,base_column)
# Out:
# 추가변수 : ['QfE_log', 'QnE_log', 'QmE_log', 'QhE_log', 'age_group_value', 'QlE_log', 'QrE_log', 'QeE_log', 'QqE_log', 'QcE_log', 'QgE_log', 'QaE_log', 'QtE_log', 'QdE_log', 'education_ft2', 'education_ft1', 'QkE_log', 'QiE_log', 'QoE_log', 'QpE_log', 'wr_wf_sum', 'QsE_log', 'Q_E_median', 'QbE_log', 'married_value', 'QjE_log', 'Q_E_sum', 'wr_sum', 'wf_sum']
# 제외변수 : ['QkE', 'QqE', 'QnE', 'QoE', 'QeE', 'QbE', 'QdE', 'QjE', 'QsE', 'QcE', 'QtE', 'QhE', 'QmE', 'QiE', 'QaE', 'QlE', 'QrE', 'QpE', 'QfE', 'QgE']
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.775749	training's binary_logloss: 0.617607	valid_1's auc: 0.763601	valid_1's binary_logloss: 0.619773
# [200]	training's auc: 0.780763	training's binary_logloss: 0.583583	valid_1's auc: 0.765367	valid_1's binary_logloss: 0.588714
# [300]	training's auc: 0.785497	training's binary_logloss: 0.565151	valid_1's auc: 0.765917	valid_1's binary_logloss: 0.57367
# [400]	training's auc: 0.788802	training's binary_logloss: 0.55462	valid_1's auc: 0.766745	valid_1's binary_logloss: 0.565994
# [500]	training's auc: 0.792017	training's binary_logloss: 0.547781	valid_1's auc: 0.768111	valid_1's binary_logloss: 0.561589
# [600]	training's auc: 0.795436	training's binary_logloss: 0.542779	valid_1's auc: 0.769082	valid_1's binary_logloss: 0.559169
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.812586	training's binary_logloss: 0.525774	valid_1's auc: 0.760866	valid_1's binary_logloss: 0.560984
# Fold  3 AUC : 0.760866
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.775013	training's binary_logloss: 0.617478	valid_1's auc: 0.762375	valid_1's binary_logloss: 0.619523
# [200]	training's auc: 0.779306	training's binary_logloss: 0.583717	valid_1's auc: 0.763498	valid_1's binary_logloss: 0.588523
# [300]	training's auc: 0.783717	training's binary_logloss: 0.565517	valid_1's auc: 0.764226	valid_1's binary_logloss: 0.573498
# [400]	training's auc: 0.786495	training's binary_logloss: 0.555121	valid_1's auc: 0.7652	valid_1's binary_logloss: 0.56584
# [500]	training's auc: 0.789767	training's binary_logloss: 0.548038	valid_1's auc: 0.76621	valid_1's binary_logloss: 0.56158
# [600]	training's auc: 0.793041	training's binary_logloss: 0.543043	valid_1's auc: 0.766712	valid_1's binary_logloss: 0.559476
# [700]	training's auc: 0.796843	training's binary_logloss: 0.538934	valid_1's auc: 0.767077	valid_1's binary_logloss: 0.558398
# [800]	training's auc: 0.800828	training's binary_logloss: 0.535076	valid_1's auc: 0.767216	valid_1's binary_logloss: 0.5578
# [900]	training's auc: 0.805413	training's binary_logloss: 0.5312	valid_1's auc: 0.76768	valid_1's binary_logloss: 0.557399
# [1000]	training's auc: 0.809438	training's binary_logloss: 0.527848	valid_1's auc: 0.768047	valid_1's binary_logloss: 0.557181
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.809438	training's binary_logloss: 0.527848	valid_1's auc: 0.768047	valid_1's binary_logloss: 0.557181
# Fold  4 AUC : 0.768047
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.776267	training's binary_logloss: 0.61759	valid_1's auc: 0.763085	valid_1's binary_logloss: 0.62007
# [200]	training's auc: 0.780378	training's binary_logloss: 0.583819	valid_1's auc: 0.76443	valid_1's binary_logloss: 0.588804
# [300]	training's auc: 0.784108	training's binary_logloss: 0.565835	valid_1's auc: 0.76537	valid_1's binary_logloss: 0.573415
# [400]	training's auc: 0.78744	training's binary_logloss: 0.555201	valid_1's auc: 0.766504	valid_1's binary_logloss: 0.565178
# [500]	training's auc: 0.790677	training's binary_logloss: 0.548247	valid_1's auc: 0.76713	valid_1's binary_logloss: 0.560834
# [600]	training's auc: 0.794472	training's binary_logloss: 0.5429	valid_1's auc: 0.767415	valid_1's binary_logloss: 0.558511
# [700]	training's auc: 0.798352	training's binary_logloss: 0.538601	valid_1's auc: 0.767427	valid_1's binary_logloss: 0.557263
# [800]	training's auc: 0.802862	training's binary_logloss: 0.534359	valid_1's auc: 0.767361	valid_1's binary_logloss: 0.556653
# [900]	training's auc: 0.807686	training's binary_logloss: 0.530282	valid_1's auc: 0.767534	valid_1's binary_logloss: 0.556266
# [1000]	training's auc: 0.812093	training's binary_logloss: 0.526686	valid_1's auc: 0.767573	valid_1's binary_logloss: 0.556137
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.812093	training's binary_logloss: 0.526686	valid_1's auc: 0.767573	valid_1's binary_logloss: 0.556137
# Fold  5 AUC : 0.767573
#
#
#
# ================================================
#
# 최종성능: 0.7728754083342784
#
# ================================================

# %% [markdown]
# #### LGBM CV

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
X_train, X_test, y_train, y_test = train_test_split(
                                tr2,tr['voted'],
                                random_state = 0,
                                test_size = 0.2
                            )

# X_train, X_test, y_train, y_test = train_test_split(
#                                 tr2.drop(columns = 'voted'),tr['voted'],
#                                 random_state = 0,
#                                 test_size = 0.2
#                             )

clf = lgb.LGBMClassifier(n_estimators=1000,
            objective='binary',
            boosting_type='gbdt',
            bagging_fraction = 0.9515683153667026,
            #colsample_bytree = 0.7860120233288207,
            feature_fraction = 0.9362075859090412,
            lambda_l1 = 0.7111030183072032,
            lambda_l2 = 0.5642765168754059,
            learning_rate = 0.011407920284082697,
            max_depth = 6,
            #min_child_weight = 33,
            #num_leaves = 380,
            random_state= 200,
    
    )

param_test ={'num_leaves': [360.380,400], 
             'min_child_weight': [32,33,34],
             'colsample_bytree': [0.75, 0.78, 0.80],}

clf.fit(
            train_x, train_y,
            eval_set = [(train_x, train_y), (valid_x, valid_y)], 
            eval_metric='auc', 
            verbose= 100, 
            early_stopping_rounds=300,
        )

fit_params={"early_stopping_rounds":300, 
            "eval_metric" : 'auc', 
            "eval_set" : [(X_test,y_test)],
            'eval_names': ['valid'],
            #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
            'verbose': 100,
            'categorical_feature': 'auto'}


n_HP_points_to_test = 100

gs = RandomizedSearchCV(
    estimator=clf, param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='roc_auc',
    cv=5,
    refit=True,
    random_state=200,
    verbose=True)

# %% [markdown]
# ### XGB training

# %%
def validation_model_xgb(df,base_column):
    plus_col = list(set(df.columns.tolist()) - set(base_column))
    except_col = list(set(base_column) - set(df.columns.tolist()))
    print(f'추가변수 : {plus_col}')
    print(f'제외변수 : {except_col}')
    
    X_train, X_test, y_train, y_test = train_test_split(
                                df.drop(columns = 'voted'),df['voted'],
                                random_state = 0,
                                test_size = 0.2
                            )

    folds = StratifiedKFold(n_splits=5, shuffle = True)
    oof_preds = np.zeros(X_train.shape[0])
    test_preds = np.zeros(X_test.shape[0])
    feature_importance = pd.DataFrame()


    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_train,y_train)):

        train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
        valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]

        clf = xgb.XGBClassifier(
            n_estimators=1000,
            objective='binary:logistic',
            booster='gbtree',
            colsample_bytree = 0.7860120233288207,
            learning_rate = 0.011407920284082697,
            max_depth = 7,
            min_child_weight = 33,
            random_state= 200,
        )
    # n_estimators = 1000,base_score=0.5, booster='gbtree', colsample_bylevel=1,
    #               colsample_bynode=1, colsample_bytree=0.7, gamma=0.5, gpu_id=-1,
    #               importance_type='gain', interaction_constraints='',
    #               learning_rate=0.7, max_delta_step=0, max_depth=5,
    #               min_child_weight=0.4, monotone_constraints='()', n_jobs=0,
    #               num_parallel_tree=1, objective='binary:logistic', random_state=0,
    #               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.9,
    #               tree_method='exact', validate_parameters=1, verbosity=None
        clf.fit(
            train_x, 
            train_y, 
            eval_set = [(train_x, train_y), (valid_x, valid_y)], 
            eval_metric='auc',
            verbose= 100, 
            early_stopping_rounds=300
        )

        oof_preds[valid_idx] = clf.predict_proba(valid_x)[:,1]
        test_preds += clf.predict_proba(X_test)[:,1] / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = X_train.columns
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance = pd.concat([feature_importance, fold_importance_df], axis=0)

        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))

    ft = feature_importance.groupby('feature')['importance'].mean().reset_index()

    ft2 = ft.sort_values('importance',ascending = False).iloc[:50]

    feature_graph_df = feature_importance.sort_values('importance')
    plt.figure(figsize = (16,12))
    plt.barh(ft2['feature'],ft2['importance'])

    final_score = roc_auc_score(y_test,test_preds)
    print('\n\n')
    print('================================================')
    print(f'\n최종성능: {final_score}\n')
    print('================================================')
    return ft, test_preds, y_test

# %%
ft, test_preds, y_test = validation_model_xgb(tr,base_column)
# Out:
# 추가변수 : ['QrE_log', 'QeE_log', 'QmE_log', 'QiE_log', 'QkE_log', 'education_ft1', 'Q_E_sum', 'QgE_log', 'QlE_log', 'QnE_log', 'QjE_log', 'education_ft2', 'wr_wf_mul', 'QdE_log', 'wr_wf_diff', 'wr_wf_sum', 'tp_mean', 'QhE_log', 'married_value', 'QsE_log', 'wf_wf_sum', 'Mach_score', 'QqE_log', 'Q_E_median', 'age_group_value', 'wr_wr_sum', 'wr_sum', 'QcE_log', 'QfE_log', 'QpE_log', 'QaE_log', 'QtE_log', 'tp_median', 'QoE_log', 'wf_sum', 'QbE_log']
# 제외변수 : ['QqE', 'QnE', 'QcE', 'QrE', 'QkE', 'QaE', 'QgE', 'QpE', 'QhE', 'QdE', 'QsE', 'QtE', 'QoE', 'QiE', 'QmE', 'QfE', 'QjE', 'QeE', 'QbE', 'QlE']
# [0]	validation_0-auc:0.76836	validation_1-auc:0.75465
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.79517	validation_1-auc:0.76600
# [200]	validation_0-auc:0.80601	validation_1-auc:0.76831
# [300]	validation_0-auc:0.81650	validation_1-auc:0.76967
# [400]	validation_0-auc:0.82798	validation_1-auc:0.77041
# [500]	validation_0-auc:0.83902	validation_1-auc:0.77030
# [600]	validation_0-auc:0.84749	validation_1-auc:0.77044
# [700]	validation_0-auc:0.85514	validation_1-auc:0.77038
# [800]	validation_0-auc:0.86195	validation_1-auc:0.77004
# Stopping. Best iteration:
# [566]	validation_0-auc:0.84507	validation_1-auc:0.77061
#
# Fold  1 AUC : 0.770608
# [0]	validation_0-auc:0.77112	validation_1-auc:0.75686
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.79550	validation_1-auc:0.76475
# [200]	validation_0-auc:0.80690	validation_1-auc:0.76723
# [300]	validation_0-auc:0.81690	validation_1-auc:0.76811
# [400]	validation_0-auc:0.82498	validation_1-auc:0.76854
# [500]	validation_0-auc:0.83248	validation_1-auc:0.76888
# [600]	validation_0-auc:0.83983	validation_1-auc:0.76851
# [700]	validation_0-auc:0.84689	validation_1-auc:0.76801
# [800]	validation_0-auc:0.85371	validation_1-auc:0.76778
# Stopping. Best iteration:
# [510]	validation_0-auc:0.83319	validation_1-auc:0.76891
#
# Fold  2 AUC : 0.768914
# [0]	validation_0-auc:0.77178	validation_1-auc:0.75737
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.79782	validation_1-auc:0.76620
# [200]	validation_0-auc:0.80843	validation_1-auc:0.76699
# [300]	validation_0-auc:0.81811	validation_1-auc:0.76788
# [400]	validation_0-auc:0.82760	validation_1-auc:0.76803
# [500]	validation_0-auc:0.83671	validation_1-auc:0.76785
# [600]	validation_0-auc:0.84552	validation_1-auc:0.76748
# [700]	validation_0-auc:0.85302	validation_1-auc:0.76701
# Stopping. Best iteration:
# [451]	validation_0-auc:0.83236	validation_1-auc:0.76811
#
# Fold  3 AUC : 0.768113
# [0]	validation_0-auc:0.77006	validation_1-auc:0.74925
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.79668	validation_1-auc:0.76054
# [200]	validation_0-auc:0.80722	validation_1-auc:0.76173
# [300]	validation_0-auc:0.81701	validation_1-auc:0.76254
# [400]	validation_0-auc:0.82745	validation_1-auc:0.76292
# [500]	validation_0-auc:0.83692	validation_1-auc:0.76266
# [600]	validation_0-auc:0.84470	validation_1-auc:0.76203
# [700]	validation_0-auc:0.85242	validation_1-auc:0.76134
# Stopping. Best iteration:
# [441]	validation_0-auc:0.83183	validation_1-auc:0.76299
#
# Fold  4 AUC : 0.762994
# [0]	validation_0-auc:0.76831	validation_1-auc:0.75236
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.79713	validation_1-auc:0.76641
# [200]	validation_0-auc:0.80765	validation_1-auc:0.76858
# [300]	validation_0-auc:0.81652	validation_1-auc:0.76954
# [400]	validation_0-auc:0.82755	validation_1-auc:0.77051
# [500]	validation_0-auc:0.83639	validation_1-auc:0.77047
# [600]	validation_0-auc:0.84435	validation_1-auc:0.77043
# Stopping. Best iteration:
# [397]	validation_0-auc:0.82721	validation_1-auc:0.77060
#
# Fold  5 AUC : 0.770598
#
#
#
# ================================================
#
# 최종성능: 0.7726163037758782
#
# ================================================

# %% [markdown]
# ### Catboost training

# %%
X_train, X_test, y_train, y_test = train_test_split(
    tr.drop(columns = 'voted'),
    tr['voted'],
    random_state = 0,
    test_size = 0.2
)

  
folds = StratifiedKFold(n_splits=5, shuffle = True, random_state=111)
oof_preds = np.zeros(X_train.shape[0])
test_preds = np.zeros(X_test.shape[0])
feature_importance = pd.DataFrame()

for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_train,y_train)):
    train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
    valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]
    
    clf = cb.CatBoostClassifier(
        n_estimators=1000,
        eval_metric = 'AUC',
    )
    
    
    clf.fit(
        train_x,
        train_y, 
        eval_set = [(train_x, train_y), (valid_x, valid_y)],
        early_stopping_rounds=300,
        verbose= 100
    )
    
    oof_preds[valid_idx] = clf.predict_proba(valid_x)[:,1]
    test_preds += clf.predict_proba(X_test)[:,1] / folds.n_splits
    
    print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
    
print('최종 성능', roc_auc_score(y_test, test_preds))

# %% [markdown]
# ### Extra Tree training

# %% [markdown]
# ### RF training

# %% [markdown]
# ## Bayesian Optimization

# %%
# X = tr.drop(columns = 'voted')
X = tr.drop(columns = ['voted'])
y = tr['voted']

# X_cb = X.fillna(0)
# X_cb = X_cb.replace(np.inf,0)

# %%
#목적함수 생성
def lgbm_cv(learning_rate, num_leaves, max_depth, min_child_weight, colsample_bytree, feature_fraction, bagging_fraction, lambda_l1, lambda_l2):
    model = lgb.LGBMClassifier(learning_rate=learning_rate,
                                n_estimators = 1000,
                                #boosting = 'dart',
                                num_leaves = int(round(num_leaves)),
                                max_depth = int(round(max_depth)),
                                min_child_weight = int(round(min_child_weight)),
                                colsample_bytree = colsample_bytree,
                                feature_fraction = max(min(feature_fraction, 1), 0),
                                bagging_fraction = max(min(bagging_fraction, 1), 0),
                                lambda_l1 = max(lambda_l1, 0),
                                lambda_l2 = max(lambda_l2, 0)
                               )
    scoring = {'roc_auc_score': make_scorer(roc_auc_score)}
    result = cross_validate(model, X, y, cv=5, scoring=scoring)
    auc_score = result["test_roc_auc_score"].mean()
    return auc_score

# n_estimators=1000,
# objective='binary:logistic',
# booster='gbtree', # gbtree
# colsample_bytree = 0.7860120233288207,
# learning_rate = 0.011407920284082697,#0.011->0.010
# max_depth = 7,
# min_child_weight = 33,
# random_state= 200,
def xgb_cv(learning_rate, gamma, max_depth, min_child_weight, colsample_bytree):
    model = xgb.XGBClassifier(learning_rate=learning_rate,
                                n_estimators = 1000,
                                gamma = gamma,
                                max_depth = int(round(max_depth)),
                                min_child_weight = int(round(min_child_weight)),
                                colsample_bytree = colsample_bytree,
                               )
    scoring = {'roc_auc_score': make_scorer(roc_auc_score)}
    result = cross_validate(model, X, y, cv=5, scoring=scoring)
    auc_score = result["test_roc_auc_score"].mean()
    return auc_score


def cb_cv(learning_rate, num_leaves ,max_depth, min_child_samples, colsample_bylevel):
    model = cb.CatBoostClassifier(learning_rate=learning_rate,
                                n_estimators = 1000,
                                num_leaves = int(round(num_leaves)),
                                max_depth = int(round(max_depth)),
                                min_child_samples = int(round(min_child_samples)),
                                colsample_bylevel = colsample_bylevel,
                               )
    scoring = {'roc_auc_score': make_scorer(roc_auc_score)}
    result = cross_validate(model, X, y, cv=5, scoring=scoring)
    auc_score = result["test_roc_auc_score"].mean()
    return auc_score

# %%
pbounds_cb = {'learning_rate' : (0.0001, 0.05),
            'num_leaves': (300, 600),
           'max_depth': (2, 25),
           'min_child_samples': (30, 100),
           'colsample_bylevel': (0, 0.99),
          }

pbounds_xgb = {'learning_rate' : (0.0001, 0.05),
           'gamma': (0, 10),
           'max_depth': (2, 25),
           'min_child_weight': (30, 100),
           'colsample_bytree': (0, 0.99),
          }

pbounds = {'learning_rate' : (0.0001, 0.05),
           'num_leaves': (300, 600),
           'max_depth': (2, 25),
           'min_child_weight': (30, 100),
           'colsample_bytree': (0, 0.99),
           'feature_fraction': (0.0001, 0.99),
           'bagging_fraction': (0.0001, 0.99),
           'lambda_l1' : (0, 0.99),
           'lambda_l2' : (0, 0.99),
          }

# %%
lgbmBO = BayesianOptimization(f = lgbm_cv, pbounds = pbounds, verbose = 2, random_state = 0 )

# %%
xgbBO = BayesianOptimization(f = xgb_cv, pbounds = pbounds_xgb, verbose = 2, random_state = 0 )

# %%
cbBO = BayesianOptimization(f = cb_cv, pbounds = pbounds_cb, verbose = 2, random_state = 0 )

# %%
cbBO.maximize(init_points=5, n_iter = 20, acq='ei', xi=0.01)

# %%
xgbBO.maximize(init_points=5, n_iter = 20, acq='ei', xi=0.01)
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | min_ch
# |  17       |  0.6841   |  0.05669  |  0.9018   |  0.7393   |  0.4519   |  0.8196   |  0.0469   |  15.76    |  54.98    |  508.0    |
# |  18       |  0.6937   |  0.646    |  0.3415   |  0.5186   |  0.08037  |  0.4337   |  0.02185  |  13.52    |  44.03    |  382.5    |
# |  19       |  0.6946   |  0.9195   |  0.6467   |  0.4626   |  0.06357  |  0.595    |  0.02307  |  20.92    |  79.71    |  453.0    |
# |  20       |  0.6813   |  0.3937   |  0.9228   |  0.02225  |  0.6842   |  0.1174   |  0.02792  |  17.83    |  31.47    |  528.3    |
# |  21       |  0.698    |  0.3144   |  0.486    |  0.3948   |  0.4732   |  0.9648   |  0.01579  |  20.93    |  97.33    |  373.8    |
# |  22       |  0.696    |  0.9866   |  0.4931   |  0.9554   |  0.8454   |  0.07576  |  0.01507  |  17.74    |  86.91    |  491.8    |
# |  23       |  0.6943   |  0.932    |  0.2864   |  0.7305   |  0.1885   |  0.7453   |  0.01795  |  24.03    |  66.26    |  313.6    |
# |  24       |  0.6857   |  0.6581   |  0.08613  |  0.8457   |  0.4733   |  0.4413   |  0.04411  |  13.63    |  84.18    |  579.3    |
# |  25       |  0.6868   |  0.5831   |  0.4398   |  0.4935   |  0.00504  |  0.5805   |  0.04326  |  18.81    |  71.98    |  371.4    |
# =====================================================================================================================================

# %%
lgbmBO.max
# Out:
# {'target': 0.7031378886953144,
#  'params': {'bagging_fraction': 0.9669958011996147,
#   'colsample_bytree': 0.5987970645475955,
#   'feature_fraction': 0.7318970172463788,
#   'lambda_l1': 0.03879591433177747,
#   'lambda_l2': 0.2799788929506455,
#   'learning_rate': 0.006097808404537128,
#   'max_depth': 8.811224543009335,
#   'min_child_weight': 38.31094032679708,
#   'num_leaves': 395.3949538181928}}

# %%
# 2
lgbmBO.max
# Out:
# {'target': 0.7053094546762602,
#  'params': {'bagging_fraction': 0.3698062073338938,
#   'colsample_bytree': 0.07489713711905326,
#   'feature_fraction': 0.8218055447768081,
#   'lambda_l1': 0.7222964907915178,
#   'lambda_l2': 0.8414555963714396,
#   'learning_rate': 0.0030925251152918113,
#   'max_depth': 7.166751819088359,
#   'min_child_weight': 37.3468883586423,
#   'num_leaves': 542.2916917720623}}

# %%
# 3 - 더미변수
lgbmBO.max
# Out:
# {'target': 0.7025369236368474,
#  'params': {'bagging_fraction': 0.8318398041402879,
#   'colsample_bytree': 0.9081129401551936,
#   'feature_fraction': 0.908742798170918,
#   'lambda_l1': 0.3738458812042474,
#   'lambda_l2': 0.0990665885840748,
#   'learning_rate': 0.0018249414148301688,
#   'max_depth': 4.829439057019151,
#   'min_child_weight': 36.749144761728466,
#   'num_leaves': 561.9676780635398}}

# %%
# 4 변수소거 (1)
lgbmBO.max
# Out:
# {'target': 0.7026733374527643,
#  'params': {'bagging_fraction': 0.5174586752499394,
#   'colsample_bytree': 0.16336591285805346,
#   'feature_fraction': 0.6600295087430476,
#   'lambda_l1': 0.5045786221433113,
#   'lambda_l2': 0.34677843618253623,
#   'learning_rate': 0.008679434863557151,
#   'max_depth': 5.05906487896959,
#   'min_child_weight': 35.46747545288431,
#   'num_leaves': 532.5547433920851}}

# %%
# 5 변수 로그화
lgbmBO.max
# Out:
# {'target': 0.7032728195590217,
#  'params': {'bagging_fraction': 0.9669958011996147,
#   'colsample_bytree': 0.5987970645475955,
#   'feature_fraction': 0.7318970172463788,
#   'lambda_l1': 0.03879591433177747,
#   'lambda_l2': 0.2799788929506455,
#   'learning_rate': 0.006097808404537128,
#   'max_depth': 8.811224543009335,
#   'min_child_weight': 38.31094032679708,
#   'num_leaves': 395.3949538181928}}

# %%
# 5 변수 로그화
lgbmBO.max
# Out:
# {'target': 0.7047802149916288,
#  'params': {'bagging_fraction': 0.16026521886490075,
#   'colsample_bytree': 0.38230762664460116,
#   'feature_fraction': 0.8803127292536881,
#   'lambda_l1': 0.6427909607958205,
#   'lambda_l2': 0.8516225399539507,
#   'learning_rate': 0.004810297234567945,
#   'max_depth': 6.072081164468878,
#   'min_child_weight': 30.470923513342353,
#   'num_leaves': 570.2124396849822}}

# %%
xgbBO.max
# Out:
# {'target': 0.702825789561774,
#  'params': {'colsample_bytree': 0.6462430788077107,
#   'gamma': 1.715971732762962,
#   'learning_rate': 0.005504669803513776,
#   'max_depth': 13.323358026565089,
#   'min_child_weight': 67.7850859645155}}

# %% [markdown]
# # Testset inference

# %% [markdown]
# ## catboost inference

# %%
X_train = tr.drop(columns = 'voted')
y_train = tr['voted']
folds = StratifiedKFold(n_splits=5, shuffle = True, random_state=111)
oof_preds = np.zeros(X_train.shape[0])
test_preds = np.zeros(te.shape[0])
feature_importance = pd.DataFrame()

for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_train,y_train)):
    train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
    valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]
    
    clf = cb.CatBoostClassifier(
        n_estimators=1000,
        eval_metric = 'AUC',
    )
    
    
    clf.fit(
        train_x,
        train_y, 
        eval_set = [(train_x, train_y), (valid_x, valid_y)],
        early_stopping_rounds=300,
        verbose= 100
    )
    
    oof_preds[valid_idx] = clf.predict_proba(valid_x)[:,1]
    test_preds += clf.predict_proba(te)[:,1] / folds.n_splits
    
    print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
    
print('최종 성능', roc_auc_score(y_test, test_preds))
# Out:
# Learning rate set to 0.077015
# 0:	test: 0.7502038	test1: 0.7366552	best: 0.7366552 (0)	total: 30.3ms	remaining: 30.3s
# 100:	test: 0.7903615	test1: 0.7564418	best: 0.7564871 (97)	total: 1.96s	remaining: 17.5s
# 200:	test: 0.8168043	test1: 0.7576411	best: 0.7580132 (158)	total: 3.74s	remaining: 14.9s
# 300:	test: 0.8419727	test1: 0.7569670	best: 0.7580132 (158)	total: 5.62s	remaining: 13.1s
# 400:	test: 0.8627617	test1: 0.7563326	best: 0.7580132 (158)	total: 7.4s	remaining: 11s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7580132013
# bestIteration = 158
#
# Shrink model to first 159 iterations.
# Fold  1 AUC : 0.758013
# Learning rate set to 0.077015
# 0:	test: 0.7477769	test1: 0.7470823	best: 0.7470823 (0)	total: 21.5ms	remaining: 21.5s
# 100:	test: 0.7887120	test1: 0.7667216	best: 0.7667597 (98)	total: 1.83s	remaining: 16.3s
# 200:	test: 0.8154533	test1: 0.7673800	best: 0.7678533 (161)	total: 3.75s	remaining: 14.9s
# 300:	test: 0.8412911	test1: 0.7648169	best: 0.7678533 (161)	total: 5.52s	remaining: 12.8s
# 400:	test: 0.8629698	test1: 0.7642251	best: 0.7678533 (161)	total: 7.37s	remaining: 11s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7678532886
# bestIteration = 161
#
# Shrink model to first 162 iterations.
# Fold  2 AUC : 0.767853
# Learning rate set to 0.077015
# 0:	test: 0.7474628	test1: 0.7476530	best: 0.7476530 (0)	total: 24.8ms	remaining: 24.8s
# 100:	test: 0.7888605	test1: 0.7691458	best: 0.7691458 (100)	total: 2.42s	remaining: 21.5s
# 200:	test: 0.8161786	test1: 0.7702068	best: 0.7707990 (166)	total: 4.63s	remaining: 18.4s
# 300:	test: 0.8424076	test1: 0.7693315	best: 0.7707990 (166)	total: 6.55s	remaining: 15.2s
# 400:	test: 0.8631223	test1: 0.7692346	best: 0.7707990 (166)	total: 8.63s	remaining: 12.9s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7707990469
# bestIteration = 166
#
# Shrink model to first 167 iterations.
# Fold  3 AUC : 0.770799
# Learning rate set to 0.077015
# 0:	test: 0.7416119	test1: 0.7429506	best: 0.7429506 (0)	total: 27.2ms	remaining: 27.1s
# 100:	test: 0.7887295	test1: 0.7690464	best: 0.7690566 (99)	total: 1.98s	remaining: 17.6s
# 200:	test: 0.8159352	test1: 0.7684712	best: 0.7701192 (142)	total: 3.86s	remaining: 15.3s
# 300:	test: 0.8412749	test1: 0.7676860	best: 0.7701192 (142)	total: 5.71s	remaining: 13.3s
# 400:	test: 0.8630916	test1: 0.7675893	best: 0.7701192 (142)	total: 7.58s	remaining: 11.3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.7701191625
# bestIteration = 142
#
# Shrink model to first 143 iterations.
# Fold  4 AUC : 0.770119
# Learning rate set to 0.077015
# 0:	test: 0.7423116	test1: 0.7489457	best: 0.7489457 (0)	total: 17.6ms	remaining: 17.6s
# 100:	test: 0.7880060	test1: 0.7733471	best: 0.7733471 (100)	total: 1.96s	remaining: 17.4s
# 200:	test: 0.8155352	test1: 0.7743979	best: 0.7744009 (198)	total: 3.99s	remaining: 15.9s
# 300:	test: 0.8411880	test1: 0.7729739	best: 0.7744009 (198)	total: 5.88s	remaining: 13.7s
# 400:	test: 0.8624966	test1: 0.7708916	best: 0.7744009 (198)	total: 8.22s	remaining: 12.3s
# Stopped by overfitting detector  (300 iterations wait)
#
# bestTest = 0.774400921
# bestIteration = 198
#
# Shrink model to first 199 iterations.
# Fold  5 AUC : 0.774401
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-256-e2a6287d1d0c> in <module>
#      29     print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
#      30
# ---> 31 print('최종 성능', roc_auc_score(y_test, test_preds))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     391                                              max_fpr=max_fpr),
#     392                                      y_true, y_score, average,
# --> 393                                      sample_weight=sample_weight)
#     394     else:  # multilabel-indicator
#     395         return _average_binary_score(partial(_binary_roc_auc_score,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     225
#     226     fpr, tpr, _ = roc_curve(y_true, y_score,
# --> 227                             sample_weight=sample_weight)
#     228     if max_fpr is None or max_fpr == 1:
#     229         return auc(fpr, tpr)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     774     """
#     775     fps, tps, thresholds = _binary_clf_curve(
# --> 776         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     777
#     778     # Attempt to drop thresholds corresponding to points in between and
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     539         raise ValueError("{0} format is not supported".format(y_type))
#     540
# --> 541     check_consistent_length(y_true, y_score, sample_weight)
#     542     y_true = column_or_1d(y_true)
#     543     y_score = column_or_1d(y_score)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     255     if len(uniques) > 1:
#     256         raise ValueError("Found input variables with inconsistent numbers of"
# --> 257                          " samples: %r" % [int(l) for l in lengths])
#     258
#     259
#
# ValueError: Found input variables with inconsistent numbers of samples: [9107, 11383]

# %% [markdown]
# ## inference code

# %%
def test_inference(tr, te, model_category):
    
    if model_category == 'lgb':
        X_train = tr.drop(columns = 'voted')
        y_train = tr['voted']

        folds = StratifiedKFold(n_splits=5, shuffle = True)
        test_preds = np.zeros(te.shape[0])
        oof_preds = np.zeros(X_train.shape[0])
        feature_importance = pd.DataFrame()
        
        oof_score = []
        valid_score = []
        
        for n_folds, (train_idx, valid_idx) in enumerate(folds.split(X_train, y_train)):
            train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
            valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]

# 베이지안 최적화 1
#  bagging_fraction = 0.9669958011996147,
#                 colsample_bytree = 0.5987970645475955, # 0.78
#                 feature_fraction = 0.7318970172463788,
#                 lambda_l1 = 0.03879591433177747,
#                 lambda_l2 = 0.2799788929506455,
#                 learning_rate = 0.006097808404537128, # 0.011
#                 max_depth = 9,
#                 min_child_weight = 38,
#                 num_leaves = 395,
#                 random_state= 200,

# 베이지안 최적화 2
# {'bagging_fraction': 0.3698062073338938,
#   'colsample_bytree': 0.07489713711905326,
#   'feature_fraction': 0.8218055447768081,
#   'lambda_l1': 0.7222964907915178,
#   'lambda_l2': 0.8414555963714396,
#   'learning_rate': 0.0030925251152918113,
#   'max_depth': 7.166751819088359,
#   'min_child_weight': 37.3468883586423,
#   'num_leaves': 542.2916917720623}

# 기본 파라미터
#  bagging_fraction = 0.9515683153667026,
#                 colsample_bytree = 0.7860120233288207, # 0.78
#                 feature_fraction = 0.9362075859090412,
#                 lambda_l1 = 0.7111030183072032,
#                 lambda_l2 = 0.5642765168754059,
#                 learning_rate = 0.011407920284082697, # 0.011
#                 max_depth = 6,
#                 min_child_weight = 33,
#                 num_leaves = 380,

# qe log 베이지안 최적화
# bagging_fraction = 0.16026521886490075,
# colsample_bytree = 0.38230762664460116,
# feature_fraction = 0.8803127292536881,
# lambda_l1 = 0.6427909607958205,
# lambda_l2 = 0.8516225399539507,
# learning_rate = 0.004810297234567945,
# max_depth = 6,
# min_child_weight = 30,
# num_leaves = 570,

            clf = lgb.LGBMClassifier(
                n_estimators=1000,
                objective='binary',
                boosting_type='gbdt', # gbdt
                bagging_fraction = 0.9669958011996147,
                colsample_bytree = 0.5987970645475955, # 0.78
                feature_fraction = 0.7318970172463788,
                lambda_l1 = 0.03879591433177747,
                lambda_l2 = 0.2799788929506455,
                learning_rate = 0.006097808404537128, # 0.011
                max_depth = 9,
                min_child_weight = 38,
                num_leaves = 395,
                random_state= 200,
                
            )

            clf.fit(
                train_x, train_y,
                eval_set = [(train_x, train_y), (valid_x, valid_y)], 
                eval_metric='auc', 
                verbose= 100, 
                early_stopping_rounds=300
            )
            
            oof_score.append(clf.best_score_['training']['auc'])
            valid_score.append(clf.best_score_['valid_1']['auc'])
            
            oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration = clf.best_iteration_)[:,1]
            test_preds += clf.predict_proba(te, num_iteration = clf.best_iteration_)[:,1] / folds.n_splits 
            
            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = X_train.columns
            fold_importance_df["importance"] = clf.feature_importances_
            fold_importance_df["fold"] = n_folds + 1
            feature_importance = pd.concat([feature_importance, fold_importance_df], axis=0)

            #print('Fold %2d AUC : %.6f' % (n_folds + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
        ft = feature_importance.groupby('feature')['importance'].mean().reset_index()
        ft2 = ft.sort_values('importance',ascending = False).iloc[:50]

        feature_graph_df = feature_importance.sort_values('importance')
        plt.figure(figsize = (16,12))
        plt.barh(ft2['feature'],ft2['importance'])

        
        print('tr: ',np.mean(oof_score))
        print('val: ',np.mean(valid_score))
        
        return ft2, test_preds, oof_preds, y_train, oof_score, valid_score
    
    elif model_category == 'xgb':
        X_train = tr.drop(columns = 'voted')
        y_train = tr['voted']

        folds = StratifiedKFold(n_splits=5, shuffle = True)
        test_preds = np.zeros(te.shape[0])
        oof_preds = np.zeros(X_train.shape[0])
        feature_importance = pd.DataFrame()

        for n_folds, (train_idx, valid_idx) in enumerate(folds.split(X_train, y_train)):
            train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
            valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]

#             'params': {'colsample_bytree': 0.6462430788077107,
#   'gamma': 1.715971732762962,
#   'learning_rate': 0.005504669803513776,
#   'max_depth': 13.323358026565089,
#   'min_child_weight': 67.7850859645155
            clf = xgb.XGBClassifier(
                n_estimators=1000,
                objective='binary:logistic',
                booster='gbtree', # gbtree
                gamma = 1.715971732762962,
                colsample_bytree = 0.6462430788077107, # 0.7860120233288207,
                learning_rate = 0.005504669803513776,# 0.011407920284082697,
                max_depth = 13, #7,
                min_child_weight = 68, #33,
                random_state= 200,
            )
            
            clf.fit(
                train_x, 
                train_y, 
                eval_set = [(train_x, train_y), (valid_x, valid_y)], 
                eval_metric='auc',
                verbose= 100, 
                early_stopping_rounds=300
            )
            
            test_preds += clf.predict_proba(te)[:,1] / folds.n_splits
            oof_preds[valid_idx] = clf.predict_proba(valid_x)[:,1]
            
            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = X_train.columns
            fold_importance_df["importance"] = clf.feature_importances_
            fold_importance_df["fold"] = n_folds + 1
            feature_importance = pd.concat([feature_importance, fold_importance_df], axis=0)

            #print('Fold %2d AUC : %.6f' % (n_folds + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
        ft = feature_importance.groupby('feature')['importance'].mean().reset_index()
        ft2 = ft.sort_values('importance',ascending = False).iloc[:50]

        feature_graph_df = feature_importance.sort_values('importance')
        plt.figure(figsize = (16,12))
        plt.barh(ft2['feature'],ft2['importance'])
        
        return ft2, test_preds, oof_preds, y_train

# %%
# 제출 43
ft_df_xgb, test_preds_xgb = test_inference(tr,te,'lgb')
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.867265	training's binary_logloss: 0.482527	valid_1's auc: 0.769793	valid_1's binary_logloss: 0.555084

# %%
# 제출 51 - 시간변수 로그화
ft_df_lgb, test_preds_lgb = test_inference(tr,te,'lgb')
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.804402	training's binary_logloss: 0.598742	valid_1's auc: 0.765876	valid_1's binary_logloss: 0.609585
# [200]	training's auc: 0.813743	training's binary_logloss: 0.558339	valid_1's auc: 0.767706	valid_1's binary_logloss: 0.579051
# [300]	training's auc: 0.822603	training's binary_logloss: 0.536448	valid_1's auc: 0.768694	valid_1's binary_logloss: 0.566355
# [400]	training's auc: 0.829142	training's binary_logloss: 0.523503	valid_1's auc: 0.76954	valid_1's binary_logloss: 0.560921
# [500]	training's auc: 0.836002	training's binary_logloss: 0.513885	valid_1's auc: 0.769928	valid_1's binary_logloss: 0.558702
# [600]	training's auc: 0.843112	training's binary_logloss: 0.505895	valid_1's auc: 0.77001	valid_1's binary_logloss: 0.55783
# [700]	training's auc: 0.850027	training's binary_logloss: 0.499059	valid_1's auc: 0.77009	valid_1's binary_logloss: 0.55749
# [800]	training's auc: 0.856881	training's binary_logloss: 0.492695	valid_1's auc: 0.770109	valid_1's binary_logloss: 0.557451
# [900]	training's auc: 0.862367	training's binary_logloss: 0.487406	valid_1's auc: 0.769668	valid_1's binary_logloss: 0.557663
# Early stopping, best iteration is:
# [674]	training's auc: 0.848343	training's binary_logloss: 0.500731	valid_1's auc: 0.770179	valid_1's binary_logloss: 0.557485
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.802845	training's binary_logloss: 0.599419	valid_1's auc: 0.760478	valid_1's binary_logloss: 0.609943
# [200]	training's auc: 0.812324	training's binary_logloss: 0.559282	valid_1's auc: 0.762122	valid_1's binary_logloss: 0.579143
# [300]	training's auc: 0.820462	training's binary_logloss: 0.537775	valid_1's auc: 0.762871	valid_1's binary_logloss: 0.566146
# [400]	training's auc: 0.827981	training's binary_logloss: 0.52444	valid_1's auc: 0.764141	valid_1's binary_logloss: 0.560079
# [500]	training's auc: 0.835407	training's binary_logloss: 0.514545	valid_1's auc: 0.765219	valid_1's binary_logloss: 0.557159
# [600]	training's auc: 0.842221	training's binary_logloss: 0.506888	valid_1's auc: 0.766146	valid_1's binary_logloss: 0.555677
# [700]	training's auc: 0.848576	training's binary_logloss: 0.500463	valid_1's auc: 0.766469	valid_1's binary_logloss: 0.555163
# [800]	training's auc: 0.853901	training's binary_logloss: 0.495147	valid_1's auc: 0.766695	valid_1's binary_logloss: 0.554971
# [900]	training's auc: 0.859895	training's binary_logloss: 0.489509	valid_1's auc: 0.766759	valid_1's binary_logloss: 0.55494
# [1000]	training's auc: 0.865313	training's binary_logloss: 0.484369	valid_1's auc: 0.766955	valid_1's binary_logloss: 0.554862
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.865313	training's binary_logloss: 0.484369	valid_1's auc: 0.766955	valid_1's binary_logloss: 0.554862
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.802699	training's binary_logloss: 0.599101	valid_1's auc: 0.762491	valid_1's binary_logloss: 0.609748
# [200]	training's auc: 0.812017	training's binary_logloss: 0.558851	valid_1's auc: 0.764923	valid_1's binary_logloss: 0.578831
# [300]	training's auc: 0.820938	training's binary_logloss: 0.536965	valid_1's auc: 0.766457	valid_1's binary_logloss: 0.565708
# [400]	training's auc: 0.828766	training's binary_logloss: 0.52336	valid_1's auc: 0.767998	valid_1's binary_logloss: 0.559618
# [500]	training's auc: 0.835943	training's binary_logloss: 0.513392	valid_1's auc: 0.768776	valid_1's binary_logloss: 0.556962
# [600]	training's auc: 0.843466	training's binary_logloss: 0.505204	valid_1's auc: 0.768883	valid_1's binary_logloss: 0.556056
# [700]	training's auc: 0.850315	training's binary_logloss: 0.498244	valid_1's auc: 0.769334	valid_1's binary_logloss: 0.555558
# [800]	training's auc: 0.856665	training's binary_logloss: 0.492198	valid_1's auc: 0.76932	valid_1's binary_logloss: 0.555498
# [900]	training's auc: 0.862472	training's binary_logloss: 0.486612	valid_1's auc: 0.769228	valid_1's binary_logloss: 0.555476
# [1000]	training's auc: 0.867392	training's binary_logloss: 0.481811	valid_1's auc: 0.76904	valid_1's binary_logloss: 0.555642
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.867392	training's binary_logloss: 0.481811	valid_1's auc: 0.76904	valid_1's binary_logloss: 0.555642
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.806666	training's binary_logloss: 0.599013	valid_1's auc: 0.767308	valid_1's binary_logloss: 0.607661
# [200]	training's auc: 0.815763	training's binary_logloss: 0.558403	valid_1's auc: 0.767292	valid_1's binary_logloss: 0.576358
# [300]	training's auc: 0.823724	training's binary_logloss: 0.536428	valid_1's auc: 0.767557	valid_1's binary_logloss: 0.563102
# [400]	training's auc: 0.830868	training's binary_logloss: 0.522954	valid_1's auc: 0.768292	valid_1's binary_logloss: 0.55704
# [500]	training's auc: 0.838512	training's binary_logloss: 0.512752	valid_1's auc: 0.769067	valid_1's binary_logloss: 0.554116
# [600]	training's auc: 0.845791	training's binary_logloss: 0.504642	valid_1's auc: 0.769667	valid_1's binary_logloss: 0.552692
# [700]	training's auc: 0.852754	training's binary_logloss: 0.497593	valid_1's auc: 0.769842	valid_1's binary_logloss: 0.552155
# [800]	training's auc: 0.860142	training's binary_logloss: 0.490586	valid_1's auc: 0.770004	valid_1's binary_logloss: 0.551935
# [900]	training's auc: 0.866105	training's binary_logloss: 0.484756	valid_1's auc: 0.769914	valid_1's binary_logloss: 0.551913
# [1000]	training's auc: 0.87189	training's binary_logloss: 0.479134	valid_1's auc: 0.770062	valid_1's binary_logloss: 0.551783
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.87189	training's binary_logloss: 0.479134	valid_1's auc: 0.770062	valid_1's binary_logloss: 0.551783
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.805616	training's binary_logloss: 0.598591	valid_1's auc: 0.764234	valid_1's binary_logloss: 0.610848
# [200]	training's auc: 0.815945	training's binary_logloss: 0.557595	valid_1's auc: 0.765638	valid_1's binary_logloss: 0.58076
# [300]	training's auc: 0.824021	training's binary_logloss: 0.535775	valid_1's auc: 0.765957	valid_1's binary_logloss: 0.568412
# [400]	training's auc: 0.831347	training's binary_logloss: 0.52221	valid_1's auc: 0.766681	valid_1's binary_logloss: 0.562775
# [500]	training's auc: 0.838422	training's binary_logloss: 0.512325	valid_1's auc: 0.766844	valid_1's binary_logloss: 0.560314
# [600]	training's auc: 0.845631	training's binary_logloss: 0.504173	valid_1's auc: 0.766976	valid_1's binary_logloss: 0.559221
# [700]	training's auc: 0.851331	training's binary_logloss: 0.498061	valid_1's auc: 0.767105	valid_1's binary_logloss: 0.558725
# [800]	training's auc: 0.856999	training's binary_logloss: 0.49254	valid_1's auc: 0.767225	valid_1's binary_logloss: 0.558558
# [900]	training's auc: 0.862136	training's binary_logloss: 0.487508	valid_1's auc: 0.767202	valid_1's binary_logloss: 0.558532
# [1000]	training's auc: 0.867575	training's binary_logloss: 0.482232	valid_1's auc: 0.76725	valid_1's binary_logloss: 0.558506
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.867575	training's binary_logloss: 0.482232	valid_1's auc: 0.76725	valid_1's binary_logloss: 0.558506

# %% [markdown]
# # Create Submission

# %%
test_preds_lgb_df = pd.read_csv(
    os.path.join(data_file_path,'dacon_submission42.csv')
)

test_preds_lgb2_df = pd.read_csv(
    os.path.join(data_file_path,'dacon_submission55.csv')
)

high_score = pd.read_csv(
    os.path.join(data_file_path,'dacon_submission62.csv')
)

# %%
nn_net = pd.read_csv(
    os.path.join(data_file_path,'1110-1254.csv')
)

nn_net['voted'] = nn_net['voted'] - 1

# %%
# 0.8 / 0.2이 최적 가중치 앙상블
test_preds = (test_preds_lgb['voted'] * 0.8) + (test_preds_xgb * 0.2)

# %%
# 성능 좋았던 0.7814 결과 값 가중치 앙상블
test_preds = (test_preds_lgb_df['voted'] * 0.7) + (test_preds_lgb2_df['voted'] * 0.3)

# %%
# 성능 좋았던 0.7814 결과 값 가중치 앙상블
test_preds2 = (high_score['voted'] * 0.8) + (test_preds * 0.2)

# %%
# 추론 테스트 코드

# submission['voted'] = test_preds
# submission['voted'] = test_preds_lgb
submission['voted'] = test_preds2
#submission['voted'] = test_preds_xgb

# %%
# 제출 버전 기록
n_sub = 67

# %%
submission.to_csv(
    os.path.join(data_file_path,'dacon_submission{}.csv'.format(n_sub)
            ),index = False)

# %%
# 28: xgb + lgb 앙상블 -> 0.78029
# 30: 기존 성능이 가장 좋았던 wf_wr_sum까지 한 뒤 kfold rs없이 제출 - index 포험 -> 0.78072
# 31: 마찬가지로 rs없이 제출 - index 포함x -> 0.78038
# 32: 0.78054 -> qe 데이터 로그화
# 33: -> 0.7788.... tp, wr 클러스터링 변수 생성 개떡락
# 34: -> ver9 데이터에 objective=dart로 변환
# 37: object 컬럼 카테고리컬 컬럼으로 변경해서 시행
# 38: colsample 0.70
# 가중치 0.7,0.3 성능이 가장 좋음 59
# 63: 0.75, 0.25 가중치
# 64: log에 베이지안 최적화 -> 성능 개떡락

# %% [markdown]
# # weight ensemble(가중치 최적화)

# %% [markdown]
# https://dacon.io/competitions/official/235573/codeshare/697#CATBOOST

# %%
# 가중치 산출은 일반 데이터가지고 산출하면 좋을듯
