# %%
'''data'''
import pandas as pd
import numpy as np
from datetime import datetime
import math


'''plotting'''
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
import seaborn as sns

'''sys library'''
#plt.style.use('fivethirtyeight')
import warnings
import os
import gc
import time
warnings.filterwarnings('ignore')
# %matplotlib inline
rc('font',family="NanumSquareR")

'''modeling'''
from sklearn.ensemble import RandomForestClassifier
#from ggplot import *
from sklearn.linear_model import LinearRegression
import scipy.stats as st
import lightgbm as lgb
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from scipy.stats import uniform, randint
from sklearn.datasets import load_breast_cancer, load_diabetes, load_wine
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error, f1_score, roc_auc_score
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split

#-*- coding: utf-8 -*-

plt.style.use('ggplot') #ggplot스타일 사용
plt.rc('axes', unicode_minus=False)
rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # ***Data Import***

# %%
# valid data
valid = pd.read_csv('data/참가번호6자리.csv')

# %%
final_sub = pd.read_csv('203675/최종 예측 파일/203675.csv')

# %%
# train, test data
train_24_recent= pd.read_csv('data/train24_MY.csv')
train_48_recent = pd.read_csv('data/train48_MY.csv')
dj_ts_aws_recent= pd.read_csv('data/test_MY.csv')

# %%
# 변수중요도를 통해서 변수소거를 위한 각 모델별, 시간별 데이터 셋
train_lgb24_df = train_24_recent.copy()
train_xgb24_df = train_24_recent.copy()

train_lgb48_df = train_48_recent.copy()
train_xgb48_df = train_48_recent.copy()

test_lgb24_df = dj_ts_aws_recent.copy()
test_xgb24_df = dj_ts_aws_recent.copy()
test_lgb48_df = dj_ts_aws_recent.copy()
test_xgb48_df = dj_ts_aws_recent.copy()

# %%
# aws + 베이스 데이터
aws_columns24 = ['loc','plant','after24_loc_predict','hum_in','tem_coil','tem_in','tem_out_loc1','hum_out_loc1',
                             'temp','1m_rain','rain_ornot','wind_direct_x','wind_speed_x','humid','sp_tem','sp_1m_rain','sp_rain_ornot','sp_wind_direct',
                             'sp_wind_speed','sp_press','sp_sea_press','sp_ilsa','sp_iljo']
aws_columns48 = ['loc','plant','after48_loc_predict','hum_in','tem_coil','tem_in','tem_out_loc1','hum_out_loc1',
                             'temp','1m_rain','rain_ornot','wind_direct_x','wind_speed_x','humid','sp_tem','sp_1m_rain','sp_rain_ornot','sp_wind_direct',
                             'sp_wind_speed','sp_press','sp_sea_press','sp_ilsa','sp_iljo']
aws_columns_test = ['loc','plant','hum_in','tem_coil','tem_in','tem_out_loc1','hum_out_loc1',
                             'temp','1m_rain','rain_ornot','wind_direct_x','wind_speed_x','humid','sp_tem','sp_1m_rain','sp_rain_ornot','sp_wind_direct',
                             'sp_wind_speed','sp_press','sp_sea_press','sp_ilsa','sp_iljo']

train_24_recent_aws = train_24_recent[aws_columns]
train_48_recent_aws = train_48_recent[aws_columns48]
dj_ts_aws_recent_aws = dj_ts_aws_recent[aws_columns_test]

# %%
# 동네예보 + 베이스 데이터
dong_ls = []
for i in train_24_recent.columns:
    if 'dong' in i:
        dong_ls.append(i)
        
dong_ls24= dong_ls + ['loc','plant','after24_loc_predict','hum_in','tem_coil','tem_in','tem_out_loc1','hum_out_loc1','cloud']
dong_ls48= dong_ls + ['loc','plant','after48_loc_predict','hum_in','tem_coil','tem_in','tem_out_loc1','hum_out_loc1','cloud']
dong_ls_test= dong_ls + ['loc','plant','hum_in','tem_coil','tem_in','tem_out_loc1','hum_out_loc1','cloud']

train_24_recent_dong = train_24_recent[dong_ls24]
train_48_recent_dong = train_48_recent[dong_ls48]
dj_ts_aws_recent_dong = dj_ts_aws_recent[dong_ls_test]

# %% [markdown]
# # ***Function***

# %%
# train, test 분할
def train_test(df,target_variable,size):
    X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = target_variable),df[target_variable],test_size = size, random_state = 0)
    
    return X_train, X_test, y_train, y_test

def proba_to_int(value_ls,cut_off):
    
    preds = []
    for i in range(len(value_ls)):
        
        if value_ls[i] >= cut_off:
            preds.append(1)
        else:
            preds.append(0)
            
            
    return preds

def nan_preprocessing(df,col):
    col_value = []
    for i in range(len(df)):
        if i != 0 and str(df[col].iloc[i]) == 'nan':

            if str(df[col].iloc[i-1]) == 'nan':
                pass

            else:

                for j in range(i+1,len(df)):
                    if str(df[col].iloc[j]) != 'nan':
                        interval = abs(df[col].iloc[i-1] - df[col].iloc[j])
                        cnt = j - (i-1)

                        value = interval / cnt 

                        value2 = df[col].iloc[i-1]

                        if df[col].iloc[i-1] < df[col].iloc[j]:
                            right_left = 'left'

                        else:
                            right_left = 'right'

                        for k in range(0,cnt - 1):

                            if right_left == 'left':
                                value2 += value
                                col_value.append(value2)
                            elif right_left == 'right':
                                value2 -= value
                                col_value.append(value2)

                        break


                    elif str(df[col].iloc[j]) == 'nan':
                        pass
        else:
            col_value.append(df[col].iloc[i])
    return col_value

def dew_point(df,tem_column,hum_column):
    b = 17.62
    c = 243.12
    
    dew_point_ls = []
    
    for i in range(len(df)):
        try:
            gamma = (b * df[tem_column].iloc[i] /(c + df[tem_column].iloc[i])) + math.log(df[hum_column].iloc[i] / 100.0)
            dewpoint = (c * gamma) / (b - gamma)

            dew_point_ls.append(dewpoint)
        except:
            dew_point_ls.append(np.nan)
        
    return dew_point_ls

# %% [markdown]
# # ***XGB***

# %%
def XGB_classifier(df,test_df, target_variable, num_folds, cut_off, real_train = False):
    
    if real_train == False:
        X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = target_variable),df[target_variable],test_size = 0.25, random_state = 0)

        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)

        oof_preds = np.zeros(X_train.shape[0])
        test_preds = np.zeros(X_test.shape[0])
        feature_importance_df = pd.DataFrame()

        for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_train,y_train)):

            train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
            valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]

            # 파라미터 삽입
            '''params = {}base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.7, gamma=0.5, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.7, max_delta_step=0, max_depth=5,
              min_child_weight=0.4, monotone_constraints='()', n_estimators=1000, n_jobs=0,
              num_parallel_tree=1, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.9,
              tree_method='exact', validate_parameters=1, verbosity=None'''
            

        
            clf = xgb.XGBClassifier(n_estimators = 1000,base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.7, gamma=0.5, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.7, max_delta_step=0, max_depth=5,
              min_child_weight=0.4, monotone_constraints='()', n_jobs=0,
              num_parallel_tree=1, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.9,
              tree_method='exact', validate_parameters=1, verbosity=None)

            # 모델 평가척도로 어떤것을 사용할 것인지
            clf.fit(train_x, train_y, eval_set = [(train_x, train_y), (valid_x, valid_y)], 
                   eval_metric='auc', verbose= 100, early_stopping_rounds=300)

            oof_preds[valid_idx] = clf.predict_proba(valid_x)[:,1]
            test_preds += clf.predict_proba(X_test)[:,1] / folds.n_splits

            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = X_train.columns
            fold_importance_df["importance"] = clf.feature_importances_
            fold_importance_df["fold"] = n_fold + 1
            feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

            print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))

            del clf, train_x, train_y, valid_x, valid_y
            gc.collect()

        print('Full AUC score %.6f' % roc_auc_score(y_train, oof_preds))

        feature_importance_fin = feature_importance_df[["feature", "importance"]].\
                                groupby("feature").mean().sort_values(by="importance", ascending=False)

        preds = []

        for i in range(len(test_preds)):
            if test_preds[i] >= cut_off:

                preds.append(1)
            else:
                preds.append(0)

        print('Test AUC score : ', roc_auc_score(y_test, test_preds))
        conf_matrix = confusion_matrix(y_test, preds,labels = [1,0])
        
        plt.figure(figsize = (16,12))
        plt.barh(feature_importance_fin.index,feature_importance_fin['importance'])


        return test_preds, preds, y_test, feature_importance_fin, conf_matrix
    
    elif real_train == True:
        
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
        
        test_preds = np.zeros(test_df.shape[0])
        feature_importance_df = pd.DataFrame()
        
        X_train = df.drop(columns = target_variable)
        y_train = df[target_variable]
        oof_preds = np.zeros(X_train.shape[0])
        
        test_df = test_df[X_train.columns.tolist()] #컬럼 순서를 맞춰주기 위한 장치
        
        for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_train,y_train)):

            train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
            valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]

            # 파라미터 삽입
            '''params = {}'''

            clf = xgb.XGBClassifier(n_estimators= 2000)

            # 모델 평가척도로 어떤것을 사용할 것인지
            clf.fit(train_x, train_y, eval_set = [(train_x, train_y), (valid_x, valid_y)], 
                   eval_metric='auc', verbose= 100, early_stopping_rounds=300)

            oof_preds[valid_idx] = clf.predict_proba(valid_x)[:,1]
            test_preds += clf.predict_proba(test_df)[:,1] / folds.n_splits

            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = X_train.columns
            fold_importance_df["importance"] = clf.feature_importances_
            fold_importance_df["fold"] = n_fold + 1
            feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

            print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))

            del clf, train_x, train_y, valid_x, valid_y
            gc.collect()

        print('Full AUC score %.6f' % roc_auc_score(y_train, oof_preds))

        feature_importance_fin = feature_importance_df[["feature", "importance"]].\
                                groupby("feature").mean().sort_values(by="importance", ascending=False)

        preds = []

        for i in range(len(test_preds)):
            if test_preds[i] >= cut_off:

                preds.append(1)
            else:
                preds.append(0)

                
        plt.figure(figsize = (16,12))
        plt.barh(feature_importance_fin.index,feature_importance_fin['importance'])

        return test_preds, preds, feature_importance_fin

# %% [markdown]
# ### ***Validation***

# %% [markdown]
# ***제출 데이터셋 검증***

# %%
# 결측치를 처리한 버전
test_preds_xgb24, preds_xgb24, y_test_xgb24, feature_importance_fin_xgb24, conf_matrix_xgb24 = XGB_classifier(\
                                                                                        train_24_recent,
                                                                                        dj_ts_aws_recent,
                                                                                        'after24_loc_predict',
                                                                                        5,
                                                                                        0.5,
                                                                                        real_train = False)
# Out:
# [0]	validation_0-auc:0.90541	validation_1-auc:0.89021
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99923
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99936
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99938
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99939
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99939
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99939
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99939
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99938
# Stopping. Best iteration:
# [532]	validation_0-auc:1.00000	validation_1-auc:0.99940
#
# Fold  1 AUC : 0.999397
# [0]	validation_0-auc:0.89853	validation_1-auc:0.89232
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99653
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99678
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99674
# Stopping. Best iteration:
# [57]	validation_0-auc:0.99998	validation_1-auc:0.99705
#
# Fold  2 AUC : 0.997047
# [0]	validation_0-auc:0.89160	validation_1-auc:0.89117
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99818
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99844
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99842
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99852
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99847
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99844
# Stopping. Best iteration:
# [389]	validation_0-auc:1.00000	validation_1-auc:0.99854
#
# Fold  3 AUC : 0.998540
# [0]	validation_0-auc:0.89850	validation_1-auc:0.89833
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99917
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99935
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99942
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99944
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99945
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99948
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99948
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99948
# [999]	validation_0-auc:1.00000	validation_1-auc:0.99948
# Fold  4 AUC : 0.999486
# [0]	validation_0-auc:0.90187	validation_1-auc:0.89536
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99786
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99804
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99826
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99829
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99832
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99834
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99838
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99843
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99845
# [999]	validation_0-auc:1.00000	validation_1-auc:0.99846
# Fold  5 AUC : 0.998475
# Full AUC score 0.997819
# Test AUC score :  0.9992011680056341

# %%
# 결측치를 처리한 버전
test_preds_xgb48, preds_xgb48, y_test_xgb48, feature_importance_fin_xgb48, conf_matrix_xgb48 = XGB_classifier(\
                                                                                        train_48_recent,
                                                                                        dj_ts_aws_recent,
                                                                                        'after48_loc_predict',
                                                                                        5,
                                                                                        0.5,
                                                                                        real_train = False)
# Out:
# [0]	validation_0-auc:0.82411	validation_1-auc:0.82933
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99878
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99890
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99891
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99891
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99896
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99898
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99897
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99895
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99893
# Stopping. Best iteration:
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99898
#
# Fold  1 AUC : 0.998981
# [0]	validation_0-auc:0.82576	validation_1-auc:0.80437
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99812
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99861
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99860
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99869
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99859
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99852
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99858
# Stopping. Best iteration:
# [418]	validation_0-auc:1.00000	validation_1-auc:0.99872
#
# Fold  2 AUC : 0.998722
# [0]	validation_0-auc:0.81826	validation_1-auc:0.79909
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99927
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99948
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99947
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99947
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99947
# Stopping. Best iteration:
# [367]	validation_0-auc:1.00000	validation_1-auc:0.99949
#
# Fold  3 AUC : 0.999492
# [0]	validation_0-auc:0.88175	validation_1-auc:0.86943
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99822
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99851
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99847
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99852
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99850
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99847
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99846
# Stopping. Best iteration:
# [415]	validation_0-auc:1.00000	validation_1-auc:0.99853
#
# Fold  4 AUC : 0.998528
# [0]	validation_0-auc:0.90472	validation_1-auc:0.88164
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99556
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99561
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99543
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99545
# Stopping. Best iteration:
# [162]	validation_0-auc:1.00000	validation_1-auc:0.99590
#
# Fold  5 AUC : 0.995904
# Full AUC score 0.998416
# Test AUC score :  0.9964987452373623

# %% [markdown]
# ***기본데이터 + aws 데이터***

# %%
# 결측치를 처리한 버전
test_preds_xgb24_aws, preds_xgb24_aws, y_test_xgb24_aws, feature_importance_fin_xgb24_aws, conf_matrix_xgb24 = XGB_classifier(\
                                                                                        train_24_recent_aws,
                                                                                        dj_ts_aws_recent_aws,
                                                                                        'after24_loc_predict',
                                                                                        5,
                                                                                        0.5,
                                                                                        real_train = False)
# Out:
# [0]	validation_0-auc:0.83008	validation_1-auc:0.83465
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99992	validation_1-auc:0.99487
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99536
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99576
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99618
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99616
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99612
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99606
# Stopping. Best iteration:
# [422]	validation_0-auc:1.00000	validation_1-auc:0.99626
#
# Fold  1 AUC : 0.996257
# [0]	validation_0-auc:0.85015	validation_1-auc:0.82490
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99997	validation_1-auc:0.99401
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99445
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99408
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99419
# Stopping. Best iteration:
# [150]	validation_0-auc:1.00000	validation_1-auc:0.99461
#
# Fold  2 AUC : 0.994612
# [0]	validation_0-auc:0.84354	validation_1-auc:0.83162
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99998	validation_1-auc:0.99277
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99372
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99417
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99358
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99337
# Stopping. Best iteration:
# [289]	validation_0-auc:1.00000	validation_1-auc:0.99438
#
# Fold  3 AUC : 0.994376
# [0]	validation_0-auc:0.80944	validation_1-auc:0.80301
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99997	validation_1-auc:0.99786
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99810
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99801
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99803
# Stopping. Best iteration:
# [156]	validation_0-auc:1.00000	validation_1-auc:0.99819
#
# Fold  4 AUC : 0.998188
# [0]	validation_0-auc:0.80837	validation_1-auc:0.80830
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99998	validation_1-auc:0.99758
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99737
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99772
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99781
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99779
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99787
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99794
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99793
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99797
# [999]	validation_0-auc:1.00000	validation_1-auc:0.99799
# Fold  5 AUC : 0.998002
# Full AUC score 0.995539
# Test AUC score :  0.9970212250976996

# %%
# 결측치를 처리한 버전
test_preds_xgb48_aws, preds_xgb48_aws, y_test_xgb48_aws, feature_importance_fin_xgb48_aws, conf_matrix_xgb48 = XGB_classifier(\
                                                                                        train_48_recent_aws,
                                                                                        dj_ts_aws_recent_aws,
                                                                                        'after48_loc_predict',
                                                                                        5,
                                                                                        0.5,
                                                                                        real_train = False)
# Out:
# [0]	validation_0-auc:0.85129	validation_1-auc:0.86678
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99992	validation_1-auc:0.99769
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99821
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99835
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99843
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99852
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99853
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99856
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99850
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99852
# [999]	validation_0-auc:1.00000	validation_1-auc:0.99847
# Fold  1 AUC : 0.998580
# [0]	validation_0-auc:0.76296	validation_1-auc:0.73711
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99993	validation_1-auc:0.99214
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99388
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99458
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99454
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99475
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99445
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99434
# Stopping. Best iteration:
# [449]	validation_0-auc:1.00000	validation_1-auc:0.99486
#
# Fold  2 AUC : 0.994865
# [0]	validation_0-auc:0.82808	validation_1-auc:0.83725
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99994	validation_1-auc:0.99495
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99660
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99716
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99729
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99727
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99728
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99716
# Stopping. Best iteration:
# [406]	validation_0-auc:1.00000	validation_1-auc:0.99735
#
# Fold  3 AUC : 0.997345
# [0]	validation_0-auc:0.83372	validation_1-auc:0.81210
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99998	validation_1-auc:0.99267
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99294
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99304
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99346
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99346
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99371
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99389
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99405
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99394
# [999]	validation_0-auc:1.00000	validation_1-auc:0.99387
# Fold  4 AUC : 0.994050
# [0]	validation_0-auc:0.85506	validation_1-auc:0.84869
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99996	validation_1-auc:0.99006
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99082
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99094
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99082
# Stopping. Best iteration:
# [170]	validation_0-auc:1.00000	validation_1-auc:0.99106
#
# Fold  5 AUC : 0.991063
# Full AUC score 0.994815
# Test AUC score :  0.9955506658969698

# %% [markdown]
# ***동네 예보***

# %%
# 결측치를 처리한 버전
test_preds_xgb24_dong, preds_xgb24_dong, y_test_xgb24_dong, feature_importance_fin_xgb24_dong, conf_matrix_xgb24_dong = XGB_classifier(\
                                                                                        train_24_recent_dong,
                                                                                        dj_ts_aws_recent_dong,
                                                                                        'after24_loc_predict',
                                                                                        5,
                                                                                        0.5,
                                                                                        real_train = False)
# Out:
# [0]	validation_0-auc:0.91317	validation_1-auc:0.90433
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99999	validation_1-auc:0.99864
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99866
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99882
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99892
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99892
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99895
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99894
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99894
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99895
# [999]	validation_0-auc:1.00000	validation_1-auc:0.99895
# Fold  1 AUC : 0.998956
# [0]	validation_0-auc:0.89992	validation_1-auc:0.90196
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99999	validation_1-auc:0.99717
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99707
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99722
# Stopping. Best iteration:
# [93]	validation_0-auc:0.99999	validation_1-auc:0.99737
#
# Fold  2 AUC : 0.997373
# [0]	validation_0-auc:0.90695	validation_1-auc:0.87290
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99999	validation_1-auc:0.99800
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99800
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99802
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99776
# Stopping. Best iteration:
# [148]	validation_0-auc:1.00000	validation_1-auc:0.99822
#
# Fold  3 AUC : 0.998217
# [0]	validation_0-auc:0.91334	validation_1-auc:0.90621
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99999	validation_1-auc:0.99859
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99899
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99910
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99910
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99917
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99916
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99920
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99923
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99924
# [999]	validation_0-auc:1.00000	validation_1-auc:0.99924
# Fold  4 AUC : 0.999252
# [0]	validation_0-auc:0.88110	validation_1-auc:0.88410
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99999	validation_1-auc:0.99822
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99866
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99871
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99857
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99866
# Stopping. Best iteration:
# [235]	validation_0-auc:1.00000	validation_1-auc:0.99875
#
# Fold  5 AUC : 0.998755
# Full AUC score 0.998212
# Test AUC score :  0.9993822931274566

# %%
# 결측치를 처리한 버전
test_preds_xgb48_dong, preds_xgb48_dong, y_test_xgb48_dong, feature_importance_fin_xgb48_dong, conf_matrix_xgb48_dong = XGB_classifier(\
                                                                                        train_48_recent_dong,
                                                                                        dj_ts_aws_recent_dong,
                                                                                        'after48_loc_predict',
                                                                                        5,
                                                                                        0.5,
                                                                                        real_train = False)
# Out:
# [0]	validation_0-auc:0.81455	validation_1-auc:0.83891
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99995	validation_1-auc:0.99597
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99691
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99695
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99705
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99722
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99717
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99720
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99713
# Stopping. Best iteration:
# [530]	validation_0-auc:1.00000	validation_1-auc:0.99733
#
# Fold  1 AUC : 0.997334
# [0]	validation_0-auc:0.81509	validation_1-auc:0.80615
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99996	validation_1-auc:0.99566
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99571
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99575
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99555
# Stopping. Best iteration:
# [117]	validation_0-auc:0.99999	validation_1-auc:0.99591
#
# Fold  2 AUC : 0.995909
# [0]	validation_0-auc:0.81637	validation_1-auc:0.81179
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99997	validation_1-auc:0.99668
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99748
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99749
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99765
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99750
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99724
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99709
# Stopping. Best iteration:
# [401]	validation_0-auc:1.00000	validation_1-auc:0.99766
#
# Fold  3 AUC : 0.997661
# [0]	validation_0-auc:0.82067	validation_1-auc:0.79289
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99997	validation_1-auc:0.99624
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99701
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99711
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99725
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99720
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99726
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99730
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99731
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99723
# [999]	validation_0-auc:1.00000	validation_1-auc:0.99731
# Fold  4 AUC : 0.997345
# [0]	validation_0-auc:0.80586	validation_1-auc:0.79526
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:0.99997	validation_1-auc:0.99521
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99650
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99688
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99685
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99685
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99704
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99695
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99694
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99682
# Stopping. Best iteration:
# [616]	validation_0-auc:1.00000	validation_1-auc:0.99707
#
# Fold  5 AUC : 0.997074
# Full AUC score 0.996086
# Test AUC score :  0.9947703935265237

# %% [markdown]
# ### ***Real Test Prediction***

# %%
test_preds_xgb24, preds_xgb24, feature_importance_fin_xgb24 = XGB_classifier(\
                                                            train_24_recent,
                                                            dj_ts_aws_recent,
                                                            'after24_loc_predict',
                                                            5,
                                                            0.5,
                                                            real_train = True)
# Out:
# [0]	validation_0-auc:0.90809	validation_1-auc:0.89027
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99858
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99858
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99864
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99859
# Stopping. Best iteration:
# [126]	validation_0-auc:1.00000	validation_1-auc:0.99876
#
# Fold  1 AUC : 0.998760
# [0]	validation_0-auc:0.90262	validation_1-auc:0.88656
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99849
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99819
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99789
# Stopping. Best iteration:
# [88]	validation_0-auc:1.00000	validation_1-auc:0.99870
#
# Fold  2 AUC : 0.998701
# [0]	validation_0-auc:0.89169	validation_1-auc:0.89886
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99868
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99888
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99899
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99905
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99905
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99910
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99909
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99910
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99912
# [1000]	validation_0-auc:1.00000	validation_1-auc:0.99914
# [1100]	validation_0-auc:1.00000	validation_1-auc:0.99914
# [1200]	validation_0-auc:1.00000	validation_1-auc:0.99913
# [1300]	validation_0-auc:1.00000	validation_1-auc:0.99914
# [1400]	validation_0-auc:1.00000	validation_1-auc:0.99913
# [1500]	validation_0-auc:1.00000	validation_1-auc:0.99914
# [1600]	validation_0-auc:1.00000	validation_1-auc:0.99915
# [1700]	validation_0-auc:1.00000	validation_1-auc:0.99915
# [1800]	validation_0-auc:1.00000	validation_1-auc:0.99915
# [1900]	validation_0-auc:1.00000	validation_1-auc:0.99915
# Stopping. Best iteration:
# [1659]	validation_0-auc:1.00000	validation_1-auc:0.99916
#
# Fold  3 AUC : 0.999157
# [0]	validation_0-auc:0.89930	validation_1-auc:0.90246
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99918
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99939
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99942
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99943
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99945
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99946
# Stopping. Best iteration:
# [624]	validation_0-auc:1.00000	validation_1-auc:0.99947
#
# Fold  4 AUC : 0.999468
# [0]	validation_0-auc:0.89566	validation_1-auc:0.90217
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99925
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99931
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99921
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99925
# Stopping. Best iteration:
# [116]	validation_0-auc:1.00000	validation_1-auc:0.99940
#
# Fold  5 AUC : 0.999398
# Full AUC score 0.998355

# %%
# 변수중요도를 통한 변수 제거
train_xgb24_remove = train_xgb24_df.drop(columns = feature_importance_fin_xgb24.tail(10).index.tolist())
test_xgb24_remove = test_xgb24_df.drop(columns = feature_importance_fin_xgb24.tail(10).index.tolist())

# %%
remove_test_preds_xgb24, remove_preds_xgb24, remove_feature_importance_fin_xgb24 = XGB_classifier(\
                                                            train_xgb24_remove,
                                                            test_xgb24_remove,
                                                            'after24_loc_predict',
                                                            5,
                                                            0.5,
                                                            real_train = True)
# Out:
# [0]	validation_0-auc:0.90809	validation_1-auc:0.89027
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99858
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99858
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99864
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99859
# Stopping. Best iteration:
# [126]	validation_0-auc:1.00000	validation_1-auc:0.99876
#
# Fold  1 AUC : 0.998760
# [0]	validation_0-auc:0.90262	validation_1-auc:0.88656
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99849
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99819
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99789
# Stopping. Best iteration:
# [88]	validation_0-auc:1.00000	validation_1-auc:0.99870
#
# Fold  2 AUC : 0.998701
# [0]	validation_0-auc:0.89169	validation_1-auc:0.89886
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99868
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99888
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99899
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99905
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99905
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99910
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99909
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99910
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99912
# [1000]	validation_0-auc:1.00000	validation_1-auc:0.99914
# [1100]	validation_0-auc:1.00000	validation_1-auc:0.99914
# [1200]	validation_0-auc:1.00000	validation_1-auc:0.99913
# [1300]	validation_0-auc:1.00000	validation_1-auc:0.99914
# [1400]	validation_0-auc:1.00000	validation_1-auc:0.99913
# [1500]	validation_0-auc:1.00000	validation_1-auc:0.99914
# [1600]	validation_0-auc:1.00000	validation_1-auc:0.99915
# [1700]	validation_0-auc:1.00000	validation_1-auc:0.99915
# [1800]	validation_0-auc:1.00000	validation_1-auc:0.99915
# [1900]	validation_0-auc:1.00000	validation_1-auc:0.99915
# Stopping. Best iteration:
# [1659]	validation_0-auc:1.00000	validation_1-auc:0.99916
#
# Fold  3 AUC : 0.999157
# [0]	validation_0-auc:0.89930	validation_1-auc:0.90246
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99918
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99939
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99942
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99943
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99945
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99946
# Stopping. Best iteration:
# [624]	validation_0-auc:1.00000	validation_1-auc:0.99947
#
# Fold  4 AUC : 0.999468
# [0]	validation_0-auc:0.89566	validation_1-auc:0.90217
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99925
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99931
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99921
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99925
# Stopping. Best iteration:
# [116]	validation_0-auc:1.00000	validation_1-auc:0.99940
#
# Fold  5 AUC : 0.999398
# Full AUC score 0.998355

# %%
test_preds_xgb48, preds_xgb48, feature_importance_fin_xgb48 = XGB_classifier(\
                                                            train_48_recent,
                                                            dj_ts_aws_recent,
                                                            'after48_loc_predict',
                                                            5,
                                                            0.5,
                                                            real_train = True)
# Out:
# [0]	validation_0-auc:0.88152	validation_1-auc:0.88672
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99942
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99955
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99947
# Stopping. Best iteration:
# [188]	validation_0-auc:1.00000	validation_1-auc:0.99957
#
# Fold  1 AUC : 0.999566
# [0]	validation_0-auc:0.90494	validation_1-auc:0.89430
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99663
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99636
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99600
# Stopping. Best iteration:
# [58]	validation_0-auc:0.99997	validation_1-auc:0.99694
#
# Fold  2 AUC : 0.996938
# [0]	validation_0-auc:0.89328	validation_1-auc:0.89160
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99919
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99930
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99932
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99931
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99928
# Stopping. Best iteration:
# [243]	validation_0-auc:1.00000	validation_1-auc:0.99935
#
# Fold  3 AUC : 0.999346
# [0]	validation_0-auc:0.88667	validation_1-auc:0.88366
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99779
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99825
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99829
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99837
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99841
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99843
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99841
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99844
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99844
# [1000]	validation_0-auc:1.00000	validation_1-auc:0.99841
# Stopping. Best iteration:
# [742]	validation_0-auc:1.00000	validation_1-auc:0.99845
#
# Fold  4 AUC : 0.998455
# [0]	validation_0-auc:0.88825	validation_1-auc:0.87919
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99924
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99930
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99931
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99924
# Stopping. Best iteration:
# [137]	validation_0-auc:1.00000	validation_1-auc:0.99935
#
# Fold  5 AUC : 0.999355
# Full AUC score 0.997743

# %%
# 변수중요도를 통한 변수 제거
train_xgb48_remove = train_xgb48_df.drop(columns = feature_importance_fin_xgb48.tail(10).index.tolist())
test_xgb48_remove = test_xgb48_df.drop(columns = feature_importance_fin_xgb48.tail(10).index.tolist())

# %%
remove_test_preds_xgb48, remove_preds_xgb48, remove_feature_importance_fin_xgb48 = XGB_classifier(\
                                                            train_xgb48_remove,
                                                            test_xgb48_remove,
                                                            'after48_loc_predict',
                                                            5,
                                                            0.5,
                                                            real_train = True)
# Out:
# [0]	validation_0-auc:0.88152	validation_1-auc:0.88672
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99942
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99955
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99946
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99947
# Stopping. Best iteration:
# [188]	validation_0-auc:1.00000	validation_1-auc:0.99957
#
# Fold  1 AUC : 0.999566
# [0]	validation_0-auc:0.90494	validation_1-auc:0.89430
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99663
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99636
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99600
# Stopping. Best iteration:
# [58]	validation_0-auc:0.99997	validation_1-auc:0.99694
#
# Fold  2 AUC : 0.996938
# [0]	validation_0-auc:0.89328	validation_1-auc:0.89160
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99919
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99930
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99932
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99931
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99928
# Stopping. Best iteration:
# [243]	validation_0-auc:1.00000	validation_1-auc:0.99935
#
# Fold  3 AUC : 0.999346
# [0]	validation_0-auc:0.88667	validation_1-auc:0.88366
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99779
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99825
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99829
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99837
# [500]	validation_0-auc:1.00000	validation_1-auc:0.99841
# [600]	validation_0-auc:1.00000	validation_1-auc:0.99843
# [700]	validation_0-auc:1.00000	validation_1-auc:0.99841
# [800]	validation_0-auc:1.00000	validation_1-auc:0.99844
# [900]	validation_0-auc:1.00000	validation_1-auc:0.99844
# [1000]	validation_0-auc:1.00000	validation_1-auc:0.99841
# Stopping. Best iteration:
# [742]	validation_0-auc:1.00000	validation_1-auc:0.99845
#
# Fold  4 AUC : 0.998455
# [0]	validation_0-auc:0.88825	validation_1-auc:0.87919
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 300 rounds.
# [100]	validation_0-auc:1.00000	validation_1-auc:0.99924
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99930
# [300]	validation_0-auc:1.00000	validation_1-auc:0.99931
# [400]	validation_0-auc:1.00000	validation_1-auc:0.99924
# Stopping. Best iteration:
# [137]	validation_0-auc:1.00000	validation_1-auc:0.99935
#
# Fold  5 AUC : 0.999355
# Full AUC score 0.997743

# %% [markdown]
# ### ***XGB Grid Search***

# %%
# A parameter grid for XGBoost
xgb_params = {
        'min_child_weight': [0.2,0.4,0.5],
        'gamma': [0.4,0.45,0.5],
        'subsample': [0.8,0.9,0.93],
        'colsample_bytree': [0.6,0.7, 0.8],
        'max_depth': [ 4.5, 5, 5.5],
        'learning_rate' : [0.6,0.65,0.7]
        }

#24시간 뒤의 결로현상을 예측하는 교차 모델
param_comb = 5
n = 5

X = train_24_recent.drop(columns = 'after24_loc_predict')
Y = train_24_recent['after24_loc_predict']

folds= KFold(n_splits=n, shuffle = True, random_state = 1001)
xgb_clf = xgb.XGBClassifier(n_estimators = 1000)

random_search_xgb = RandomizedSearchCV(xgb_clf, param_distributions=xgb_params, n_iter=param_comb, scoring='roc_auc', n_jobs=1, cv=folds.split(X,Y), verbose=10, random_state=1001 )

# Here we go
start_time = time.time() # timing starts from this point for "start_time" variable
random_search_xgb.fit(X, Y)
print('걸린 시간 : ', time.time() - start_time) # timing ends here for "start_time" variable

# %%
print('------------------------------------')
print(xgb_params)
print('------------------------------------')
print(random_search_xgb.best_estimator_)
print('------------------------------------')
print(random_search_xgb.best_params_)
print('------------------------------------')
print(random_search_xgb.best_score_)
print('------------------------------------')

# %% [markdown]
# # ***LGBM***

# %%
def LGBM_classifier(df, test_df, target_variable, num_folds,cut_off , real_train = False):
    
    if real_train == False:
        X_train, X_test, y_train, y_test = train_test_split(df.drop(columns = target_variable),df[target_variable],test_size = 0.25, random_state = 0)

        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)

        oof_preds = np.zeros(X_train.shape[0])
        test_preds = np.zeros(X_test.shape[0])
        feature_importance_df = pd.DataFrame()

        for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_train,y_train)):

            train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
            valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]

            # 파라미터 삽입
            '''params = {}boosting_type='gbdt', class_weight='balanced',
               colsample_bytree=0.8, gamma=0.4, importance_type='split',
               learning_rate=0.6, max_depth=5, min_child_samples=20,
               min_child_weight=0.5, min_split_gain=0.0,
               n_estimators=1000, n_jobs=-1, num_leaves=31, objective=None,
               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
               subsample=0.8, subsample_for_bin=200000, subsample_freq=0'''
            clf = lgb.LGBMClassifier(
                                    boosting_type='gbdt', class_weight='balanced',
               colsample_bytree=0.8, gamma=0.4, importance_type='split',
               learning_rate=0.6, max_depth=5, min_child_samples=20,
               min_child_weight=0.5, min_split_gain=0.0,
               n_estimators=1000, n_jobs=-1, num_leaves=31, objective=None,
               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
               subsample=0.8, subsample_for_bin=200000, subsample_freq=0)


            # 모델 평가척도로 어떤것을 사용할 것인지
            clf.fit(train_x, train_y, eval_set = [(train_x, train_y), (valid_x, valid_y)], 
                   eval_metric='auc', verbose= 100, early_stopping_rounds=300)

            oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration = clf.best_iteration_)[:,1]
            test_preds += clf.predict_proba(X_test, num_iteration = clf.best_iteration_)[:,1] / folds.n_splits

            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = X_train.columns
            fold_importance_df["importance"] = clf.feature_importances_
            fold_importance_df["fold"] = n_fold + 1
            feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

            print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))

            del clf, train_x, train_y, valid_x, valid_y
            gc.collect()

        print('Full AUC score %.6f' % roc_auc_score(y_train, oof_preds))

        feature_importance_fin = feature_importance_df[["feature", "importance"]].\
                                groupby("feature").mean().sort_values(by="importance", ascending=False)

        preds = []

        for i in range(len(test_preds)):
            if test_preds[i] >= cut_off:

                preds.append(1)
            else:
                preds.append(0)

        print('Test AUC score : ', roc_auc_score(y_test, test_preds))
        conf_matrix = confusion_matrix(y_test, preds,labels = [1,0])
        
        plt.figure(figsize = (16,12))
        plt.barh(feature_importance_fin.index,feature_importance_fin['importance'])


        return test_preds, preds, y_test, feature_importance_fin, conf_matrix
    
    elif real_train == True:
        
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=1001)
        
        test_preds = np.zeros(test_df.shape[0])
        feature_importance_df = pd.DataFrame()
        
        X_train = df.drop(columns = target_variable)
        y_train = df[target_variable]
        
        oof_preds = np.zeros(X_train.shape[0])
        
        test_df = test_df[X_train.columns.tolist()] #컬럼 순서를 맞춰주기 위한 장치
        
        for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X_train,y_train)):

            train_x, train_y = X_train.iloc[train_idx], y_train.iloc[train_idx]
            valid_x, valid_y = X_train.iloc[valid_idx], y_train.iloc[valid_idx]

            # 파라미터 삽입
            '''params = {}'''
            clf = lgb.LGBMClassifier(class_weight = 'balanced', n_estimators = 2000)

            # 모델 평가척도로 어떤것을 사용할 것인지
            clf.fit(train_x, train_y, eval_set = [(train_x, train_y), (valid_x, valid_y)], 
                   eval_metric='auc', verbose= 100, early_stopping_rounds=300)

            oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration = clf.best_iteration_)[:,1]
            test_preds += clf.predict_proba(test_df, num_iteration = clf.best_iteration_)[:,1] / folds.n_splits

            fold_importance_df = pd.DataFrame()
            fold_importance_df["feature"] = X_train.columns
            fold_importance_df["importance"] = clf.feature_importances_
            fold_importance_df["fold"] = n_fold + 1
            feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

            print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))

            del clf, train_x, train_y, valid_x, valid_y
            gc.collect()

        print('Full AUC score %.6f' % roc_auc_score(y_train, oof_preds))

        feature_importance_fin = feature_importance_df[["feature", "importance"]].\
                                groupby("feature").mean().sort_values(by="importance", ascending=False)

        preds = []

        for i in range(len(test_preds)):
            if test_preds[i] >= cut_off:

                preds.append(1)
            else:
                preds.append(0)
                
        plt.figure(figsize = (16,12))
        plt.barh(feature_importance_fin.index,feature_importance_fin['importance'])


        return test_preds, preds, feature_importance_fin

# %% [markdown]
# ### ***Validation***

# %% [markdown]
# ***제출 데이터셋 검증***

# %%
test_preds_lgb24, preds_lgb24, y_test_lgb24, feature_importance_fin_lgb24, conf_matrix_lgb24 = LGBM_classifier(\
                                                                                train_24_recent,
                                                                                dj_ts_aws_recent,
                                                                                'after24_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = False)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999943	training's binary_logloss: 0.0114272	valid_1's auc: 0.999189	valid_1's binary_logloss: 0.0159969
# [200]	training's auc: 0.999999	training's binary_logloss: 0.00232583	valid_1's auc: 0.999325	valid_1's binary_logloss: 0.00679681
# [300]	training's auc: 1	training's binary_logloss: 0.000590323	valid_1's auc: 0.999421	valid_1's binary_logloss: 0.00549729
# [400]	training's auc: 1	training's binary_logloss: 0.000174304	valid_1's auc: 0.999438	valid_1's binary_logloss: 0.00542738
# [500]	training's auc: 1	training's binary_logloss: 5.17961e-05	valid_1's auc: 0.9994	valid_1's binary_logloss: 0.00580556
# [600]	training's auc: 1	training's binary_logloss: 1.64391e-05	valid_1's auc: 0.999465	valid_1's binary_logloss: 0.0061831
# Early stopping, best iteration is:
# [346]	training's auc: 1	training's binary_logloss: 0.00033637	valid_1's auc: 0.999413	valid_1's binary_logloss: 0.00540219
# Fold  1 AUC : 0.999413
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999951	training's binary_logloss: 0.0108478	valid_1's auc: 0.997225	valid_1's binary_logloss: 0.0154721
# [200]	training's auc: 0.999997	training's binary_logloss: 0.00215267	valid_1's auc: 0.997763	valid_1's binary_logloss: 0.00688869
# [300]	training's auc: 1	training's binary_logloss: 0.000593596	valid_1's auc: 0.997919	valid_1's binary_logloss: 0.00587453
# [400]	training's auc: 1	training's binary_logloss: 0.000182764	valid_1's auc: 0.997874	valid_1's binary_logloss: 0.00594915
# [500]	training's auc: 1	training's binary_logloss: 5.62952e-05	valid_1's auc: 0.99755	valid_1's binary_logloss: 0.00643272
# [600]	training's auc: 1	training's binary_logloss: 1.73746e-05	valid_1's auc: 0.997564	valid_1's binary_logloss: 0.0070837
# Early stopping, best iteration is:
# [310]	training's auc: 1	training's binary_logloss: 0.000521461	valid_1's auc: 0.997977	valid_1's binary_logloss: 0.00586697
# Fold  2 AUC : 0.997977
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99993	training's binary_logloss: 0.0110891	valid_1's auc: 0.998561	valid_1's binary_logloss: 0.0159665
# [200]	training's auc: 0.999997	training's binary_logloss: 0.00226072	valid_1's auc: 0.998382	valid_1's binary_logloss: 0.00733919
# [300]	training's auc: 1	training's binary_logloss: 0.000583858	valid_1's auc: 0.998328	valid_1's binary_logloss: 0.00629644
# [400]	training's auc: 1	training's binary_logloss: 0.000178534	valid_1's auc: 0.998613	valid_1's binary_logloss: 0.00641328
# [500]	training's auc: 1	training's binary_logloss: 5.55024e-05	valid_1's auc: 0.998669	valid_1's binary_logloss: 0.00688556
# [600]	training's auc: 1	training's binary_logloss: 1.72415e-05	valid_1's auc: 0.998751	valid_1's binary_logloss: 0.00749064
# Early stopping, best iteration is:
# [334]	training's auc: 1	training's binary_logloss: 0.000387769	valid_1's auc: 0.998547	valid_1's binary_logloss: 0.00624502
# Fold  3 AUC : 0.998547
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999922	training's binary_logloss: 0.0111116	valid_1's auc: 0.998937	valid_1's binary_logloss: 0.0161278
# [200]	training's auc: 0.999999	training's binary_logloss: 0.00224796	valid_1's auc: 0.999189	valid_1's binary_logloss: 0.00678058
# [300]	training's auc: 1	training's binary_logloss: 0.000594389	valid_1's auc: 0.999257	valid_1's binary_logloss: 0.00517994
# [400]	training's auc: 1	training's binary_logloss: 0.000181168	valid_1's auc: 0.999284	valid_1's binary_logloss: 0.00492611
# [500]	training's auc: 1	training's binary_logloss: 5.64628e-05	valid_1's auc: 0.999372	valid_1's binary_logloss: 0.00506528
# [600]	training's auc: 1	training's binary_logloss: 1.81915e-05	valid_1's auc: 0.999358	valid_1's binary_logloss: 0.00537386
# [700]	training's auc: 1	training's binary_logloss: 5.9136e-06	valid_1's auc: 0.999368	valid_1's binary_logloss: 0.00577612
# Early stopping, best iteration is:
# [426]	training's auc: 1	training's binary_logloss: 0.000130735	valid_1's auc: 0.999337	valid_1's binary_logloss: 0.00491238
# Fold  4 AUC : 0.999337
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999926	training's binary_logloss: 0.0115181	valid_1's auc: 0.997312	valid_1's binary_logloss: 0.0155114
# [200]	training's auc: 0.999998	training's binary_logloss: 0.00240767	valid_1's auc: 0.991292	valid_1's binary_logloss: 0.00759263
# [300]	training's auc: 1	training's binary_logloss: 0.000633724	valid_1's auc: 0.991392	valid_1's binary_logloss: 0.00624218
# [400]	training's auc: 1	training's binary_logloss: 0.000192606	valid_1's auc: 0.992273	valid_1's binary_logloss: 0.00617447
# Early stopping, best iteration is:
# [119]	training's auc: 0.999962	training's binary_logloss: 0.00834349	valid_1's auc: 0.997792	valid_1's binary_logloss: 0.0123092
# Fold  5 AUC : 0.997792
# Full AUC score 0.997868
# Test AUC score :  0.9993036055345553

# %%
test_preds_lgb48, preds_lgb48, y_test_lgb48, feature_importance_fin_lgb48, conf_matrix_lgb48 = LGBM_classifier(\
                                                                                train_48_recent,
                                                                                dj_ts_aws_recent,
                                                                                'after48_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = False)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999891	training's binary_logloss: 0.0197363	valid_1's auc: 0.998743	valid_1's binary_logloss: 0.0242806
# [200]	training's auc: 0.999999	training's binary_logloss: 0.00459519	valid_1's auc: 0.996901	valid_1's binary_logloss: 0.00855437
# [300]	training's auc: 1	training's binary_logloss: 0.0014465	valid_1's auc: 0.998177	valid_1's binary_logloss: 0.00568788
# [400]	training's auc: 1	training's binary_logloss: 0.00049181	valid_1's auc: 0.998608	valid_1's binary_logloss: 0.0049813
# Early stopping, best iteration is:
# [116]	training's auc: 0.999935	training's binary_logloss: 0.015261	valid_1's auc: 0.998796	valid_1's binary_logloss: 0.019658
# Fold  1 AUC : 0.998796
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999883	training's binary_logloss: 0.01951	valid_1's auc: 0.997891	valid_1's binary_logloss: 0.0251278
# [200]	training's auc: 0.999998	training's binary_logloss: 0.00467285	valid_1's auc: 0.998739	valid_1's binary_logloss: 0.00881558
# [300]	training's auc: 1	training's binary_logloss: 0.00143473	valid_1's auc: 0.99904	valid_1's binary_logloss: 0.00571488
# [400]	training's auc: 1	training's binary_logloss: 0.000489839	valid_1's auc: 0.999145	valid_1's binary_logloss: 0.00509078
# [500]	training's auc: 1	training's binary_logloss: 0.000178003	valid_1's auc: 0.999148	valid_1's binary_logloss: 0.00519717
# [600]	training's auc: 1	training's binary_logloss: 6.57145e-05	valid_1's auc: 0.999106	valid_1's binary_logloss: 0.0055676
# [700]	training's auc: 1	training's binary_logloss: 2.4905e-05	valid_1's auc: 0.999028	valid_1's binary_logloss: 0.00602126
# Early stopping, best iteration is:
# [415]	training's auc: 1	training's binary_logloss: 0.000411868	valid_1's auc: 0.999159	valid_1's binary_logloss: 0.00500016
# Fold  2 AUC : 0.999159
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999893	training's binary_logloss: 0.0194565	valid_1's auc: 0.997234	valid_1's binary_logloss: 0.0237819
# [200]	training's auc: 0.999995	training's binary_logloss: 0.00450165	valid_1's auc: 0.997763	valid_1's binary_logloss: 0.00820788
# [300]	training's auc: 1	training's binary_logloss: 0.00134659	valid_1's auc: 0.999102	valid_1's binary_logloss: 0.00547762
# [400]	training's auc: 1	training's binary_logloss: 0.000455124	valid_1's auc: 0.999381	valid_1's binary_logloss: 0.00498267
# [500]	training's auc: 1	training's binary_logloss: 0.000165703	valid_1's auc: 0.999439	valid_1's binary_logloss: 0.00512782
# [600]	training's auc: 1	training's binary_logloss: 6.23816e-05	valid_1's auc: 0.99944	valid_1's binary_logloss: 0.00542462
# [700]	training's auc: 1	training's binary_logloss: 2.17833e-05	valid_1's auc: 0.999451	valid_1's binary_logloss: 0.00570187
# Early stopping, best iteration is:
# [407]	training's auc: 1	training's binary_logloss: 0.00042199	valid_1's auc: 0.999395	valid_1's binary_logloss: 0.00495171
# Fold  3 AUC : 0.999395
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999894	training's binary_logloss: 0.019062	valid_1's auc: 0.997807	valid_1's binary_logloss: 0.0244428
# [200]	training's auc: 0.999996	training's binary_logloss: 0.00443588	valid_1's auc: 0.994961	valid_1's binary_logloss: 0.00950673
# [300]	training's auc: 1	training's binary_logloss: 0.00130355	valid_1's auc: 0.993939	valid_1's binary_logloss: 0.00692472
# [400]	training's auc: 1	training's binary_logloss: 0.000424902	valid_1's auc: 0.994338	valid_1's binary_logloss: 0.00640215
# Early stopping, best iteration is:
# [148]	training's auc: 0.999968	training's binary_logloss: 0.00895976	valid_1's auc: 0.99853	valid_1's binary_logloss: 0.0133873
# Fold  4 AUC : 0.998530
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999904	training's binary_logloss: 0.0191923	valid_1's auc: 0.995577	valid_1's binary_logloss: 0.0239846
# [200]	training's auc: 0.999998	training's binary_logloss: 0.00444069	valid_1's auc: 0.99618	valid_1's binary_logloss: 0.0087588
# [300]	training's auc: 1	training's binary_logloss: 0.00133474	valid_1's auc: 0.995584	valid_1's binary_logloss: 0.00659811
# [400]	training's auc: 1	training's binary_logloss: 0.000453385	valid_1's auc: 0.994696	valid_1's binary_logloss: 0.00640408
# Early stopping, best iteration is:
# [183]	training's auc: 0.999996	training's binary_logloss: 0.0055158	valid_1's auc: 0.996371	valid_1's binary_logloss: 0.00976389
# Fold  5 AUC : 0.996371
# Full AUC score 0.997396
# Test AUC score :  0.9958924957656586

# %% [markdown]
# ***aws + 베이스 데이터만***

# %%
test_preds_lgb24, preds_lgb24_aws, y_test_lgb24_aws, feature_importance_fin_lgb24_aws, conf_matrix_lgb24_aws = LGBM_classifier(\
                                                                                train_24_recent_aws,
                                                                                dj_ts_aws_recent_aws,
                                                                                'after24_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = False)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999609	training's binary_logloss: 0.0375258	valid_1's auc: 0.994027	valid_1's binary_logloss: 0.0461455
# [200]	training's auc: 0.999973	training's binary_logloss: 0.0114254	valid_1's auc: 0.994066	valid_1's binary_logloss: 0.0172049
# [300]	training's auc: 0.999999	training's binary_logloss: 0.00454537	valid_1's auc: 0.99427	valid_1's binary_logloss: 0.0103192
# [400]	training's auc: 1	training's binary_logloss: 0.00193479	valid_1's auc: 0.995192	valid_1's binary_logloss: 0.00797136
# [500]	training's auc: 1	training's binary_logloss: 0.000840728	valid_1's auc: 0.995158	valid_1's binary_logloss: 0.00713323
# [600]	training's auc: 1	training's binary_logloss: 0.000403695	valid_1's auc: 0.995471	valid_1's binary_logloss: 0.00710396
# [700]	training's auc: 1	training's binary_logloss: 0.000190714	valid_1's auc: 0.995365	valid_1's binary_logloss: 0.0072952
# [800]	training's auc: 1	training's binary_logloss: 8.87335e-05	valid_1's auc: 0.995796	valid_1's binary_logloss: 0.00747511
# Early stopping, best iteration is:
# [552]	training's auc: 1	training's binary_logloss: 0.00056761	valid_1's auc: 0.995285	valid_1's binary_logloss: 0.00706455
# Fold  1 AUC : 0.995285
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999632	training's binary_logloss: 0.0371201	valid_1's auc: 0.992774	valid_1's binary_logloss: 0.0461147
# [200]	training's auc: 0.999972	training's binary_logloss: 0.0120137	valid_1's auc: 0.993938	valid_1's binary_logloss: 0.0179863
# [300]	training's auc: 0.999998	training's binary_logloss: 0.00455149	valid_1's auc: 0.994374	valid_1's binary_logloss: 0.0104585
# [400]	training's auc: 1	training's binary_logloss: 0.00195207	valid_1's auc: 0.994256	valid_1's binary_logloss: 0.00833378
# [500]	training's auc: 1	training's binary_logloss: 0.000877954	valid_1's auc: 0.994156	valid_1's binary_logloss: 0.00766717
# Early stopping, best iteration is:
# [280]	training's auc: 0.999997	training's binary_logloss: 0.00556267	valid_1's auc: 0.994538	valid_1's binary_logloss: 0.0113671
# Fold  2 AUC : 0.994538
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99968	training's binary_logloss: 0.034228	valid_1's auc: 0.992752	valid_1's binary_logloss: 0.0432297
# [200]	training's auc: 0.999962	training's binary_logloss: 0.0115992	valid_1's auc: 0.993762	valid_1's binary_logloss: 0.0183818
# [300]	training's auc: 0.999997	training's binary_logloss: 0.00441565	valid_1's auc: 0.992927	valid_1's binary_logloss: 0.0110289
# [400]	training's auc: 1	training's binary_logloss: 0.00187395	valid_1's auc: 0.993484	valid_1's binary_logloss: 0.00885498
# [500]	training's auc: 1	training's binary_logloss: 0.000798949	valid_1's auc: 0.99452	valid_1's binary_logloss: 0.00809847
# [600]	training's auc: 1	training's binary_logloss: 0.000359591	valid_1's auc: 0.99462	valid_1's binary_logloss: 0.00808421
# [700]	training's auc: 1	training's binary_logloss: 0.00016286	valid_1's auc: 0.994485	valid_1's binary_logloss: 0.00833959
# [800]	training's auc: 1	training's binary_logloss: 7.61574e-05	valid_1's auc: 0.994499	valid_1's binary_logloss: 0.00876903
# Early stopping, best iteration is:
# [549]	training's auc: 1	training's binary_logloss: 0.000535192	valid_1's auc: 0.994673	valid_1's binary_logloss: 0.00803405
# Fold  3 AUC : 0.994673
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999615	training's binary_logloss: 0.0368575	valid_1's auc: 0.995964	valid_1's binary_logloss: 0.0451666
# [200]	training's auc: 0.99996	training's binary_logloss: 0.0126007	valid_1's auc: 0.997116	valid_1's binary_logloss: 0.0177932
# [300]	training's auc: 0.999997	training's binary_logloss: 0.00489053	valid_1's auc: 0.997382	valid_1's binary_logloss: 0.00969647
# [400]	training's auc: 1	training's binary_logloss: 0.0021005	valid_1's auc: 0.997449	valid_1's binary_logloss: 0.00691858
# [500]	training's auc: 1	training's binary_logloss: 0.000984493	valid_1's auc: 0.997642	valid_1's binary_logloss: 0.00601958
# [600]	training's auc: 1	training's binary_logloss: 0.000460282	valid_1's auc: 0.997761	valid_1's binary_logloss: 0.00566164
# [700]	training's auc: 1	training's binary_logloss: 0.000218415	valid_1's auc: 0.997682	valid_1's binary_logloss: 0.00563729
# [800]	training's auc: 1	training's binary_logloss: 0.000103251	valid_1's auc: 0.997688	valid_1's binary_logloss: 0.00579339
# [900]	training's auc: 1	training's binary_logloss: 5.05665e-05	valid_1's auc: 0.997724	valid_1's binary_logloss: 0.0061025
# Early stopping, best iteration is:
# [604]	training's auc: 1	training's binary_logloss: 0.000444468	valid_1's auc: 0.997794	valid_1's binary_logloss: 0.00563625
# Fold  4 AUC : 0.997794
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999581	training's binary_logloss: 0.0393644	valid_1's auc: 0.99655	valid_1's binary_logloss: 0.047409
# [200]	training's auc: 0.999954	training's binary_logloss: 0.0125663	valid_1's auc: 0.997446	valid_1's binary_logloss: 0.0174777
# [300]	training's auc: 0.999998	training's binary_logloss: 0.00498332	valid_1's auc: 0.997867	valid_1's binary_logloss: 0.00941678
# [400]	training's auc: 0.999999	training's binary_logloss: 0.00212843	valid_1's auc: 0.997774	valid_1's binary_logloss: 0.0066437
# [500]	training's auc: 1	training's binary_logloss: 0.000965189	valid_1's auc: 0.997802	valid_1's binary_logloss: 0.00577612
# [600]	training's auc: 1	training's binary_logloss: 0.000456974	valid_1's auc: 0.997792	valid_1's binary_logloss: 0.0055361
# [700]	training's auc: 1	training's binary_logloss: 0.000210243	valid_1's auc: 0.997712	valid_1's binary_logloss: 0.00542196
# Early stopping, best iteration is:
# [449]	training's auc: 1	training's binary_logloss: 0.00143381	valid_1's auc: 0.997929	valid_1's binary_logloss: 0.00602666
# Fold  5 AUC : 0.997929
# Full AUC score 0.995463
# Test AUC score :  0.9971760746805499

# %%
test_preds_lgb48_aws, preds_lgb48_aws, y_test_lgb48_aws, feature_importance_fin_lgb48_aws, conf_matrix_lgb48_aws = LGBM_classifier(\
                                                                                train_48_recent_aws,
                                                                                dj_ts_aws_recent_aws,
                                                                                'after48_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = False)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999451	training's binary_logloss: 0.061804	valid_1's auc: 0.996358	valid_1's binary_logloss: 0.0708183
# [200]	training's auc: 0.99993	training's binary_logloss: 0.0208904	valid_1's auc: 0.998082	valid_1's binary_logloss: 0.0260034
# [300]	training's auc: 0.999987	training's binary_logloss: 0.00870639	valid_1's auc: 0.997956	valid_1's binary_logloss: 0.0129098
# [400]	training's auc: 0.999999	training's binary_logloss: 0.00403048	valid_1's auc: 0.998044	valid_1's binary_logloss: 0.00825435
# [500]	training's auc: 1	training's binary_logloss: 0.00196243	valid_1's auc: 0.998226	valid_1's binary_logloss: 0.00653159
# [600]	training's auc: 1	training's binary_logloss: 0.000974075	valid_1's auc: 0.998094	valid_1's binary_logloss: 0.00590613
# [700]	training's auc: 1	training's binary_logloss: 0.000497547	valid_1's auc: 0.998251	valid_1's binary_logloss: 0.00567764
# [800]	training's auc: 1	training's binary_logloss: 0.000261951	valid_1's auc: 0.998256	valid_1's binary_logloss: 0.00561891
# [900]	training's auc: 1	training's binary_logloss: 0.000140097	valid_1's auc: 0.99823	valid_1's binary_logloss: 0.00574978
# [1000]	training's auc: 1	training's binary_logloss: 7.48637e-05	valid_1's auc: 0.998223	valid_1's binary_logloss: 0.0059746
# Did not meet early stopping. Best iteration is:
# [555]	training's auc: 1	training's binary_logloss: 0.00131432	valid_1's auc: 0.998248	valid_1's binary_logloss: 0.00610664
# Fold  1 AUC : 0.998248
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999369	training's binary_logloss: 0.0591109	valid_1's auc: 0.990172	valid_1's binary_logloss: 0.0673897
# [200]	training's auc: 0.999931	training's binary_logloss: 0.0196746	valid_1's auc: 0.994215	valid_1's binary_logloss: 0.0249612
# [300]	training's auc: 0.999982	training's binary_logloss: 0.0083536	valid_1's auc: 0.995836	valid_1's binary_logloss: 0.0132686
# [400]	training's auc: 0.999996	training's binary_logloss: 0.00391539	valid_1's auc: 0.996336	valid_1's binary_logloss: 0.0091257
# [500]	training's auc: 1	training's binary_logloss: 0.00198438	valid_1's auc: 0.996472	valid_1's binary_logloss: 0.00762259
# [600]	training's auc: 1	training's binary_logloss: 0.00100228	valid_1's auc: 0.996504	valid_1's binary_logloss: 0.00712493
# [700]	training's auc: 1	training's binary_logloss: 0.000527059	valid_1's auc: 0.996601	valid_1's binary_logloss: 0.00698885
# [800]	training's auc: 1	training's binary_logloss: 0.000272066	valid_1's auc: 0.996447	valid_1's binary_logloss: 0.00706596
# [900]	training's auc: 1	training's binary_logloss: 0.00014766	valid_1's auc: 0.996569	valid_1's binary_logloss: 0.00731174
# [1000]	training's auc: 1	training's binary_logloss: 7.71385e-05	valid_1's auc: 0.996458	valid_1's binary_logloss: 0.00755483
# Did not meet early stopping. Best iteration is:
# [492]	training's auc: 1	training's binary_logloss: 0.00207108	valid_1's auc: 0.996491	valid_1's binary_logloss: 0.00767386
# Fold  2 AUC : 0.996491
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99937	training's binary_logloss: 0.0586489	valid_1's auc: 0.989921	valid_1's binary_logloss: 0.0670095
# [200]	training's auc: 0.999923	training's binary_logloss: 0.0203738	valid_1's auc: 0.993742	valid_1's binary_logloss: 0.0256097
# [300]	training's auc: 0.999979	training's binary_logloss: 0.0085861	valid_1's auc: 0.995021	valid_1's binary_logloss: 0.0133957
# [400]	training's auc: 0.999998	training's binary_logloss: 0.00397328	valid_1's auc: 0.995626	valid_1's binary_logloss: 0.00925148
# [500]	training's auc: 1	training's binary_logloss: 0.00195926	valid_1's auc: 0.995752	valid_1's binary_logloss: 0.00766623
# [600]	training's auc: 1	training's binary_logloss: 0.000994876	valid_1's auc: 0.995341	valid_1's binary_logloss: 0.00724433
# [700]	training's auc: 1	training's binary_logloss: 0.000491325	valid_1's auc: 0.995674	valid_1's binary_logloss: 0.00698055
# [800]	training's auc: 1	training's binary_logloss: 0.000254926	valid_1's auc: 0.996181	valid_1's binary_logloss: 0.00704852
# [900]	training's auc: 1	training's binary_logloss: 0.000134318	valid_1's auc: 0.996121	valid_1's binary_logloss: 0.00735314
# [1000]	training's auc: 1	training's binary_logloss: 7.12861e-05	valid_1's auc: 0.996025	valid_1's binary_logloss: 0.00771379
# Did not meet early stopping. Best iteration is:
# [619]	training's auc: 1	training's binary_logloss: 0.000861074	valid_1's auc: 0.995592	valid_1's binary_logloss: 0.00715239
# Fold  3 AUC : 0.995592
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99934	training's binary_logloss: 0.057895	valid_1's auc: 0.992598	valid_1's binary_logloss: 0.0676052
# [200]	training's auc: 0.999927	training's binary_logloss: 0.0195468	valid_1's auc: 0.993226	valid_1's binary_logloss: 0.0253278
# [300]	training's auc: 0.999982	training's binary_logloss: 0.00857791	valid_1's auc: 0.992563	valid_1's binary_logloss: 0.0134586
# [400]	training's auc: 0.999999	training's binary_logloss: 0.00393611	valid_1's auc: 0.992558	valid_1's binary_logloss: 0.0086341
# Early stopping, best iteration is:
# [127]	training's auc: 0.999712	training's binary_logloss: 0.0416351	valid_1's auc: 0.993318	valid_1's binary_logloss: 0.0496232
# Fold  4 AUC : 0.993318
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999369	training's binary_logloss: 0.0603717	valid_1's auc: 0.98889	valid_1's binary_logloss: 0.0694637
# [200]	training's auc: 0.999928	training's binary_logloss: 0.0200928	valid_1's auc: 0.991902	valid_1's binary_logloss: 0.025742
# [300]	training's auc: 0.999988	training's binary_logloss: 0.00845422	valid_1's auc: 0.99252	valid_1's binary_logloss: 0.013992
# [400]	training's auc: 1	training's binary_logloss: 0.00382548	valid_1's auc: 0.992747	valid_1's binary_logloss: 0.00976361
# [500]	training's auc: 1	training's binary_logloss: 0.0018454	valid_1's auc: 0.992433	valid_1's binary_logloss: 0.00808519
# [600]	training's auc: 1	training's binary_logloss: 0.000903358	valid_1's auc: 0.992782	valid_1's binary_logloss: 0.00739864
# [700]	training's auc: 1	training's binary_logloss: 0.000458505	valid_1's auc: 0.992869	valid_1's binary_logloss: 0.00728792
# [800]	training's auc: 1	training's binary_logloss: 0.000232171	valid_1's auc: 0.992867	valid_1's binary_logloss: 0.00743821
# [900]	training's auc: 1	training's binary_logloss: 0.00011919	valid_1's auc: 0.99289	valid_1's binary_logloss: 0.00767175
# Early stopping, best iteration is:
# [639]	training's auc: 1	training's binary_logloss: 0.000681907	valid_1's auc: 0.993115	valid_1's binary_logloss: 0.00720808
# Fold  5 AUC : 0.993115
# Full AUC score 0.991405
# Test AUC score :  0.9949576570468275

# %% [markdown]
# ***동네예보 + 베이스 데이터***

# %%
test_preds_lgb24_dong, preds_lgb24_dong, y_test_lgb24_dong, feature_importance_fin_lgb24_dong, conf_matrix_lgb24_dong = LGBM_classifier(\
                                                                                train_24_recent_dong,
                                                                                dj_ts_aws_recent_dong,
                                                                                'after24_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = False)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999765	training's binary_logloss: 0.0203227	valid_1's auc: 0.998023	valid_1's binary_logloss: 0.0274188
# [200]	training's auc: 0.999978	training's binary_logloss: 0.00637999	valid_1's auc: 0.996579	valid_1's binary_logloss: 0.0127142
# [300]	training's auc: 1	training's binary_logloss: 0.00231307	valid_1's auc: 0.997719	valid_1's binary_logloss: 0.00839273
# [400]	training's auc: 1	training's binary_logloss: 0.000931898	valid_1's auc: 0.998074	valid_1's binary_logloss: 0.0072098
# Early stopping, best iteration is:
# [112]	training's auc: 0.99984	training's binary_logloss: 0.0170322	valid_1's auc: 0.998255	valid_1's binary_logloss: 0.0235455
# Fold  1 AUC : 0.998255
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99979	training's binary_logloss: 0.019371	valid_1's auc: 0.99703	valid_1's binary_logloss: 0.0264465
# [200]	training's auc: 0.999979	training's binary_logloss: 0.00626561	valid_1's auc: 0.996952	valid_1's binary_logloss: 0.0120994
# [300]	training's auc: 0.999999	training's binary_logloss: 0.00222609	valid_1's auc: 0.996689	valid_1's binary_logloss: 0.00845685
# [400]	training's auc: 1	training's binary_logloss: 0.000881444	valid_1's auc: 0.996545	valid_1's binary_logloss: 0.00760305
# Early stopping, best iteration is:
# [134]	training's auc: 0.999922	training's binary_logloss: 0.0126298	valid_1's auc: 0.997405	valid_1's binary_logloss: 0.0189149
# Fold  2 AUC : 0.997405
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999759	training's binary_logloss: 0.0199419	valid_1's auc: 0.997929	valid_1's binary_logloss: 0.0261165
# [200]	training's auc: 0.999978	training's binary_logloss: 0.00605605	valid_1's auc: 0.994929	valid_1's binary_logloss: 0.0113724
# [300]	training's auc: 0.999998	training's binary_logloss: 0.00222423	valid_1's auc: 0.99465	valid_1's binary_logloss: 0.00805746
# [400]	training's auc: 1	training's binary_logloss: 0.000853558	valid_1's auc: 0.994674	valid_1's binary_logloss: 0.0071169
# Early stopping, best iteration is:
# [139]	training's auc: 0.999901	training's binary_logloss: 0.0121103	valid_1's auc: 0.998151	valid_1's binary_logloss: 0.0170094
# Fold  3 AUC : 0.998151
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99973	training's binary_logloss: 0.0201754	valid_1's auc: 0.997966	valid_1's binary_logloss: 0.0283246
# [200]	training's auc: 0.999974	training's binary_logloss: 0.00626838	valid_1's auc: 0.997184	valid_1's binary_logloss: 0.0118935
# [300]	training's auc: 1	training's binary_logloss: 0.00237755	valid_1's auc: 0.997937	valid_1's binary_logloss: 0.00741139
# [400]	training's auc: 1	training's binary_logloss: 0.000896316	valid_1's auc: 0.998335	valid_1's binary_logloss: 0.00594716
# Early stopping, best iteration is:
# [151]	training's auc: 0.999932	training's binary_logloss: 0.0106685	valid_1's auc: 0.998463	valid_1's binary_logloss: 0.0168268
# Fold  4 AUC : 0.998463
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999752	training's binary_logloss: 0.0209217	valid_1's auc: 0.998226	valid_1's binary_logloss: 0.026341
# [200]	training's auc: 0.999977	training's binary_logloss: 0.00644897	valid_1's auc: 0.995673	valid_1's binary_logloss: 0.0116512
# [300]	training's auc: 0.999999	training's binary_logloss: 0.00235599	valid_1's auc: 0.997066	valid_1's binary_logloss: 0.00811232
# [400]	training's auc: 1	training's binary_logloss: 0.000966009	valid_1's auc: 0.997791	valid_1's binary_logloss: 0.00672654
# Early stopping, best iteration is:
# [135]	training's auc: 0.999892	training's binary_logloss: 0.013233	valid_1's auc: 0.998323	valid_1's binary_logloss: 0.0179649
# Fold  5 AUC : 0.998323
# Full AUC score 0.998058
# Test AUC score :  0.9988687615840313

# %%
test_preds_lgb48_dong, preds_lgb48_dong, y_test_lgb48_dong, feature_importance_fin_lgb48_dong, conf_matrix_lgb48_dong = LGBM_classifier(\
                                                                                train_48_recent_dong,
                                                                                dj_ts_aws_recent_dong,
                                                                                'after48_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = False)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999509	training's binary_logloss: 0.0453691	valid_1's auc: 0.995853	valid_1's binary_logloss: 0.0535358
# [200]	training's auc: 0.999936	training's binary_logloss: 0.0156984	valid_1's auc: 0.99625	valid_1's binary_logloss: 0.0203403
# [300]	training's auc: 0.999995	training's binary_logloss: 0.00684386	valid_1's auc: 0.99589	valid_1's binary_logloss: 0.0113717
# [400]	training's auc: 1	training's binary_logloss: 0.00306994	valid_1's auc: 0.995132	valid_1's binary_logloss: 0.00772974
# Early stopping, best iteration is:
# [179]	training's auc: 0.99991	training's binary_logloss: 0.0190936	valid_1's auc: 0.996441	valid_1's binary_logloss: 0.0240002
# Fold  1 AUC : 0.996441
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999462	training's binary_logloss: 0.0457223	valid_1's auc: 0.994646	valid_1's binary_logloss: 0.0548454
# [200]	training's auc: 0.999925	training's binary_logloss: 0.0155041	valid_1's auc: 0.996455	valid_1's binary_logloss: 0.0214047
# [300]	training's auc: 0.999988	training's binary_logloss: 0.00630339	valid_1's auc: 0.996742	valid_1's binary_logloss: 0.0116806
# [400]	training's auc: 0.999999	training's binary_logloss: 0.0027952	valid_1's auc: 0.997125	valid_1's binary_logloss: 0.00823858
# [500]	training's auc: 1	training's binary_logloss: 0.00134651	valid_1's auc: 0.996994	valid_1's binary_logloss: 0.00716834
# [600]	training's auc: 1	training's binary_logloss: 0.000681778	valid_1's auc: 0.996923	valid_1's binary_logloss: 0.00677588
# [700]	training's auc: 1	training's binary_logloss: 0.000347302	valid_1's auc: 0.997118	valid_1's binary_logloss: 0.00664561
# Early stopping, best iteration is:
# [413]	training's auc: 1	training's binary_logloss: 0.00254711	valid_1's auc: 0.997245	valid_1's binary_logloss: 0.00803983
# Fold  2 AUC : 0.997245
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999542	training's binary_logloss: 0.0460101	valid_1's auc: 0.992003	valid_1's binary_logloss: 0.054781
# [200]	training's auc: 0.999924	training's binary_logloss: 0.0157576	valid_1's auc: 0.994319	valid_1's binary_logloss: 0.0209591
# [300]	training's auc: 0.999987	training's binary_logloss: 0.0066156	valid_1's auc: 0.994734	valid_1's binary_logloss: 0.0115857
# [400]	training's auc: 0.999997	training's binary_logloss: 0.00303163	valid_1's auc: 0.995564	valid_1's binary_logloss: 0.00831914
# [500]	training's auc: 1	training's binary_logloss: 0.00142918	valid_1's auc: 0.995595	valid_1's binary_logloss: 0.00703318
# [600]	training's auc: 1	training's binary_logloss: 0.000704928	valid_1's auc: 0.995806	valid_1's binary_logloss: 0.00659522
# [700]	training's auc: 1	training's binary_logloss: 0.000347003	valid_1's auc: 0.996096	valid_1's binary_logloss: 0.00654524
# [800]	training's auc: 1	training's binary_logloss: 0.000176528	valid_1's auc: 0.996422	valid_1's binary_logloss: 0.00652882
# [900]	training's auc: 1	training's binary_logloss: 9.18309e-05	valid_1's auc: 0.996484	valid_1's binary_logloss: 0.00664527
# Early stopping, best iteration is:
# [652]	training's auc: 1	training's binary_logloss: 0.000486257	valid_1's auc: 0.996021	valid_1's binary_logloss: 0.0064911
# Fold  3 AUC : 0.996021
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999537	training's binary_logloss: 0.0441646	valid_1's auc: 0.994327	valid_1's binary_logloss: 0.0547316
# [200]	training's auc: 0.999932	training's binary_logloss: 0.0157773	valid_1's auc: 0.995784	valid_1's binary_logloss: 0.0223897
# [300]	training's auc: 0.999987	training's binary_logloss: 0.00650478	valid_1's auc: 0.99615	valid_1's binary_logloss: 0.0120643
# [400]	training's auc: 0.999995	training's binary_logloss: 0.00295388	valid_1's auc: 0.99625	valid_1's binary_logloss: 0.00827219
# [500]	training's auc: 1	training's binary_logloss: 0.00144638	valid_1's auc: 0.996068	valid_1's binary_logloss: 0.00686487
# [600]	training's auc: 1	training's binary_logloss: 0.000711887	valid_1's auc: 0.996068	valid_1's binary_logloss: 0.00635194
# [700]	training's auc: 1	training's binary_logloss: 0.000358432	valid_1's auc: 0.996	valid_1's binary_logloss: 0.00625411
# Early stopping, best iteration is:
# [454]	training's auc: 1	training's binary_logloss: 0.00197447	valid_1's auc: 0.996364	valid_1's binary_logloss: 0.00734488
# Fold  4 AUC : 0.996364
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999559	training's binary_logloss: 0.0450888	valid_1's auc: 0.993939	valid_1's binary_logloss: 0.0545025
# [200]	training's auc: 0.999942	training's binary_logloss: 0.0154262	valid_1's auc: 0.99593	valid_1's binary_logloss: 0.021245
# [300]	training's auc: 0.999986	training's binary_logloss: 0.00649851	valid_1's auc: 0.996584	valid_1's binary_logloss: 0.0120079
# [400]	training's auc: 0.999999	training's binary_logloss: 0.0029063	valid_1's auc: 0.995185	valid_1's binary_logloss: 0.00883759
# [500]	training's auc: 1	training's binary_logloss: 0.00137246	valid_1's auc: 0.99579	valid_1's binary_logloss: 0.00754574
# [600]	training's auc: 1	training's binary_logloss: 0.000666039	valid_1's auc: 0.99629	valid_1's binary_logloss: 0.00720031
# Early stopping, best iteration is:
# [344]	training's auc: 0.999996	training's binary_logloss: 0.00456067	valid_1's auc: 0.996752	valid_1's binary_logloss: 0.0101476
# Fold  5 AUC : 0.996752
# Full AUC score 0.994766
# Test AUC score :  0.9942273200746262

# %% [markdown]
# ### ***Real Test Prediction***

# %%
test_preds_lgb24, preds_lgb24, feature_importance_fin_lgb24 = LGBM_classifier(\
                                                                                train_24_recent,
                                                                                dj_ts_aws_recent,
                                                                                'after24_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = True)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999912	training's binary_logloss: 0.0123587	valid_1's auc: 0.998836	valid_1's binary_logloss: 0.0177664
# [200]	training's auc: 0.999995	training's binary_logloss: 0.00299121	valid_1's auc: 0.99642	valid_1's binary_logloss: 0.00789134
# [300]	training's auc: 1	training's binary_logloss: 0.000893067	valid_1's auc: 0.99723	valid_1's binary_logloss: 0.00597184
# [400]	training's auc: 1	training's binary_logloss: 0.000319115	valid_1's auc: 0.997818	valid_1's binary_logloss: 0.00555538
# Early stopping, best iteration is:
# [108]	training's auc: 0.999929	training's binary_logloss: 0.0107532	valid_1's auc: 0.998889	valid_1's binary_logloss: 0.0159128
# Fold  1 AUC : 0.998889
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999903	training's binary_logloss: 0.0130823	valid_1's auc: 0.999154	valid_1's binary_logloss: 0.0162019
# [200]	training's auc: 0.999998	training's binary_logloss: 0.00302112	valid_1's auc: 0.999299	valid_1's binary_logloss: 0.00657326
# [300]	training's auc: 1	training's binary_logloss: 0.00097252	valid_1's auc: 0.999126	valid_1's binary_logloss: 0.00519345
# [400]	training's auc: 1	training's binary_logloss: 0.000346035	valid_1's auc: 0.998941	valid_1's binary_logloss: 0.00502369
# Early stopping, best iteration is:
# [194]	training's auc: 0.999998	training's binary_logloss: 0.00331088	valid_1's auc: 0.999322	valid_1's binary_logloss: 0.00675232
# Fold  2 AUC : 0.999322
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99989	training's binary_logloss: 0.0131358	valid_1's auc: 0.99869	valid_1's binary_logloss: 0.0173393
# [200]	training's auc: 0.999996	training's binary_logloss: 0.00321464	valid_1's auc: 0.998825	valid_1's binary_logloss: 0.00688684
# [300]	training's auc: 1	training's binary_logloss: 0.00100747	valid_1's auc: 0.998823	valid_1's binary_logloss: 0.00508834
# [400]	training's auc: 1	training's binary_logloss: 0.000367792	valid_1's auc: 0.998809	valid_1's binary_logloss: 0.00462326
# [500]	training's auc: 1	training's binary_logloss: 0.000138682	valid_1's auc: 0.998696	valid_1's binary_logloss: 0.00466697
# [600]	training's auc: 1	training's binary_logloss: 5.39288e-05	valid_1's auc: 0.998552	valid_1's binary_logloss: 0.00483
# [700]	training's auc: 1	training's binary_logloss: 2.15778e-05	valid_1's auc: 0.998597	valid_1's binary_logloss: 0.00497821
# Early stopping, best iteration is:
# [430]	training's auc: 1	training's binary_logloss: 0.00027455	valid_1's auc: 0.99887	valid_1's binary_logloss: 0.00459136
# Fold  3 AUC : 0.998870
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999885	training's binary_logloss: 0.0130181	valid_1's auc: 0.998795	valid_1's binary_logloss: 0.0182772
# [200]	training's auc: 0.999991	training's binary_logloss: 0.00306919	valid_1's auc: 0.996308	valid_1's binary_logloss: 0.00770903
# [300]	training's auc: 1	training's binary_logloss: 0.000925021	valid_1's auc: 0.997009	valid_1's binary_logloss: 0.00575703
# [400]	training's auc: 1	training's binary_logloss: 0.000333066	valid_1's auc: 0.99789	valid_1's binary_logloss: 0.00529309
# Early stopping, best iteration is:
# [129]	training's auc: 0.999942	training's binary_logloss: 0.00805445	valid_1's auc: 0.998964	valid_1's binary_logloss: 0.0125389
# Fold  4 AUC : 0.998964
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999921	training's binary_logloss: 0.0127771	valid_1's auc: 0.999034	valid_1's binary_logloss: 0.0172075
# [200]	training's auc: 0.999997	training's binary_logloss: 0.00308877	valid_1's auc: 0.996801	valid_1's binary_logloss: 0.00748201
# [300]	training's auc: 1	training's binary_logloss: 0.000961238	valid_1's auc: 0.99694	valid_1's binary_logloss: 0.00573258
# [400]	training's auc: 1	training's binary_logloss: 0.00034673	valid_1's auc: 0.997129	valid_1's binary_logloss: 0.00536616
# Early stopping, best iteration is:
# [157]	training's auc: 0.99998	training's binary_logloss: 0.0054874	valid_1's auc: 0.999294	valid_1's binary_logloss: 0.00938558
# Fold  5 AUC : 0.999294
# Full AUC score 0.998125

# %%
# 변수중요도를 통한 변수 제거
train_lgb24_remove = train_lgb24_df.drop(columns = feature_importance_fin_lgb24.tail(3).index.tolist())
test_lgb24_remove = test_lgb24_df.drop(columns = feature_importance_fin_lgb24.tail(3).index.tolist())

# %%
remove_test_preds_lgb24, remove_preds_lgb24, remove_feature_importance_fin_lgb24 = LGBM_classifier(\
                                                                                train_lgb24_remove,
                                                                                test_lgb24_remove,
                                                                                'after24_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = True)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999912	training's binary_logloss: 0.0123587	valid_1's auc: 0.998836	valid_1's binary_logloss: 0.0177664
# [200]	training's auc: 0.999995	training's binary_logloss: 0.00299121	valid_1's auc: 0.99642	valid_1's binary_logloss: 0.00789134
# [300]	training's auc: 1	training's binary_logloss: 0.000893067	valid_1's auc: 0.99723	valid_1's binary_logloss: 0.00597184
# [400]	training's auc: 1	training's binary_logloss: 0.000319115	valid_1's auc: 0.997818	valid_1's binary_logloss: 0.00555538
# Early stopping, best iteration is:
# [108]	training's auc: 0.999929	training's binary_logloss: 0.0107532	valid_1's auc: 0.998889	valid_1's binary_logloss: 0.0159128
# Fold  1 AUC : 0.998889
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999903	training's binary_logloss: 0.0130823	valid_1's auc: 0.999154	valid_1's binary_logloss: 0.0162019
# [200]	training's auc: 0.999998	training's binary_logloss: 0.00302112	valid_1's auc: 0.999299	valid_1's binary_logloss: 0.00657326
# [300]	training's auc: 1	training's binary_logloss: 0.00097252	valid_1's auc: 0.999126	valid_1's binary_logloss: 0.00519345
# [400]	training's auc: 1	training's binary_logloss: 0.000346035	valid_1's auc: 0.998941	valid_1's binary_logloss: 0.00502369
# Early stopping, best iteration is:
# [194]	training's auc: 0.999998	training's binary_logloss: 0.00331088	valid_1's auc: 0.999322	valid_1's binary_logloss: 0.00675232
# Fold  2 AUC : 0.999322
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99989	training's binary_logloss: 0.0131358	valid_1's auc: 0.99869	valid_1's binary_logloss: 0.0173393
# [200]	training's auc: 0.999996	training's binary_logloss: 0.00321464	valid_1's auc: 0.998825	valid_1's binary_logloss: 0.00688684
# [300]	training's auc: 1	training's binary_logloss: 0.00100747	valid_1's auc: 0.998823	valid_1's binary_logloss: 0.00508834
# [400]	training's auc: 1	training's binary_logloss: 0.000367792	valid_1's auc: 0.998809	valid_1's binary_logloss: 0.00462326
# [500]	training's auc: 1	training's binary_logloss: 0.000138682	valid_1's auc: 0.998696	valid_1's binary_logloss: 0.00466697
# [600]	training's auc: 1	training's binary_logloss: 5.39288e-05	valid_1's auc: 0.998552	valid_1's binary_logloss: 0.00483
# [700]	training's auc: 1	training's binary_logloss: 2.15778e-05	valid_1's auc: 0.998597	valid_1's binary_logloss: 0.00497821
# Early stopping, best iteration is:
# [430]	training's auc: 1	training's binary_logloss: 0.00027455	valid_1's auc: 0.99887	valid_1's binary_logloss: 0.00459136
# Fold  3 AUC : 0.998870
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999885	training's binary_logloss: 0.0130181	valid_1's auc: 0.998795	valid_1's binary_logloss: 0.0182772
# [200]	training's auc: 0.999991	training's binary_logloss: 0.00306919	valid_1's auc: 0.996308	valid_1's binary_logloss: 0.00770903
# [300]	training's auc: 1	training's binary_logloss: 0.000925021	valid_1's auc: 0.997009	valid_1's binary_logloss: 0.00575703
# [400]	training's auc: 1	training's binary_logloss: 0.000333066	valid_1's auc: 0.99789	valid_1's binary_logloss: 0.00529309
# Early stopping, best iteration is:
# [129]	training's auc: 0.999942	training's binary_logloss: 0.00805445	valid_1's auc: 0.998964	valid_1's binary_logloss: 0.0125389
# Fold  4 AUC : 0.998964
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999921	training's binary_logloss: 0.0127771	valid_1's auc: 0.999034	valid_1's binary_logloss: 0.0172075
# [200]	training's auc: 0.999997	training's binary_logloss: 0.00308877	valid_1's auc: 0.996801	valid_1's binary_logloss: 0.00748201
# [300]	training's auc: 1	training's binary_logloss: 0.000961238	valid_1's auc: 0.99694	valid_1's binary_logloss: 0.00573258
# [400]	training's auc: 1	training's binary_logloss: 0.00034673	valid_1's auc: 0.997129	valid_1's binary_logloss: 0.00536616
# Early stopping, best iteration is:
# [157]	training's auc: 0.99998	training's binary_logloss: 0.0054874	valid_1's auc: 0.999294	valid_1's binary_logloss: 0.00938558
# Fold  5 AUC : 0.999294
# Full AUC score 0.998125

# %%
test_preds_lgb48, preds_lgb48, feature_importance_fin_lgb48 = LGBM_classifier(\
                                                                                train_48_recent,
                                                                                dj_ts_aws_recent,
                                                                                'after48_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = True)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99985	training's binary_logloss: 0.0231309	valid_1's auc: 0.99931	valid_1's binary_logloss: 0.0266703
# [200]	training's auc: 0.999986	training's binary_logloss: 0.0063421	valid_1's auc: 0.997036	valid_1's binary_logloss: 0.00932349
# [300]	training's auc: 1	training's binary_logloss: 0.00222437	valid_1's auc: 0.997056	valid_1's binary_logloss: 0.00576155
# [400]	training's auc: 1	training's binary_logloss: 0.000898363	valid_1's auc: 0.997038	valid_1's binary_logloss: 0.00483195
# Early stopping, best iteration is:
# [183]	training's auc: 0.999973	training's binary_logloss: 0.00763577	valid_1's auc: 0.999592	valid_1's binary_logloss: 0.0100994
# Fold  1 AUC : 0.999592
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999871	training's binary_logloss: 0.0201483	valid_1's auc: 0.996139	valid_1's binary_logloss: 0.0265427
# [200]	training's auc: 0.999989	training's binary_logloss: 0.00562754	valid_1's auc: 0.994353	valid_1's binary_logloss: 0.0102746
# [300]	training's auc: 1	training's binary_logloss: 0.00197003	valid_1's auc: 0.995309	valid_1's binary_logloss: 0.00687441
# [400]	training's auc: 1	training's binary_logloss: 0.000779931	valid_1's auc: 0.995632	valid_1's binary_logloss: 0.00596948
# Early stopping, best iteration is:
# [166]	training's auc: 0.999973	training's binary_logloss: 0.00820118	valid_1's auc: 0.996523	valid_1's binary_logloss: 0.0127619
# Fold  2 AUC : 0.996523
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999843	training's binary_logloss: 0.022503	valid_1's auc: 0.999089	valid_1's binary_logloss: 0.0274109
# [200]	training's auc: 0.999985	training's binary_logloss: 0.00618997	valid_1's auc: 0.999116	valid_1's binary_logloss: 0.00977152
# [300]	training's auc: 1	training's binary_logloss: 0.00210212	valid_1's auc: 0.99898	valid_1's binary_logloss: 0.0058942
# [400]	training's auc: 1	training's binary_logloss: 0.000823114	valid_1's auc: 0.999151	valid_1's binary_logloss: 0.00480193
# Early stopping, best iteration is:
# [136]	training's auc: 0.999926	training's binary_logloss: 0.0133685	valid_1's auc: 0.999326	valid_1's binary_logloss: 0.0173384
# Fold  3 AUC : 0.999326
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999849	training's binary_logloss: 0.0209108	valid_1's auc: 0.997306	valid_1's binary_logloss: 0.0255371
# [200]	training's auc: 0.999984	training's binary_logloss: 0.00554631	valid_1's auc: 0.998053	valid_1's binary_logloss: 0.00969916
# [300]	training's auc: 1	training's binary_logloss: 0.00184032	valid_1's auc: 0.993559	valid_1's binary_logloss: 0.0072166
# [400]	training's auc: 1	training's binary_logloss: 0.000707903	valid_1's auc: 0.993332	valid_1's binary_logloss: 0.00657897
# [500]	training's auc: 1	training's binary_logloss: 0.000281994	valid_1's auc: 0.99318	valid_1's binary_logloss: 0.00650021
# Early stopping, best iteration is:
# [210]	training's auc: 0.999987	training's binary_logloss: 0.00491753	valid_1's auc: 0.998158	valid_1's binary_logloss: 0.00905761
# Fold  4 AUC : 0.998158
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999859	training's binary_logloss: 0.0227252	valid_1's auc: 0.998704	valid_1's binary_logloss: 0.0276622
# [200]	training's auc: 0.999984	training's binary_logloss: 0.00626352	valid_1's auc: 0.999271	valid_1's binary_logloss: 0.00971834
# [300]	training's auc: 1	training's binary_logloss: 0.00218112	valid_1's auc: 0.999286	valid_1's binary_logloss: 0.00596992
# [400]	training's auc: 1	training's binary_logloss: 0.000820386	valid_1's auc: 0.998862	valid_1's binary_logloss: 0.00509571
# [500]	training's auc: 1	training's binary_logloss: 0.000343951	valid_1's auc: 0.998744	valid_1's binary_logloss: 0.00488415
# Early stopping, best iteration is:
# [289]	training's auc: 0.999997	training's binary_logloss: 0.0024737	valid_1's auc: 0.99934	valid_1's binary_logloss: 0.00616292
# Fold  5 AUC : 0.999340
# Full AUC score 0.998388

# %%
# 변수중요도를 통한 변수 제거
train_lgb48_remove = train_lgb48_df.drop(columns = feature_importance_fin_lgb48.tail(5).index.tolist())
test_lgb48_remove = test_lgb48_df.drop(columns = feature_importance_fin_lgb48.tail(5).index.tolist())

# %%
remove_test_preds_lgb48, remove_preds_lgb48, remove_feature_importance_fin_lgb48 = LGBM_classifier(\
                                                                                train_lgb48_remove,
                                                                                test_lgb48_remove,
                                                                                'after48_loc_predict',
                                                                                5,
                                                                                0.5,
                                                                                real_train = True)
# Out:
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.99985	training's binary_logloss: 0.0231309	valid_1's auc: 0.99931	valid_1's binary_logloss: 0.0266703
# [200]	training's auc: 0.999986	training's binary_logloss: 0.0063421	valid_1's auc: 0.997036	valid_1's binary_logloss: 0.00932349
# [300]	training's auc: 1	training's binary_logloss: 0.00222437	valid_1's auc: 0.997056	valid_1's binary_logloss: 0.00576155
# [400]	training's auc: 1	training's binary_logloss: 0.000898363	valid_1's auc: 0.997038	valid_1's binary_logloss: 0.00483195
# Early stopping, best iteration is:
# [183]	training's auc: 0.999973	training's binary_logloss: 0.00763577	valid_1's auc: 0.999592	valid_1's binary_logloss: 0.0100994
# Fold  1 AUC : 0.999592
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999871	training's binary_logloss: 0.0201483	valid_1's auc: 0.996139	valid_1's binary_logloss: 0.0265427
# [200]	training's auc: 0.999989	training's binary_logloss: 0.00562754	valid_1's auc: 0.994353	valid_1's binary_logloss: 0.0102746
# [300]	training's auc: 1	training's binary_logloss: 0.00197003	valid_1's auc: 0.995309	valid_1's binary_logloss: 0.00687441
# [400]	training's auc: 1	training's binary_logloss: 0.000779931	valid_1's auc: 0.995632	valid_1's binary_logloss: 0.00596948
# Early stopping, best iteration is:
# [166]	training's auc: 0.999973	training's binary_logloss: 0.00820118	valid_1's auc: 0.996523	valid_1's binary_logloss: 0.0127619
# Fold  2 AUC : 0.996523
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999843	training's binary_logloss: 0.022503	valid_1's auc: 0.999089	valid_1's binary_logloss: 0.0274109
# [200]	training's auc: 0.999985	training's binary_logloss: 0.00618997	valid_1's auc: 0.999116	valid_1's binary_logloss: 0.00977152
# [300]	training's auc: 1	training's binary_logloss: 0.00210212	valid_1's auc: 0.99898	valid_1's binary_logloss: 0.0058942
# [400]	training's auc: 1	training's binary_logloss: 0.000823114	valid_1's auc: 0.999151	valid_1's binary_logloss: 0.00480193
# Early stopping, best iteration is:
# [136]	training's auc: 0.999926	training's binary_logloss: 0.0133685	valid_1's auc: 0.999326	valid_1's binary_logloss: 0.0173384
# Fold  3 AUC : 0.999326
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999849	training's binary_logloss: 0.0209108	valid_1's auc: 0.997306	valid_1's binary_logloss: 0.0255371
# [200]	training's auc: 0.999984	training's binary_logloss: 0.00554631	valid_1's auc: 0.998053	valid_1's binary_logloss: 0.00969916
# [300]	training's auc: 1	training's binary_logloss: 0.00184032	valid_1's auc: 0.993559	valid_1's binary_logloss: 0.0072166
# [400]	training's auc: 1	training's binary_logloss: 0.000707903	valid_1's auc: 0.993332	valid_1's binary_logloss: 0.00657897
# [500]	training's auc: 1	training's binary_logloss: 0.000281994	valid_1's auc: 0.99318	valid_1's binary_logloss: 0.00650021
# Early stopping, best iteration is:
# [210]	training's auc: 0.999987	training's binary_logloss: 0.00491753	valid_1's auc: 0.998158	valid_1's binary_logloss: 0.00905761
# Fold  4 AUC : 0.998158
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.999859	training's binary_logloss: 0.0227252	valid_1's auc: 0.998704	valid_1's binary_logloss: 0.0276622
# [200]	training's auc: 0.999984	training's binary_logloss: 0.00626352	valid_1's auc: 0.999271	valid_1's binary_logloss: 0.00971834
# [300]	training's auc: 1	training's binary_logloss: 0.00218112	valid_1's auc: 0.999286	valid_1's binary_logloss: 0.00596992
# [400]	training's auc: 1	training's binary_logloss: 0.000820386	valid_1's auc: 0.998862	valid_1's binary_logloss: 0.00509571
# [500]	training's auc: 1	training's binary_logloss: 0.000343951	valid_1's auc: 0.998744	valid_1's binary_logloss: 0.00488415
# Early stopping, best iteration is:
# [289]	training's auc: 0.999997	training's binary_logloss: 0.0024737	valid_1's auc: 0.99934	valid_1's binary_logloss: 0.00616292
# Fold  5 AUC : 0.999340
# Full AUC score 0.998388

# %% [markdown]
# ### ***LGBM Grid Search***

# %%
# A parameter grid for XGBoost
lgb_params = {
        'min_child_weight': [0.5],
        'gamma': [0.4],
        'subsample': [0.8],
        'colsample_bytree': [0.8],
        'max_depth': [5],
        'learning_rate' : [0.6]
        }

#24시간 뒤의 결로현상을 예측하는 교차 모델
param_comb = 5
n = 5

X = train_24_recent.drop(columns = 'after24_loc_predict')
Y = train_24_recent['after24_loc_predict']

folds= KFold(n_splits=n, shuffle = True, random_state = 1001)
lgb_clf = lgb.LGBMClassifier(n_estimators = 1000, class_weight='balanced')

random_search_lgb = RandomizedSearchCV(lgb_clf, param_distributions=lgb_params, n_iter=param_comb, scoring='roc_auc', n_jobs=1, cv=folds.split(X,Y), verbose=10, random_state=1001 )

# Here we go
start_time = time.time() # timing starts from this point for "start_time" variable
random_search_lgb.fit(X, Y)
print('걸린 시간 : ', time.time() - start_time) # timing ends here for "start_time" variable

# %%
print('------------------------------------')
print(lgb_params)
print('------------------------------------')
print(random_search_lgb.best_estimator_)
print('------------------------------------')
print(random_search_lgb.best_params_)
print('------------------------------------')
print(random_search_lgb.best_score_)
print('------------------------------------')

# %% [markdown]
# # ***단일모델 검증***

# %%
def validation_simple(proba24,proba48, y_test24, y_test48,cut_off):
    prob24 = proba24
    prob48 = proba48

    prob24_pred = proba_to_int(prob24,cut_off)
    prob48_pred = proba_to_int(prob48,cut_off)
    
    print('After 24 hour predict auc : ',roc_auc_score(y_test24,prob24_pred))
    print('After 24 hour proba auc : ',roc_auc_score(y_test24,prob24))
    
    print('\nAfter 48 hour predict auc : ',roc_auc_score(y_test48,prob48_pred))
    print('After 48 hour proba auc : ',roc_auc_score(y_test48,prob48))
    
    
    conf_matrix24 = confusion_matrix(y_test24,prob24_pred,labels = [1,0])
    conf_matrix48 = confusion_matrix(y_test48,prob48_pred,labels = [1,0])
    print('\nCut Off : ', cut_off)
    print('\nAfter 24hour confusion matrix : \n',conf_matrix24)
    print('\nAfter 48hour confusion matrix : \n',conf_matrix48)
    
    
    csi24 = conf_matrix24[0,0] / (conf_matrix24[0,0] + conf_matrix24[0,1] + conf_matrix24[1,0])
    csi48 = conf_matrix48[0,0] / (conf_matrix48[0,0] + conf_matrix48[0,1] + conf_matrix48[1,0])
    
    print('\nAfter 24hour CSI : ', csi24)
    print('\nAfter 48hour CSI : ', csi48)
    
    return prob24_pred, prob48_pred

# %% [markdown]
# ***이슬점까지 컬럼으로 최종 제출 데이터셋***

# %%
#xgb 단일모델
a,b = validation_simple(test_preds_xgb24,test_preds_xgb48,y_test_xgb24,y_test_xgb48,0.5)
# Out:
# After 24 hour predict auc :  0.9126579999249733
# After 24 hour proba auc :  0.9992011680056341
#
# After 48 hour predict auc :  0.9012900224360368
# After 48 hour proba auc :  0.9964987452373623
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  412    87]
#  [   29 86460]]
#
# After 48hour confusion matrix :
#  [[  403    99]
#  [   18 86189]]
#
# After 24hour CSI :  0.7803030303030303
#
# After 48hour CSI :  0.775

# %%
#lgb 단일모델
a,b = validation_simple(test_preds_lgb24,test_preds_lgb48,y_test_lgb24,y_test_lgb48,0.5)
# Out:
# After 24 hour predict auc :  0.9512967940065634
# After 24 hour proba auc :  0.9993036055345553
#
# After 48 hour predict auc :  0.9663484750431846
# After 48 hour proba auc :  0.9958924957656586
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  451    48]
#  [  105 86384]]
#
# After 48hour confusion matrix :
#  [[  469    33]
#  [  135 86072]]
#
# After 24hour CSI :  0.7466887417218543
#
# After 48hour CSI :  0.7362637362637363

# %% [markdown]
# ***aws + 베이스 데이터***

# %%
#xgb 단일모델
a,b = validation_simple(test_preds_xgb24_aws,test_preds_xgb48_aws,y_test_xgb24_aws,y_test_xgb48_aws,0.5)
# Out:
# After 24 hour predict auc :  0.8896523753145158
# After 24 hour proba auc :  0.9970212250976996
#
# After 48 hour predict auc :  0.8813755037039771
# After 48 hour proba auc :  0.9955506658969698
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  389   110]
#  [   22 86467]]
#
# After 48hour confusion matrix :
#  [[  383   119]
#  [   17 86190]]
#
# After 24hour CSI :  0.746641074856046
#
# After 48hour CSI :  0.7379576107899807

# %%
#lgb 단일모델
a,b = validation_simple(test_preds_lgb24,test_preds_lgb48_aws,y_test_lgb24_aws,y_test_lgb48_aws,0.5)
# Out:
# After 24 hour predict auc :  0.9442885470324385
# After 24 hour proba auc :  0.9971760746805499
#
# After 48 hour predict auc :  0.9446333242089353
# After 48 hour proba auc :  0.9949576570468275
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  444    55]
#  [  104 86385]]
#
# After 48hour confusion matrix :
#  [[  447    55]
#  [  101 86106]]
#
# After 24hour CSI :  0.736318407960199
#
# After 48hour CSI :  0.7412935323383084

# %% [markdown]
# ***동네예보 + 베이스 데이터***

# %%
#xgb 단일모델
a,b = validation_simple(test_preds_xgb24_dong,test_preds_xgb48_dong,y_test_xgb24_dong,y_test_xgb48_dong,0.5)
# Out:
# After 24 hour predict auc :  0.9076653231308551
# After 24 hour proba auc :  0.9993822931274566
#
# After 48 hour predict auc :  0.8674486805755275
# After 48 hour proba auc :  0.9947703935265237
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  407    92]
#  [   26 86463]]
#
# After 48hour confusion matrix :
#  [[  369   133]
#  [   14 86193]]
#
# After 24hour CSI :  0.7752380952380953
#
# After 48hour CSI :  0.7151162790697675

# %%
#lgb 단일모델
a,b = validation_simple(test_preds_lgb24_dong,test_preds_lgb48_dong,y_test_lgb24_dong,y_test_lgb48_dong,0.5)
# Out:
# After 24 hour predict auc :  0.9715910911649751
# After 24 hour proba auc :  0.9988687615840313
#
# After 48 hour predict auc :  0.9504412200283049
# After 48 hour proba auc :  0.9942273200746262
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  474    25]
#  [  581 85908]]
#
# After 48hour confusion matrix :
#  [[  453    49]
#  [  130 86077]]
#
# After 24hour CSI :  0.4388888888888889
#
# After 48hour CSI :  0.7167721518987342

# %% [markdown]
# # ***Validation Ensemble Function***

# %%
def proba_to_int(value_ls,cut_off):
    
    preds = []
    for i in range(len(value_ls)):
        
        if value_ls[i] >= cut_off:
            preds.append(1)
        else:
            preds.append(0)
            
            
    return preds

#proba 데이터를 넣어줘야함
def validation_emd(lgb24,lgb48,xgb24,xgb48,y_test24,y_test48,cut_off):
    lgb24 = lgb24
    xgb24 = xgb24

    lgb48 = lgb48
    xgb48 = xgb48

    lgb_xgb_emb24 = (lgb24 + xgb24) / 2
    lgb_xgb_emb48 = (lgb48 + xgb48) / 2

    emb24_pred = proba_to_int(lgb_xgb_emb24,cut_off)
    emb48_pred = proba_to_int(lgb_xgb_emb48,cut_off)
    
    print('After 24 hour predict auc : ',roc_auc_score(y_test24,emb24_pred))
    print('After 24 hour proba auc : ',roc_auc_score(y_test24,lgb_xgb_emb24))
    
    print('\nAfter 48 hour predict auc : ',roc_auc_score(y_test48,emb48_pred))
    print('After 48 hour proba auc : ',roc_auc_score(y_test48,lgb_xgb_emb48))
    
    
    conf_matrix24 = confusion_matrix(y_test24,emb24_pred,labels = [1,0])
    conf_matrix48 = confusion_matrix(y_test48,emb48_pred,labels = [1,0])
    print('\nCut Off : ', cut_off)
    print('\nAfter 24hour confusion matrix : \n',conf_matrix24)
    print('\nAfter 48hour confusion matrix : \n',conf_matrix48)
    
    
    csi24 = conf_matrix24[0,0] / (conf_matrix24[0,0] + conf_matrix24[0,1] + conf_matrix24[1,0])
    csi48 = conf_matrix48[0,0] / (conf_matrix48[0,0] + conf_matrix48[0,1] + conf_matrix48[1,0])
    
    print('\nAfter 24hour CSI : ', csi24)
    print('\nAfter 48hour CSI : ', csi48)
    return emb24_pred, emb48_pred

def validation_emd2(lgb24,lgb48,xgb24,xgb48,rf24,rf48,y_test24,y_test48,n):
    lgb24 = lgb24
    xgb24 = xgb24
    rf24 = rf24

    lgb48 = lgb48
    xgb48 = xgb48
    rf48 = rf48

    emb24 = (lgb24 + xgb24 + rf24) / n
    emb48 = (lgb48 + xgb48 + rf48) / n

    emb24_pred = proba_to_int(emb24)
    emb48_pred = proba_to_int(emb48)
    
    conf_matrix24 = confusion_matrix(y_test24,emb24_pred,labels = [1,0])
    conf_matrix48 = confusion_matrix(y_test48,emb48_pred,labels = [1,0])
    
    
    print('After 24hour confusion matrix : \n',conf_matrix24)
    print('\nAfter 48hour confusion matrix : \n',conf_matrix48)
    
    csi24 = conf_matrix24[0,0] / (conf_matrix24[0,0] + conf_matrix24[0,1] + conf_matrix24[1,0])
    csi48 = conf_matrix48[0,0] / (conf_matrix48[0,0] + conf_matrix48[0,1] + conf_matrix48[1,0])
    
    print('\nAfter 24hour CSI : ', csi24)
    print('\nAfter 48hour CSI : ', csi48)
    return emb24_pred, emb48_pred

# %%
# 최종 데이터 train validation
emb24_pred, emb48_pred = validation_emd(test_preds_lgb24,test_preds_lgb48,test_preds_xgb24,test_preds_xgb48,y_test_lgb24,y_test_lgb48,0.5)
# Out:
# After 24 hour predict auc :  0.9315573301095825
# After 24 hour proba auc :  0.9988343067988004
#
# After 48 hour predict auc :  0.938044012195791
# After 48 hour proba auc :  0.9959399124418262
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  431    68]
#  [   53 86436]]
#
# After 48hour confusion matrix :
#  [[  440    62]
#  [   35 86172]]
#
# After 24hour CSI :  0.7807971014492754
#
# After 48hour CSI :  0.819366852886406

# %%
# aws + 베이스 train validation
emb24_pred, emb48_pred = validation_emd(test_preds_lgb24,test_preds_lgb48_aws,test_preds_xgb24_aws,test_preds_xgb48_aws,y_test_lgb24_aws,y_test_lgb48_aws,0.5)
# Out:
# After 24 hour predict auc :  0.9185544023333235
# After 24 hour proba auc :  0.9971809173504312
#
# After 48 hour predict auc :  0.9180830935194114
# After 48 hour proba auc :  0.9950937604691608
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  418    81]
#  [   49 86440]]
#
# After 48hour confusion matrix :
#  [[  420    82]
#  [   42 86165]]
#
# After 24hour CSI :  0.7627737226277372
#
# After 48hour CSI :  0.7720588235294118

# %%
# 동네예보 + 베이스 train validation
emb24_pred, emb48_pred = validation_emd(test_preds_lgb24_dong,test_preds_lgb48_dong,test_preds_xgb24_dong,test_preds_xgb48_dong,y_test_lgb24_dong,y_test_lgb48_dong,0.5)
# Out:
# After 24 hour predict auc :  0.9463098982944326
# After 24 hour proba auc :  0.9990989621834055
#
# After 48 hour predict auc :  0.9101323660084916
# After 48 hour proba auc :  0.994382371681393
#
# Cut Off :  0.5
#
# After 24hour confusion matrix :
#  [[  446    53]
#  [  101 86388]]
#
# After 48hour confusion matrix :
#  [[  412    90]
#  [   39 86168]]
#
# After 24hour CSI :  0.7433333333333333
#
# After 48hour CSI :  0.7615526802218114

# %% [markdown]
# # ***Real Test Ensemble***

# %%
def real_ensemble(lgb24, lgb48, xgb24, xgb48,cut_off):
    lgb24 = lgb24
    xgb24 = xgb24

    lgb48 = lgb48
    xgb48 = xgb48

    lgb_xgb_emb24 = (lgb24 + xgb24) / 2
    lgb_xgb_emb48 = (lgb48 + xgb48) / 2

    emb24_pred = proba_to_int(lgb_xgb_emb24,cut_off)
    emb48_pred = proba_to_int(lgb_xgb_emb48,cut_off)
    
    emb24_proba = lgb_xgb_emb24*100.0
    emb48_proba = lgb_xgb_emb48*100.0
    
    return emb24_pred,emb48_pred,emb24_proba,emb48_proba

# %%
emb24_pred, emb48_pred, emb24_proba,emb48_proba = real_ensemble(test_preds_lgb24,test_preds_lgb48,test_preds_xgb24,test_preds_xgb48,0.06)

# %%
emb24_pred, emb48_pred, emb24_proba,emb48_proba = real_ensemble(remove_test_preds_lgb24,remove_test_preds_lgb48,remove_test_preds_xgb24,remove_test_preds_xgb48,0.06)

# %%
valid['X24H_COND_LOC'] = emb24_pred
valid['X48H_COND_LOC'] = emb48_pred

valid['X24H_COND_LOC_PROB'] = emb24_proba
valid['X48H_COND_LOC_PROB'] = emb48_proba

# %%
valid.to_csv('data/203675.csv',index = False)
