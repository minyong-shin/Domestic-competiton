# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import re

# %% [markdown]
# # 서울 구 지도
#
# <img src = '서울구지도.png'>

# %%
'''
강서구 : 우장산역(스마트), 까치산역(스마트), 마곡역(스마트), 강서구청 본관 - 스마트 도서관
양천구 : 목동역(U-도서관), 양천도서관 현관(스마트), 오목교(스마트 도서관)
구로구 : 천왕역(스마트), 신도림(스마트), 개봉역(스마트)
영등포구 : 여의도역, 제1/2 스포츠센터 => 스마트도서관
동작구 : 신대방삼거리역, 장승배기역, 총신대입구역, 노들역 => 스마트
금천구 : 금천고가(스마트)
관악구 : 신림역(스마트), 서울대입구, 신대방, 봉천, 낙성대, 관악중앙도서관=> U-도서관
서초구 : 내방역(스마트), 양재역(스마트), 
강남구 : 강남구청역, 논현1동, 삼성2동, 청담역
송파구 : 잠실나루역
강동구 : x
마포구 : x
서대문구 : 아현역, 홍제역, 독립문역
은평구 : 연신내역, 불광역, 역촌역
종로구 : x
중구 : 충정로역, 중립동 주민센터
용산구 : 남산도서관
성북구 : 석계역, 고려대역 / U-도서관이 활발(12개)
강북구 : x / U-도서관
성동구 : 금호역, 옥수역, 상왕십리
동대문구 : 한국외대 (스마트)
도봉구 : 쌍문역(U-도서관)
노원구 : 노원평생학습관(스마트)
중랑구 : 용마산역, 망우역, 중화역(스마트)
광진구 : 광진정보도서관(스마트)
'''

# %% [markdown]
# # 데이터셋 구축

# %%
smart = pd.DataFrame()

# %%
smart['gu'] = ['강서구']*4 + ['양천구']*3 + ['구로구']*3 + ['영등포구']*3 + ['동작구']*4 + ['금천구']\
                + ['관악구']*6 + ['서초구']*2 + ['강남구']*4 + ['송파구'] + ['강동구'] + ['마포구']\
                + ['서대문구']*3 + ['은평구']*3 + ['종로구'] + ['중구']*2 + ['용산구'] + ['성북구']*2\
                + ['강북구'] + ['성동구']*3 + ['동대문구'] + ['도봉구'] + ['노원구'] + ['중랑구']*3 + ['광진구']
smart['location'] = ['우장산역','까치산역','마곡역','강서구청 본관','목동역','양천도서관','오목교역'
                     ,'천왕역','신도림역','개봉역','여의도역','제1스포츠센터','제2스포츠센터'
                    ,'신대방삼거리역','장승배기역','총신대입구역','노들역','금천고가','신림역','서울대입구역','봉천역'
                    ,'신대방역','낙성대역','관악중앙도서관','내방역','양재역','강남구청역','논현1동','삼성2동','청담역'
                    ,'잠실나루역',np.nan,np.nan,'아현역','홍제역','독립문역','연신내역','불광역','역촌역'
                    ,np.nan,'충정로역','중립동_주민센터','남산도서관','석계역','고려대역',np.nan,'금호역'
                    ,'옥수역','상왕십리역','한국외대','쌍문역','노원평생학습관','용마산역','망우역','중화역'
                    ,'광진정보도서관']

# %%
smart['whether'] = [2]*19 + [1]*5 + [2]*7 +[np.nan]*2 + [2]*6 + [np.nan] + [2]*5 + [np.nan]\
                    +[2]*10

# %%
smart['location2'] = smart['gu'] + ' ' +smart['location']

# %% [markdown]
# # 위치 좌표 끌어오기
#
#     - 네이버 셀레늄 -> 주소 수집 -> 카카오 api

# %%
smart.head()
# Out:
#     gu location  whether    location2             addr
# 0  강서구     우장산역      2.0     강서구 우장산역   서울 강서구 강서로 262
# 1  강서구     까치산역      2.0     강서구 까치산역    서울 강서구 강서로 54
# 2  강서구      마곡역      2.0      강서구 마곡역  서울 강서구 공항대로 163
# 3  강서구  강서구청 본관      2.0  강서구 강서구청 본관            error
# 4  양천구      목동역      2.0      양천구 목동역   서울 양천구 오목로 245

# %%
base_url = 'https://map.naver.com/'

browser = webdriver.Chrome('/Users/sinmin-yong/GitHub/공모전/도서빅데이터/chromedriver')
browser.get(base_url)
time.sleep(1.5)

# %%
addr_ls = []
for idx, loc in enumerate(smart['location2'].tolist()):
    
    if str(loc) == 'nan':
        addr_ls.append(np.nan)
        pass
    
    else:
        try:
            
            '''browser.switch_to_default_content()

            browser.find_elements_by_xpath('//search-input-box/div/div/div/input')[0].clear()

            browser.find_elements_by_xpath('//search-input-box/div/div/div/input')[0].send_keys(loc)
            time.sleep(0.2)
            browser.find_elements_by_xpath('//search-input-box/div/div/div/input')[0].send_keys(Keys.ENTER)
            time.sleep(1.5)

            browser.switch_to_frame('searchIframe')

            addr = browser.find_elements_by_xpath('//*[@id = "app-root"]//ul/li[1]')[0].text.split('\n')[1]

            addr_ls.append(addr)'''
            
            browser.switch_to_default_content()

            browser.find_elements_by_xpath('//search-input-box/div/div/div/input')[0].clear()

            browser.find_elements_by_xpath('//search-input-box/div/div/div/input')[0].send_keys(loc)
            time.sleep(0.2)
            browser.find_elements_by_xpath('//search-input-box/div/div/div/input')[0].send_keys(Keys.ENTER)
            time.sleep(1.5)

            browser.switch_to_frame('searchIframe')
            
            try:
                browser.find_elements_by_xpath('//*[@id = "app-root"]//ul/li[1]/div[2]/div[2]/span')[0].click()
                time.sleep(0.8)

                addr = browser.find_elements_by_xpath('//*[@id = "app-root"]//ul/li[1]/div[2]/div[2]/div/div[1]')[0].text

                addr_ls.append(addr)
            except:
                browser.find_elements_by_xpath('//*[@id = "app-root"]//ul/li[1]/div[1]/div[2]/span')[0].click()
                time.sleep(0.8)

                addr = browser.find_elements_by_xpath('//*[@id = "app-root"]//ul/li[1]/div[1]/div[2]/div/div[1]')[0].text

                addr_ls.append(addr)
            
        except:
            addr_ls.append('error')
        
    time.sleep(1)
# Out:
# /Users/sinmin-yong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: DeprecationWarning: use driver.switch_to.default_content instead
# /Users/sinmin-yong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: DeprecationWarning: use driver.switch_to.frame instead

# %%
smart['addr2'] = addr_ls

# %%
smart.fillna('error',inplace = True)

# %%
smart['addr3'] = smart['addr2'].apply(lambda x : re.sub('도로명|복사','',x))

# %%
smart
# Out:
#       gu  location whether     location2                       addr  \
# 0    강서구      우장산역       2      강서구 우장산역             서울 강서구 강서로 262
# 1    강서구      까치산역       2      강서구 까치산역              서울 강서구 강서로 54
# 2    강서구       마곡역       2       강서구 마곡역            서울 강서구 공항대로 163
# 3    강서구   강서구청 본관       2   강서구 강서구청 본관                      error
# 4    양천구       목동역       2       양천구 목동역             서울 양천구 오목로 245
# 5    양천구     양천도서관       2     양천구 양천도서관                          3
# 6    양천구      오목교역       2      양천구 오목교역             서울 양천구 오목로 342
# 7    구로구       천왕역       2       구로구 천왕역            서울 구로구 천왕로1길 60
# 8    구로구      신도림역       2      구로구 신도림역                          8
# 9    구로구       개봉역       2       구로구 개봉역           서울 구로구 경인로40길 47
# 10  영등포구      여의도역       2     영등포구 여의도역      서울 영등포구 여의나루로 40 여의도역
# 11  영등포구   제1스포츠센터       2  영등포구 제1스포츠센터              서울 영등포구 신풍로 1
# 12  영등포구   제2스포츠센터       2  영등포구 제2스포츠센터                    서울 영등포구
# 13   동작구   신대방삼거리역       2   동작구 신대방삼거리역              서울 동작구 상도로 76
# 14   동작구     장승배기역       2     동작구 장승배기역             서울 동작구 상도로 188
# 15   동작구    총신대입구역       2    동작구 총신대입구역            서울 동작구 동작대로 117
# 16   동작구       노들역       2       동작구 노들역            서울 동작구 노량진로 238
# 17   금천구      금천고가       2      금천구 금천고가                 서울 금천구 가산동
# 18   관악구       신림역       2       관악구 신림역                         15
# 19   관악구    서울대입구역       1    관악구 서울대입구역  서울 관악구 남부순환로 1822 서울대입구역사
# 20   관악구       봉천역       1       관악구 봉천역          서울 관악구 남부순환로 1721
# 21   관악구      신대방역       1      관악구 신대방역           서울 관악구 신림동 643-1
# 22   관악구      낙성대역       1      관악구 낙성대역          서울 관악구 남부순환로 1928
# 23   관악구   관악중앙도서관       1   관악구 관악중앙도서관            서울 관악구 신림로3길 35
# 24   서초구       내방역       2       서초구 내방역            서울 서초구 서초대로 103
# 25   서초구       양재역       2       서초구 양재역          서울 서초구 남부순환로 2585
# 26   강남구     강남구청역       2     강남구 강남구청역             서울 강남구 학동로 346
# 27   강남구      논현1동       2      강남구 논현1동  서울 강남구 학동로20길 25 논현1동주민센터
# 28   강남구      삼성2동       2      강남구 삼성2동                     서울 강남구
# 29   강남구       청담역       2       강남구 청담역             서울 강남구 학동로 508
# 30   송파구     잠실나루역       2     송파구 잠실나루역              서울 송파구 오금로 20
# 31   강동구     error   error         error                      error
# 32   마포구     error   error         error                      error
# 33  서대문구       아현역       2      서대문구 아현역                          2
# 34  서대문구       홍제역       2      서대문구 홍제역          서울 서대문구 통일로 440-1
# 35  서대문구      독립문역       2     서대문구 독립문역            서울 서대문구 통일로 247
# 36   은평구      연신내역       2      은평구 연신내역             서울 은평구 통일로 849
# 37   은평구       불광역       2       은평구 불광역           서울 은평구 통일로 723-1
# 38   은평구       역촌역       2       은평구 역촌역        서울 은평구 서오릉로 63 역촌역사
# 39   종로구     error   error         error                      error
# 40    중구      충정로역       2       중구 충정로역                          6
# 41    중구  중립동_주민센터       2   중구 중립동_주민센터                      error
# 42   용산구     남산도서관       2     용산구 남산도서관                         21
# 43   성북구       석계역       2       성북구 석계역                          3
# 44   성북구      고려대역       2      성북구 고려대역               서울 성북구 종암로 1
# 45   강북구     error   error         error                      error
# 46   성동구       금호역       2       성동구 금호역             서울 성동구 동호로 104
# 47   성동구       옥수역       2       성동구 옥수역              서울 성동구 동호로 21
# 48   성동구     상왕십리역       2     성동구 상왕십리역            서울 성동구 왕십리로 374
# 49  동대문구      한국외대       2     동대문구 한국외대                          3
# 50   도봉구       쌍문역       2       도봉구 쌍문역           서울 도봉구 도봉로 486-1
# 51   노원구   노원평생학습관       2   노원구 노원평생학습관                          3
# 52   중랑구      용마산역       2      중랑구 용마산역            서울 중랑구 용마산로 227
# 53   중랑구       망우역       2       중랑구 망우역                          6
# 54   중랑구       중화역       2       중랑구 중화역             서울 중랑구 동일로 797
# 55   광진구   광진정보도서관       2   광진구 광진정보도서관                          2
#
#                                addr2                        addr3
# 0                도로명서울 강서구 강서로 262복사               서울 강서구 강서로 262
# 1                 도로명서울 강서구 강서로 54복사                서울 강서구 강서로 54
# 2               도로명서울 강서구 공항대로 163복사              서울 강서구 공항대로 163
# 3                              error                        error
# 4                도로명서울 양천구 오목로 245복사               서울 양천구 오목로 245
# 5               도로명서울 양천구 목동서로 113복사              서울 양천구 목동서로 113
# 6                도로명서울 양천구 오목로 342복사               서울 양천구 오목로 342
# 7               도로명서울 구로구 천왕로1길 60복사              서울 구로구 천왕로1길 60
# 8                도로명서울 구로구 경인로 662복사               서울 구로구 경인로 662
# 9              도로명서울 구로구 경인로40길 47복사             서울 구로구 경인로40길 47
# 10        도로명서울 영등포구 여의나루로 40 여의도역복사        서울 영등포구 여의나루로 40 여의도역
# 11                도로명서울 영등포구 신풍로 1복사                서울 영등포구 신풍로 1
# 12  도로명서울 영등포구 국회대로 615 영등포제2스포츠센터복사  서울 영등포구 국회대로 615 영등포제2스포츠센터
# 13                도로명서울 동작구 상도로 76복사                서울 동작구 상도로 76
# 14               도로명서울 동작구 상도로 188복사               서울 동작구 상도로 188
# 15              도로명서울 동작구 동작대로 117복사              서울 동작구 동작대로 117
# 16              도로명서울 동작구 노량진로 238복사              서울 동작구 노량진로 238
# 17                    지번서울 금천구 가산동복사                 지번서울 금천구 가산동
# 18          도로명서울 관악구 남부순환로 1597-8복사          서울 관악구 남부순환로 1597-8
# 19    도로명서울 관악구 남부순환로 1822 서울대입구역사복사    서울 관악구 남부순환로 1822 서울대입구역사
# 20            도로명서울 관악구 남부순환로 1721복사            서울 관악구 남부순환로 1721
# 21              지번서울 관악구 신림동 643-1복사           지번서울 관악구 신림동 643-1
# 22            도로명서울 관악구 남부순환로 1928복사            서울 관악구 남부순환로 1928
# 23              도로명서울 관악구 신림로3길 35복사              서울 관악구 신림로3길 35
# 24              도로명서울 서초구 서초대로 103복사              서울 서초구 서초대로 103
# 25            도로명서울 서초구 남부순환로 2585복사            서울 서초구 남부순환로 2585
# 26               도로명서울 강남구 학동로 346복사               서울 강남구 학동로 346
# 27                             error                        error
# 28                             error                        error
# 29               도로명서울 강남구 학동로 508복사               서울 강남구 학동로 508
# 30                도로명서울 송파구 오금로 20복사                서울 송파구 오금로 20
# 31                             error                        error
# 32                             error                        error
# 33              도로명서울 서대문구 신촌로 243복사              서울 서대문구 신촌로 243
# 34            도로명서울 서대문구 통일로 440-1복사            서울 서대문구 통일로 440-1
# 35              도로명서울 서대문구 통일로 247복사              서울 서대문구 통일로 247
# 36               도로명서울 은평구 통일로 849복사               서울 은평구 통일로 849
# 37             도로명서울 은평구 통일로 723-1복사             서울 은평구 통일로 723-1
# 38          도로명서울 은평구 서오릉로 63 역촌역사복사          서울 은평구 서오릉로 63 역촌역사
# 39                             error                        error
# 40         도로명서울 중구 중림로 10 2동 104호복사         서울 중구 중림로 10 2동 104호
# 41                             error                        error
# 42         도로명서울 용산구 소월로 109 남산도서관복사         서울 용산구 소월로 109 남산도서관
# 43             도로명서울 성북구 한천로78길 53복사             서울 성북구 한천로78길 53
# 44                 도로명서울 성북구 종암로 1복사                 서울 성북구 종암로 1
# 45                             error                        error
# 46               도로명서울 성동구 동호로 104복사               서울 성동구 동호로 104
# 47                도로명서울 성동구 동호로 21복사                서울 성동구 동호로 21
# 48              도로명서울 성동구 왕십리로 374복사              서울 성동구 왕십리로 374
# 49     도로명서울 동대문구 이문로 107 한국외국어대학교복사     서울 동대문구 이문로 107 한국외국어대학교
# 50             도로명서울 도봉구 도봉로 486-1복사             서울 도봉구 도봉로 486-1
# 51    도로명서울 노원구 동일로204길 13 노원평생학습관복사    서울 노원구 동일로204길 13 노원평생학습관
# 52              도로명서울 중랑구 용마산로 227복사              서울 중랑구 용마산로 227
# 53            도로명서울 중랑구 망우로 383 1층복사            서울 중랑구 망우로 383 1층
# 54               도로명서울 중랑구 동일로 797복사               서울 중랑구 동일로 797
# 55            도로명서울 광진구 아차산로78길 90복사            서울 광진구 아차산로78길 90

# %%
def getLatLng(addr):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+addr
    headers = {"Authorization": "74e28dfd4b8f3d68ffb593d320d338d1"}
    result = json.loads(str(requests.get(url,headers=headers).text))
    match_first = result['documents'][0]['address']

    return float(match_first['y']),float(match_first['x'])

# %%
result_ls = []
for idx,loc in enumerate(smart['addr3'].tolist()):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query='+loc
    headers = {"Authorization": "KakaoAK 74e28dfd4b8f3d68ffb593d320d338d1"}
    result = json.loads(str(requests.get(url,headers=headers).text))
    ls = [result]
    
    result_ls.append(ls)

# %%
result_ls
# Out:
# [[{'documents': [{'address': {'address_name': '서울 강서구 화곡동 1089-3',
#       'b_code': '1150010300',
#       'h_code': '1150061500',
#       'main_address_no': '1089',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강서구',
#       'region_3depth_h_name': '우장산동',
#       'region_3depth_name': '화곡동',
#       'sub_address_no': '3',
#       'x': '126.836408931785',
#       'y': '37.5490001953873'},
#      'address_name': '서울 강서구 강서로 지하 262',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 강서구 강서로 지하 262',
#       'building_name': '우장산역 5호선',
#       'main_building_no': '262',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강서구',
#       'region_3depth_name': '화곡동',
#       'road_name': '강서로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.836408931785',
#       'y': '37.5490001953873',
#       'zone_no': '07691'},
#      'x': '126.836408931785',
#      'y': '37.5490001953873'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 강서구 화곡동 662-5',
#       'b_code': '1150010300',
#       'h_code': '1150059300',
#       'main_address_no': '662',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강서구',
#       'region_3depth_h_name': '화곡8동',
#       'region_3depth_name': '화곡동',
#       'sub_address_no': '5',
#       'x': '126.846611592059',
#       'y': '37.5319560847746'},
#      'address_name': '서울 강서구 강서로 지하 54',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 강서구 강서로 지하 54',
#       'building_name': '까치산역',
#       'main_building_no': '54',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강서구',
#       'region_3depth_name': '화곡동',
#       'road_name': '강서로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.846611592059',
#       'y': '37.5319560847746',
#       'zone_no': '07757'},
#      'x': '126.846611592059',
#      'y': '37.5319560847746'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 강서구 마곡동 769-3',
#       'b_code': '1150010500',
#       'h_code': '1150062000',
#       'main_address_no': '769',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강서구',
#       'region_3depth_h_name': '공항동',
#       'region_3depth_name': '마곡동',
#       'sub_address_no': '3',
#       'x': '126.825547992125',
#       'y': '37.5601984535897'},
#      'address_name': '서울 강서구 공항대로 지하 163',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 강서구 공항대로 지하 163',
#       'building_name': '마곡역(5호선)',
#       'main_building_no': '163',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강서구',
#       'region_3depth_name': '마곡동',
#       'road_name': '공항대로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.825547992125',
#       'y': '37.5601984535897',
#       'zone_no': '07800'},
#      'x': '126.825547992125',
#      'y': '37.5601984535897'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [{'address': {'address_name': '서울 양천구 목동 926-3',
#       'b_code': '1147010200',
#       'h_code': '1147051000',
#       'main_address_no': '926',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '양천구',
#       'region_3depth_h_name': '목1동',
#       'region_3depth_name': '목동',
#       'sub_address_no': '3',
#       'x': '126.864742584692',
#       'y': '37.52619868083'},
#      'address_name': '서울 양천구 오목로 지하 245',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 양천구 오목로 지하 245',
#       'building_name': '목동역',
#       'main_building_no': '245',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '양천구',
#       'region_3depth_name': '목동',
#       'road_name': '오목로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.864742584692',
#       'y': '37.52619868083',
#       'zone_no': '07993'},
#      'x': '126.864742584692',
#      'y': '37.52619868083'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 양천구 목동 905',
#       'b_code': '1147010200',
#       'h_code': '1147055000',
#       'main_address_no': '905',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '양천구',
#       'region_3depth_h_name': '목5동',
#       'region_3depth_name': '목동',
#       'sub_address_no': '',
#       'x': '126.876230784641',
#       'y': '37.5335602034508'},
#      'address_name': '서울 양천구 목동서로 113',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 양천구 목동서로 113',
#       'building_name': '양천도서관',
#       'main_building_no': '113',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '양천구',
#       'region_3depth_name': '목동',
#       'road_name': '목동서로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.876230784641',
#       'y': '37.5335602034508',
#       'zone_no': '07988'},
#      'x': '126.876230784641',
#      'y': '37.5335602034508'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 양천구 목동 406-30',
#       'b_code': '1147010200',
#       'h_code': '1147051000',
#       'main_address_no': '406',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '양천구',
#       'region_3depth_h_name': '목1동',
#       'region_3depth_name': '목동',
#       'sub_address_no': '30',
#       'x': '126.875354626254',
#       'y': '37.5244500703802'},
#      'address_name': '서울 양천구 오목로 지하 342',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 양천구 오목로 지하 342',
#       'building_name': '오목교역',
#       'main_building_no': '342',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '양천구',
#       'region_3depth_name': '목동',
#       'road_name': '오목로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.875354626254',
#       'y': '37.5244500703802',
#       'zone_no': '08006'},
#      'x': '126.875354626254',
#      'y': '37.5244500703802'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 구로구 천왕동 174',
#       'b_code': '1153011100',
#       'h_code': '1153078000',
#       'main_address_no': '174',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '구로구',
#       'region_3depth_h_name': '오류2동',
#       'region_3depth_name': '천왕동',
#       'sub_address_no': '',
#       'x': '126.834202124109',
#       'y': '37.4826379965713'},
#      'address_name': '서울 구로구 천왕로1길 60',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 구로구 천왕로1길 60',
#       'building_name': '',
#       'main_building_no': '60',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '구로구',
#       'region_3depth_name': '천왕동',
#       'road_name': '천왕로1길',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.834202124109',
#       'y': '37.4826379965713',
#       'zone_no': '08364'},
#      'x': '126.834202124109',
#      'y': '37.4826379965713'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 구로구 신도림동 692',
#       'b_code': '1153010100',
#       'h_code': '1153051000',
#       'main_address_no': '692',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '구로구',
#       'region_3depth_h_name': '신도림동',
#       'region_3depth_name': '신도림동',
#       'sub_address_no': '',
#       'x': '126.888212953215',
#       'y': '37.5081230677129'},
#      'address_name': '서울 구로구 경인로 662',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 구로구 경인로 662',
#       'building_name': '디큐브시티',
#       'main_building_no': '662',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '구로구',
#       'region_3depth_name': '신도림동',
#       'road_name': '경인로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.888212953215',
#       'y': '37.5081230677129',
#       'zone_no': '08209'},
#      'x': '126.888212953215',
#      'y': '37.5081230677129'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 구로구 개봉동 415',
#       'b_code': '1153010700',
#       'h_code': '1153074000',
#       'main_address_no': '415',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '구로구',
#       'region_3depth_h_name': '개봉1동',
#       'region_3depth_name': '개봉동',
#       'sub_address_no': '',
#       'x': '126.859102583368',
#       'y': '37.4945222528654'},
#      'address_name': '서울 구로구 경인로40길 47',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 구로구 경인로40길 47',
#       'building_name': '개봉역',
#       'main_building_no': '47',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '구로구',
#       'region_3depth_name': '개봉동',
#       'road_name': '경인로40길',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.859102583368',
#       'y': '37.4945222528654',
#       'zone_no': '08276'},
#      'x': '126.859102583368',
#      'y': '37.4945222528654'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 영등포구 여의도동 3',
#       'b_code': '1156011000',
#       'h_code': '1156054000',
#       'main_address_no': '3',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '영등포구',
#       'region_3depth_h_name': '여의동',
#       'region_3depth_name': '여의도동',
#       'sub_address_no': '',
#       'x': '126.924484687694',
#       'y': '37.5218423045786'},
#      'address_name': '서울 영등포구 여의나루로 지하 40',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 영등포구 여의나루로 지하 40',
#       'building_name': '여의도역',
#       'main_building_no': '40',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '영등포구',
#       'region_3depth_name': '여의도동',
#       'road_name': '여의나루로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.924484687694',
#       'y': '37.5218423045786',
#       'zone_no': '07327'},
#      'x': '126.924484687694',
#      'y': '37.5218423045786'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 영등포구 신길동 426-3',
#       'b_code': '1156013200',
#       'h_code': '1156067000',
#       'main_address_no': '426',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '영등포구',
#       'region_3depth_h_name': '신길5동',
#       'region_3depth_name': '신길동',
#       'sub_address_no': '3',
#       'x': '126.906305034633',
#       'y': '37.5005420689346'},
#      'address_name': '서울 영등포구 신풍로 1',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 영등포구 신풍로 1',
#       'building_name': '영등포제1스포츠센터',
#       'main_building_no': '1',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '영등포구',
#       'region_3depth_name': '신길동',
#       'road_name': '신풍로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.906305034633',
#       'y': '37.5005420689346',
#       'zone_no': '07398'},
#      'x': '126.906305034633',
#      'y': '37.5005420689346'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 영등포구 당산동4가 96-1',
#       'b_code': '1156011400',
#       'h_code': '1156056000',
#       'main_address_no': '96',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '영등포구',
#       'region_3depth_h_name': '당산2동',
#       'region_3depth_name': '당산동4가',
#       'sub_address_no': '1',
#       'x': '126.902731373207',
#       'y': '37.5266924348156'},
#      'address_name': '서울 영등포구 국회대로 615',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 영등포구 국회대로 615',
#       'building_name': '영등포제2스포츠센터',
#       'main_building_no': '615',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '영등포구',
#       'region_3depth_name': '당산동4가',
#       'road_name': '국회대로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.902731373207',
#       'y': '37.5266924348156',
#       'zone_no': '07221'},
#      'x': '126.902731373207',
#      'y': '37.5266924348156'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 동작구 대방동 406-10',
#       'b_code': '1159010800',
#       'h_code': '1159066000',
#       'main_address_no': '406',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동작구',
#       'region_3depth_h_name': '대방동',
#       'region_3depth_name': '대방동',
#       'sub_address_no': '10',
#       'x': '126.928222967016',
#       'y': '37.4997218266711'},
#      'address_name': '서울 동작구 상도로 지하 76',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 동작구 상도로 지하 76',
#       'building_name': '7호선 신대방삼거리역',
#       'main_building_no': '76',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동작구',
#       'region_3depth_name': '대방동',
#       'road_name': '상도로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.928222967016',
#       'y': '37.4997218266711',
#       'zone_no': '07041'},
#      'x': '126.928222967016',
#      'y': '37.4997218266711'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 동작구 상도동 26-20',
#       'b_code': '1159010200',
#       'h_code': '1159054000',
#       'main_address_no': '26',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동작구',
#       'region_3depth_h_name': '상도2동',
#       'region_3depth_name': '상도동',
#       'sub_address_no': '20',
#       'x': '126.938744364462',
#       'y': '37.5046658024741'},
#      'address_name': '서울 동작구 상도로 지하 188',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 동작구 상도로 지하 188',
#       'building_name': '장승배기역',
#       'main_building_no': '188',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동작구',
#       'region_3depth_name': '상도동',
#       'road_name': '상도로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.938744364462',
#       'y': '37.5046658024741',
#       'zone_no': '06963'},
#      'x': '126.938744364462',
#      'y': '37.5046658024741'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 동작구 사당동 736-1',
#       'b_code': '1159010700',
#       'h_code': '1159063000',
#       'main_address_no': '736',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동작구',
#       'region_3depth_h_name': '사당2동',
#       'region_3depth_name': '사당동',
#       'sub_address_no': '1',
#       'x': '126.982199707405',
#       'y': '37.4875538278198'},
#      'address_name': '서울 동작구 동작대로 지하 117',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 동작구 동작대로 지하 117',
#       'building_name': '총신대입구(이수)역4호선',
#       'main_building_no': '117',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동작구',
#       'region_3depth_name': '사당동',
#       'road_name': '동작대로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.982199707405',
#       'y': '37.4875538278198',
#       'zone_no': '07008'},
#      'x': '126.982199707405',
#      'y': '37.4875538278198'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 동작구 본동 475-1',
#       'b_code': '1159010400',
#       'h_code': '1159051000',
#       'main_address_no': '475',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동작구',
#       'region_3depth_h_name': '노량진1동',
#       'region_3depth_name': '본동',
#       'sub_address_no': '1',
#       'x': '126.95306410612',
#       'y': '37.5127787896024'},
#      'address_name': '서울 동작구 노량진로 지하 238',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 동작구 노량진로 지하 238',
#       'building_name': '9호선 노들역',
#       'main_building_no': '238',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동작구',
#       'region_3depth_name': '본동',
#       'road_name': '노량진로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.95306410612',
#       'y': '37.5127787896024',
#       'zone_no': '06906'},
#      'x': '126.95306410612',
#      'y': '37.5127787896024'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [{'address': {'address_name': '서울 관악구 신림동 1433-64',
#       'b_code': '1162010200',
#       'h_code': '1162069500',
#       'main_address_no': '1433',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_h_name': '신림동',
#       'region_3depth_name': '신림동',
#       'sub_address_no': '64',
#       'x': '126.927978489296',
#       'y': '37.4845080821278'},
#      'address_name': '서울 관악구 남부순환로 1597-8',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 관악구 남부순환로 1597-8',
#       'building_name': '',
#       'main_building_no': '1597',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_name': '신림동',
#       'road_name': '남부순환로',
#       'sub_building_no': '8',
#       'underground_yn': 'N',
#       'x': '126.927978489296',
#       'y': '37.4845080821278',
#       'zone_no': '08759'},
#      'x': '126.927978489296',
#      'y': '37.4845080821278'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 관악구 봉천동 979-2',
#       'b_code': '1162010100',
#       'h_code': '1162059500',
#       'main_address_no': '979',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_h_name': '청룡동',
#       'region_3depth_name': '봉천동',
#       'sub_address_no': '2',
#       'x': '126.952645104944',
#       'y': '37.4811526631844'},
#      'address_name': '서울 관악구 남부순환로 지하 1822',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 관악구 남부순환로 지하 1822',
#       'building_name': '',
#       'main_building_no': '1822',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_name': '봉천동',
#       'road_name': '남부순환로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.952645104944',
#       'y': '37.4811526631844',
#       'zone_no': '08787'},
#      'x': '126.952645104944',
#      'y': '37.4811526631844'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 관악구 봉천동 979-7',
#       'b_code': '1162010100',
#       'h_code': '1162060500',
#       'main_address_no': '979',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_h_name': '은천동',
#       'region_3depth_name': '봉천동',
#       'sub_address_no': '7',
#       'x': '126.941495272047',
#       'y': '37.4825562153548'},
#      'address_name': '서울 관악구 남부순환로 지하 1721',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 관악구 남부순환로 지하 1721',
#       'building_name': '',
#       'main_building_no': '1721',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_name': '봉천동',
#       'road_name': '남부순환로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.941495272047',
#       'y': '37.4825562153548',
#       'zone_no': '08757'},
#      'x': '126.941495272047',
#      'y': '37.4825562153548'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [{'address': {'address_name': '서울 관악구 봉천동 1693-39',
#       'b_code': '1162010100',
#       'h_code': '1162057500',
#       'main_address_no': '1693',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_h_name': '행운동',
#       'region_3depth_name': '봉천동',
#       'sub_address_no': '39',
#       'x': '126.963409959152',
#       'y': '37.4770651843603'},
#      'address_name': '서울 관악구 남부순환로 지하 1928',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 관악구 남부순환로 지하 1928',
#       'building_name': '',
#       'main_building_no': '1928',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_name': '봉천동',
#       'road_name': '남부순환로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.963409959152',
#       'y': '37.4770651843603',
#       'zone_no': '08793'},
#      'x': '126.963409959152',
#      'y': '37.4770651843603'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 관악구 신림동 209-1',
#       'b_code': '1162010200',
#       'h_code': '1162073500',
#       'main_address_no': '209',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_h_name': '대학동',
#       'region_3depth_name': '신림동',
#       'sub_address_no': '1',
#       'x': '126.944870911674',
#       'y': '37.4675976516718'},
#      'address_name': '서울 관악구 신림로3길 35',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 관악구 신림로3길 35',
#       'building_name': '관악문화관도서관',
#       'main_building_no': '35',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '관악구',
#       'region_3depth_name': '신림동',
#       'road_name': '신림로3길',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.944870911674',
#       'y': '37.4675976516718',
#       'zone_no': '08825'},
#      'x': '126.944870911674',
#      'y': '37.4675976516718'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 서초구 방배동 874-16',
#       'b_code': '1165010100',
#       'h_code': '1165060000',
#       'main_address_no': '874',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서초구',
#       'region_3depth_h_name': '방배1동',
#       'region_3depth_name': '방배동',
#       'sub_address_no': '16',
#       'x': '126.993190309509',
#       'y': '37.487533528504'},
#      'address_name': '서울 서초구 서초대로 지하 103',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 서초구 서초대로 지하 103',
#       'building_name': '내방역',
#       'main_building_no': '103',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서초구',
#       'region_3depth_name': '방배동',
#       'road_name': '서초대로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.993190309509',
#       'y': '37.487533528504',
#       'zone_no': '06573'},
#      'x': '126.993190309509',
#      'y': '37.487533528504'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 서초구 서초동 1366-9',
#       'b_code': '1165010800',
#       'h_code': '1165065100',
#       'main_address_no': '1366',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서초구',
#       'region_3depth_h_name': '양재1동',
#       'region_3depth_name': '서초동',
#       'sub_address_no': '9',
#       'x': '127.034544193436',
#       'y': '37.4839347328908'},
#      'address_name': '서울 서초구 남부순환로 지하 2585',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 서초구 남부순환로 지하 2585',
#       'building_name': '양재역',
#       'main_building_no': '2585',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서초구',
#       'region_3depth_name': '서초동',
#       'road_name': '남부순환로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '127.034544193436',
#       'y': '37.4839347328908',
#       'zone_no': '06735'},
#      'x': '127.034544193436',
#      'y': '37.4839347328908'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 강남구 삼성동 111-44',
#       'b_code': '1168010500',
#       'h_code': '1168059000',
#       'main_address_no': '111',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강남구',
#       'region_3depth_h_name': '삼성2동',
#       'region_3depth_name': '삼성동',
#       'sub_address_no': '44',
#       'x': '127.04130142966',
#       'y': '37.5171892352971'},
#      'address_name': '서울 강남구 학동로 지하 346',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 강남구 학동로 지하 346',
#       'building_name': '강남구청역',
#       'main_building_no': '346',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강남구',
#       'region_3depth_name': '삼성동',
#       'road_name': '학동로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '127.04130142966',
#       'y': '37.5171892352971',
#       'zone_no': '06099'},
#      'x': '127.04130142966',
#      'y': '37.5171892352971'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [{'address': {'address_name': '서울 강남구 청담동 77-76',
#       'b_code': '1168010400',
#       'h_code': '1168058000',
#       'main_address_no': '77',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강남구',
#       'region_3depth_h_name': '삼성1동',
#       'region_3depth_name': '청담동',
#       'sub_address_no': '76',
#       'x': '127.053644513011',
#       'y': '37.5194406566749'},
#      'address_name': '서울 강남구 학동로 지하 508',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 강남구 학동로 지하 508',
#       'building_name': '청담역',
#       'main_building_no': '508',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '강남구',
#       'region_3depth_name': '청담동',
#       'road_name': '학동로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '127.053644513011',
#       'y': '37.5194406566749',
#       'zone_no': '06084'},
#      'x': '127.053644513011',
#      'y': '37.5194406566749'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 송파구 신천동 15',
#       'b_code': '1171010200',
#       'h_code': '1171071000',
#       'main_address_no': '15',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '송파구',
#       'region_3depth_h_name': '잠실6동',
#       'region_3depth_name': '신천동',
#       'sub_address_no': '',
#       'x': '127.103811089444',
#       'y': '37.5206867318088'},
#      'address_name': '서울 송파구 오금로 20',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 송파구 오금로 20',
#       'building_name': '잠실나루역',
#       'main_building_no': '20',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '송파구',
#       'region_3depth_name': '신천동',
#       'road_name': '오금로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '127.103811089444',
#       'y': '37.5206867318088',
#       'zone_no': '05504'},
#      'x': '127.103811089444',
#      'y': '37.5206867318088'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [{'address': {'address_name': '서울 서대문구 북아현동 220-35',
#       'b_code': '1141011000',
#       'h_code': '1141055500',
#       'main_address_no': '220',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서대문구',
#       'region_3depth_h_name': '북아현동',
#       'region_3depth_name': '북아현동',
#       'sub_address_no': '35',
#       'x': '126.953011539907',
#       'y': '37.5574531753456'},
#      'address_name': '서울 서대문구 신촌로 243',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 서대문구 신촌로 243',
#       'building_name': '',
#       'main_building_no': '243',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서대문구',
#       'region_3depth_name': '북아현동',
#       'road_name': '신촌로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.953011539907',
#       'y': '37.5574531753456',
#       'zone_no': '03774'},
#      'x': '126.953011539907',
#      'y': '37.5574531753456'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 서대문구 홍제동 161-1',
#       'b_code': '1141011100',
#       'h_code': '1141064000',
#       'main_address_no': '161',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서대문구',
#       'region_3depth_h_name': '홍제3동',
#       'region_3depth_name': '홍제동',
#       'sub_address_no': '1',
#       'x': '126.944242309924',
#       'y': '37.5887103667691'},
#      'address_name': '서울 서대문구 통일로 지하 440-1',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 서대문구 통일로 지하 440-1',
#       'building_name': '홍제역',
#       'main_building_no': '440',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서대문구',
#       'region_3depth_name': '홍제동',
#       'road_name': '통일로',
#       'sub_building_no': '1',
#       'underground_yn': 'Y',
#       'x': '126.944242309924',
#       'y': '37.5887103667691',
#       'zone_no': '03629'},
#      'x': '126.944242309924',
#      'y': '37.5887103667691'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 서대문구 현저동 101',
#       'b_code': '1141010900',
#       'h_code': '1141052000',
#       'main_address_no': '101',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서대문구',
#       'region_3depth_h_name': '천연동',
#       'region_3depth_name': '현저동',
#       'sub_address_no': '',
#       'x': '126.957750279047',
#       'y': '37.5744103589329'},
#      'address_name': '서울 서대문구 통일로 지하 247',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 서대문구 통일로 지하 247',
#       'building_name': '독립문역',
#       'main_building_no': '247',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '서대문구',
#       'region_3depth_name': '현저동',
#       'road_name': '통일로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.957750279047',
#       'y': '37.5744103589329',
#       'zone_no': '03732'},
#      'x': '126.957750279047',
#      'y': '37.5744103589329'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 은평구 갈현동 397',
#       'b_code': '1138010400',
#       'h_code': '1138053000',
#       'main_address_no': '397',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '은평구',
#       'region_3depth_h_name': '불광2동',
#       'region_3depth_name': '갈현동',
#       'sub_address_no': '',
#       'x': '126.921162124977',
#       'y': '37.618962003178'},
#      'address_name': '서울 은평구 통일로 지하 849',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 은평구 통일로 지하 849',
#       'building_name': '3,6호선 연신내역사무소',
#       'main_building_no': '849',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '은평구',
#       'region_3depth_name': '갈현동',
#       'road_name': '통일로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.921162124977',
#       'y': '37.618962003178',
#       'zone_no': '03330'},
#      'x': '126.921162124977',
#      'y': '37.618962003178'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 은평구 대조동 13-10',
#       'b_code': '1138010600',
#       'h_code': '1138057000',
#       'main_address_no': '13',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '은평구',
#       'region_3depth_h_name': '대조동',
#       'region_3depth_name': '대조동',
#       'sub_address_no': '10',
#       'x': '126.92998576213',
#       'y': '37.6102072578868'},
#      'address_name': '서울 은평구 통일로 지하 723-1',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 은평구 통일로 지하 723-1',
#       'building_name': '3,6호선 불광역사무소',
#       'main_building_no': '723',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '은평구',
#       'region_3depth_name': '대조동',
#       'road_name': '통일로',
#       'sub_building_no': '1',
#       'underground_yn': 'Y',
#       'x': '126.92998576213',
#       'y': '37.6102072578868',
#       'zone_no': '03397'},
#      'x': '126.92998576213',
#      'y': '37.6102072578868'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 은평구 녹번동 153-31',
#       'b_code': '1138010200',
#       'h_code': '1138051000',
#       'main_address_no': '153',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '은평구',
#       'region_3depth_h_name': '녹번동',
#       'region_3depth_name': '녹번동',
#       'sub_address_no': '31',
#       'x': '126.922967946327',
#       'y': '37.6060390534435'},
#      'address_name': '서울 은평구 서오릉로 지하 63',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 은평구 서오릉로 지하 63',
#       'building_name': '6호선 역촌역사무소',
#       'main_building_no': '63',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '은평구',
#       'region_3depth_name': '녹번동',
#       'road_name': '서오릉로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '126.922967946327',
#       'y': '37.6060390534435',
#       'zone_no': '03459'},
#      'x': '126.922967946327',
#      'y': '37.6060390534435'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [{'address': {'address_name': '서울 중구 중림동 200',
#       'b_code': '1114017100',
#       'h_code': '1114068000',
#       'main_address_no': '200',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '중구',
#       'region_3depth_h_name': '중림동',
#       'region_3depth_name': '중림동',
#       'sub_address_no': '',
#       'x': '126.964320892997',
#       'y': '37.5589266608979'},
#      'address_name': '서울 중구 중림로 10',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 중구 중림로 10',
#       'building_name': '중림동 삼성 사이버 빌리지',
#       'main_building_no': '10',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '중구',
#       'region_3depth_name': '중림동',
#       'road_name': '중림로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.964320892997',
#       'y': '37.5589266608979',
#       'zone_no': '04502'},
#      'x': '126.964320892997',
#      'y': '37.5589266608979'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [{'address': {'address_name': '서울 용산구 후암동 30-84',
#       'b_code': '1117010100',
#       'h_code': '1117051000',
#       'main_address_no': '30',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '용산구',
#       'region_3depth_h_name': '후암동',
#       'region_3depth_name': '후암동',
#       'sub_address_no': '84',
#       'x': '126.982158117042',
#       'y': '37.5525564160959'},
#      'address_name': '서울 용산구 소월로 109',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 용산구 소월로 109',
#       'building_name': '남산도서관',
#       'main_building_no': '109',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '용산구',
#       'region_3depth_name': '후암동',
#       'road_name': '소월로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '126.982158117042',
#       'y': '37.5525564160959',
#       'zone_no': '04340'},
#      'x': '126.982158117042',
#      'y': '37.5525564160959'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 성북구 석관동 133-61',
#       'b_code': '1129013900',
#       'h_code': '1129081000',
#       'main_address_no': '133',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성북구',
#       'region_3depth_h_name': '석관동',
#       'region_3depth_name': '석관동',
#       'sub_address_no': '61',
#       'x': '127.064637747074',
#       'y': '37.6128367078355'},
#      'address_name': '서울 성북구 한천로78길 53',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 성북구 한천로78길 53',
#       'building_name': '',
#       'main_building_no': '53',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성북구',
#       'region_3depth_name': '석관동',
#       'road_name': '한천로78길',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '127.064637747074',
#       'y': '37.6128367078355',
#       'zone_no': '02781'},
#      'x': '127.064637747074',
#      'y': '37.6128367078355'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 성북구 종암동 29-18',
#       'b_code': '1129013500',
#       'h_code': '1129070500',
#       'main_address_no': '29',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성북구',
#       'region_3depth_h_name': '종암동',
#       'region_3depth_name': '종암동',
#       'sub_address_no': '18',
#       'x': '127.036284948669',
#       'y': '37.590649686622'},
#      'address_name': '서울 성북구 종암로 지하 1',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 성북구 종암로 지하 1',
#       'building_name': '고려대역',
#       'main_building_no': '1',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성북구',
#       'region_3depth_name': '종암동',
#       'road_name': '종암로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '127.036284948669',
#       'y': '37.590649686622',
#       'zone_no': '02841'},
#      'x': '127.036284948669',
#      'y': '37.590649686622'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [],
#    'meta': {'is_end': True, 'pageable_count': 0, 'total_count': 0}}],
#  [{'documents': [{'address': {'address_name': '서울 성동구 금호동4가 1470',
#       'b_code': '1120011200',
#       'h_code': '1120062000',
#       'main_address_no': '1470',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성동구',
#       'region_3depth_h_name': '금호4가동',
#       'region_3depth_name': '금호동4가',
#       'sub_address_no': '',
#       'x': '127.015893753726',
#       'y': '37.5481125196986'},
#      'address_name': '서울 성동구 동호로 지하 104',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 성동구 동호로 지하 104',
#       'building_name': '금호역',
#       'main_building_no': '104',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성동구',
#       'region_3depth_name': '금호동4가',
#       'road_name': '동호로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '127.015893753726',
#       'y': '37.5481125196986',
#       'zone_no': '04724'},
#      'x': '127.015893753726',
#      'y': '37.5481125196986'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 성동구 옥수동 168-1',
#       'b_code': '1120011300',
#       'h_code': '1120064500',
#       'main_address_no': '168',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성동구',
#       'region_3depth_h_name': '옥수동',
#       'region_3depth_name': '옥수동',
#       'sub_address_no': '1',
#       'x': '127.018329991576',
#       'y': '37.5410468905674'},
#      'address_name': '서울 성동구 동호로 21',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 성동구 동호로 21',
#       'building_name': '옥수역',
#       'main_building_no': '21',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성동구',
#       'region_3depth_name': '옥수동',
#       'road_name': '동호로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '127.018329991576',
#       'y': '37.5410468905674',
#       'zone_no': '04739'},
#      'x': '127.018329991576',
#      'y': '37.5410468905674'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 성동구 하왕십리동 946-14',
#       'b_code': '1120010200',
#       'h_code': '1120052000',
#       'main_address_no': '946',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성동구',
#       'region_3depth_h_name': '왕십리2동',
#       'region_3depth_name': '하왕십리동',
#       'sub_address_no': '14',
#       'x': '127.029031221392',
#       'y': '37.5644687111181'},
#      'address_name': '서울 성동구 왕십리로 지하 374',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 성동구 왕십리로 지하 374',
#       'building_name': '상왕십리역',
#       'main_building_no': '374',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '성동구',
#       'region_3depth_name': '하왕십리동',
#       'road_name': '왕십리로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '127.029031221392',
#       'y': '37.5644687111181',
#       'zone_no': '04701'},
#      'x': '127.029031221392',
#      'y': '37.5644687111181'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 동대문구 이문동 270-1',
#       'b_code': '1123011000',
#       'h_code': '1123074000',
#       'main_address_no': '270',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동대문구',
#       'region_3depth_h_name': '이문1동',
#       'region_3depth_name': '이문동',
#       'sub_address_no': '1',
#       'x': '127.057942413722',
#       'y': '37.5982966771548'},
#      'address_name': '서울 동대문구 이문로 107',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 동대문구 이문로 107',
#       'building_name': '한국외국어대학교',
#       'main_building_no': '107',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '동대문구',
#       'region_3depth_name': '이문동',
#       'road_name': '이문로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '127.057942413722',
#       'y': '37.5982966771548',
#       'zone_no': '02450'},
#      'x': '127.057942413722',
#      'y': '37.5982966771548'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 도봉구 창동 703-4',
#       'b_code': '1132010700',
#       'h_code': '1132051100',
#       'main_address_no': '703',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '도봉구',
#       'region_3depth_h_name': '창1동',
#       'region_3depth_name': '창동',
#       'sub_address_no': '4',
#       'x': '127.034880717215',
#       'y': '37.6488498649136'},
#      'address_name': '서울 도봉구 도봉로 지하 486-1',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 도봉구 도봉로 지하 486-1',
#       'building_name': '쌍문역',
#       'main_building_no': '486',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '도봉구',
#       'region_3depth_name': '창동',
#       'road_name': '도봉로',
#       'sub_building_no': '1',
#       'underground_yn': 'Y',
#       'x': '127.034880717215',
#       'y': '37.6488498649136',
#       'zone_no': '01454'},
#      'x': '127.034880717215',
#      'y': '37.6488498649136'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 노원구 중계동 508',
#       'b_code': '1135010600',
#       'h_code': '1135062500',
#       'main_address_no': '508',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '노원구',
#       'region_3depth_h_name': '중계2.3동',
#       'region_3depth_name': '중계동',
#       'sub_address_no': '',
#       'x': '127.067821262987',
#       'y': '37.6395138569616'},
#      'address_name': '서울 노원구 동일로204길 13',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 노원구 동일로204길 13',
#       'building_name': '노원평생학습관',
#       'main_building_no': '13',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '노원구',
#       'region_3depth_name': '중계동',
#       'road_name': '동일로204길',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '127.067821262987',
#       'y': '37.6395138569616',
#       'zone_no': '01783'},
#      'x': '127.067821262987',
#      'y': '37.6395138569616'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 중랑구 면목동 1316-5',
#       'b_code': '1126010100',
#       'h_code': '1126054000',
#       'main_address_no': '1316',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '중랑구',
#       'region_3depth_h_name': '면목4동',
#       'region_3depth_name': '면목동',
#       'sub_address_no': '5',
#       'x': '127.087038114766',
#       'y': '37.5740302107904'},
#      'address_name': '서울 중랑구 용마산로 지하 227',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 중랑구 용마산로 지하 227',
#       'building_name': '용마산역',
#       'main_building_no': '227',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '중랑구',
#       'region_3depth_name': '면목동',
#       'road_name': '용마산로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '127.087038114766',
#       'y': '37.5740302107904',
#       'zone_no': '02254'},
#      'x': '127.087038114766',
#      'y': '37.5740302107904'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 중랑구 상봉동 74-4',
#       'b_code': '1126010200',
#       'h_code': '1126058000',
#       'main_address_no': '74',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '중랑구',
#       'region_3depth_h_name': '상봉1동',
#       'region_3depth_name': '상봉동',
#       'sub_address_no': '4',
#       'x': '127.094804633379',
#       'y': '37.5988433313352'},
#      'address_name': '서울 중랑구 망우로 383',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 중랑구 망우로 383',
#       'building_name': '',
#       'main_building_no': '383',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '중랑구',
#       'region_3depth_name': '상봉동',
#       'road_name': '망우로',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '127.094804633379',
#       'y': '37.5988433313352',
#       'zone_no': '02086'},
#      'x': '127.094804633379',
#      'y': '37.5988433313352'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 중랑구 중화동 50-3',
#       'b_code': '1126010300',
#       'h_code': '1126060000',
#       'main_address_no': '50',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '중랑구',
#       'region_3depth_h_name': '중화1동',
#       'region_3depth_name': '중화동',
#       'sub_address_no': '3',
#       'x': '127.079469204905',
#       'y': '37.6015796992834'},
#      'address_name': '서울 중랑구 동일로 지하 797',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 중랑구 동일로 지하 797',
#       'building_name': '중화역',
#       'main_building_no': '797',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '중랑구',
#       'region_3depth_name': '중화동',
#       'road_name': '동일로',
#       'sub_building_no': '',
#       'underground_yn': 'Y',
#       'x': '127.079469204905',
#       'y': '37.6015796992834',
#       'zone_no': '02017'},
#      'x': '127.079469204905',
#      'y': '37.6015796992834'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}],
#  [{'documents': [{'address': {'address_name': '서울 광진구 광장동 112',
#       'b_code': '1121510400',
#       'h_code': '1121581000',
#       'main_address_no': '112',
#       'mountain_yn': 'N',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '광진구',
#       'region_3depth_h_name': '광장동',
#       'region_3depth_name': '광장동',
#       'sub_address_no': '',
#       'x': '127.110615495296',
#       'y': '37.5510729137918'},
#      'address_name': '서울 광진구 아차산로78길 90',
#      'address_type': 'ROAD_ADDR',
#      'road_address': {'address_name': '서울 광진구 아차산로78길 90',
#       'building_name': '',
#       'main_building_no': '90',
#       'region_1depth_name': '서울',
#       'region_2depth_name': '광진구',
#       'region_3depth_name': '광장동',
#       'road_name': '아차산로78길',
#       'sub_building_no': '',
#       'underground_yn': 'N',
#       'x': '127.110615495296',
#       'y': '37.5510729137918',
#       'zone_no': '04969'},
#      'x': '127.110615495296',
#      'y': '37.5510729137918'}],
#    'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}]]

# %%
smart['longtitude'] =

# %%
smart['latitude'] =
